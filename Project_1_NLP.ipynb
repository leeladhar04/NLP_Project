# %% [markdown]
# ### Book Link
#
# https://drive.google.com/file/d/18BmnoAIu7tT-Rt_6jI0mPjwC8StyVvep/view?usp=share_link

# %% [markdown]
# ### Importing necessary libraries

# %%
import nltk
import seaborn as sns 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import re
import random as rnd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from wordcloud import WordCloud
from collections import defaultdict,Counter
from nltk.util import ngrams

# %% [markdown]
# ### Downloading packages

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\issar\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\issar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\issar\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# ### Function for data preprocessing using regular expressions

# %%
def text_preprocessing(raw):
    # lower case
    raw = raw.lower()
    # remove numbers
    raw = re.sub(r'\d+', '', raw)
    # remove punctuation
    raw = re.sub(r'[^\w\s]', '', raw)
    # white space removal
    raw = raw.strip()
    #removing any non alphanumeric characters
    raw = re.sub('\W', ' ', raw)  
    #removing extra white spaces
    raw = re.sub('\s+', ' ', raw) 
    #removing chapter numbers and running sections
    raw = re.sub('chapter \w*', '', raw)   
    return (raw)

# %% [markdown]
# ## Importing the text

# %%
novel= open("novel.txt")
raw_text=novel.read()
T=raw_text

# %%
T
# Out:
# ' OPERATION INTERSTELLAR ***\n\n\n\n\nProduced by Greg Weeks, Mary Meehan and the Online\nDistributed Proofreading Team at http://www.pgdp.net\n\n\n\n\n\n\n\n\n\n                        OPERATION INTERSTELLAR\n\n                                 _By_\n                            George O. Smith\n\n                         CENTURY PUBLICATIONS\n                                Chicago\n\n                  Published by Century Publications,\n                   139 N. Clark St., Chicago 2, Ill.\n               _Printed in the United States of America_\n\n     Characters and situations in this book are fictional and any\n    similarity to actual persons or places is purely coincidental.\n\n        Permission to use some of the refrains from the ballad:\n\n                     THE CYCLOTRONIST\'S NIGHTMARE\n\n                           by Arthur Roberts\n                                  of\n                     The State University of Iowa\n          was graciously granted, and is hereby acknowledged\n                      with sincere appreciation.\n\n                        Cover by Malcolm Smith\n\n                _Copyright 1950, Century Publications_\n\n      [Transcriber\'s Note: Extensive research did not uncover any\n    evidence that the U.S. copyright on this publication was renewed.]\n\n\n\n\nCHAPTER 1\n\n\nPaul Grayson walked the city street slowly. He was sauntering towards\nthe spaceport, but he was in no hurry. He had allowed himself plenty of\ntime to breathe the fresh spring air, to listen to the myriad of sounds\nmade by his fellow men, and to revel in the grand freedom that being\nout in the open gave him. Soon enough he would be breathing canned air,\npungent with the odor of compressor oil and the tang of the greenery\nused to replenish the oxygen, unable to walk freely more than a few\ndozen steps, and unable to see what lies beyond his viewports.\n\nOccasionally his eyes looked along the low southern sky towards Alpha\nCentauri. Proxima, of course, could not be resolved by the naked eye,\nmuch less the stinking little overheated mote that rotated about\nProxima. Obviously unfit for human life and patently incapable of\nspawning life of its own, it was Paul Grayson\'s destination, and would\nbe his home for a few days or a few weeks depending entirely upon\nwhether things went good or bad.\n\nOnly during the last four out of two thousand millions of years of its\nlife had this planet been useful. Man needed a place to stand; not\nto move the earth with Archimedes\'s lever but to survey the galaxy.\nProxima Centauri I was the only planet in the trinary and as bad as it\nwas, it was useful for a space station.\n\nIn an hour, Paul Grayson would be locked in a capsule of metal hurling\nhimself through space towards Proxima I. He was looking forward to ten\ndays cooped up in a spacecraft of the type furnished by the Bureau of\nAstrogation to its engineers which was a far cry from the sumptuous\ncraft run by the Big Brass. His confines would be lined with functional\nscientific equipment; his air supply would be medically acceptable but\naesthetically horrible; and his vision limited to the cabin, for beyond\nthe viewports would be only the formless, endless, abysmal blackness of\nabsolutely nothing while the ship mounted into multiples of the speed\nof light.\n\nThen days in a building filled to the dome with power equipment and\nradio gear; timing mechanism and recorders; and a refrigerator set-up\nthat struggled with the awesome heat poured into Proxima I by its\nclose-by luminary but which succeeded only in lowering the temperature\nto the point where the potting compound in the transformers did not run\nout, where the calibrating resistors would not change their values,\nwhere the recording machines would still make a record.\n\nAnd then again more days in the ship before it returned to earth. Call\nit thirty days and understand why Paul Grayson sauntered along killing\ntime in the fresh air before taking off.\n ...

# %% [markdown]
# ### Applying the preprocessing function

# %%
T=text_preprocessing(T)
print(T)
# Out:
# operation interstellar produced by greg weeks mary meehan and the online distributed proofreading team at httpwwwpgdpnet operation interstellar _by_ george o smith century publications chicago published by century publications n clark st chicago ill _printed in the united states of america_ characters and situations in this book are fictional and any similarity to actual persons or places is purely coincidental permission to use some of the refrains from the ballad the cyclotronists nightmare by arthur roberts of the state university of iowa was graciously granted and is hereby acknowledged with sincere appreciation cover by malcolm smith _copyright century publications_ transcribers note extensive research did not uncover any evidence that the us copyright on this publication was renewed  grayson walked the city street slowly he was sauntering towards the spaceport but he was in no hurry he had allowed himself plenty of time to breathe the fresh spring air to listen to the myriad of sounds made by his fellow men and to revel in the grand freedom that being out in the open gave him soon enough he would be breathing canned air pungent with the odor of compressor oil and the tang of the greenery used to replenish the oxygen unable to walk freely more than a few dozen steps and unable to see what lies beyond his viewports occasionally his eyes looked along the low southern sky towards alpha centauri proxima of course could not be resolved by the naked eye much less the stinking little overheated mote that rotated about proxima obviously unfit for human life and patently incapable of spawning life of its own it was paul graysons destination and would be his home for a few days or a few weeks depending entirely upon whether things went good or bad only during the last four out of two thousand millions of years of its life had this planet been useful man needed a place to stand not to move the earth with archimedess lever but to survey the galaxy proxima centauri i was the only planet in the trinary and as bad as it was it was useful for a space station in an hour paul grayson would be locked in a capsule of metal hurling himself through space towards proxima i he was looking forward to ten days cooped up in a spacecraft of the type furnished by the bureau of astrogation to its engineers which was a far cry from the sumptuous craft run by the big brass his confines would be lined with functional scientific equipment his air supply would be medically acceptable but aesthetically horrible and his vision limited to the cabin for beyond the viewports would be only the formless endless abysmal blackness of absolutely nothing while the ship mounted into multiples of the speed of light then days in a building filled to the dome with power equipment and radio gear timing mechanism and recorders and a refrigerator setup that struggled with the awesome heat poured into proxima i by its closeby luminary but which succeeded only in lowering the temperature to the point where the potting compound in the transformers did not run out where the calibrating resistors would not change their values where the recording machines would still make a record and then again more days in the ship before it returned to earth call it thirty days and understand why paul grayson sauntered along killing time in the fresh air before taking off paul grinned four years ago he had arrived a full hour early and wasted the hour in the smelly ship instead of filling his lungs with clean fresh air never again he would arrive a full five minutes before checkin time he heard some radio music its tone stripped of high frequencies from its passage through the slit of a partiallyopened window he sniffed the air and laughed because someone was cooking corned beef and cabbage then he was out of the range of the radio music paul liked music he hummed a tune as he walked and then as the fancy struck him he started to sing it was faint singing it would not have carried more than a  ...

# %%
def stopwords_text(text):
    stop_words = set(nltk.corpus.stopwords.words('english'))

    x = 65
    y = 97
    # Adding all the uppercase and lowecase letters to stopwords
    
    for i in range(26):
        stop_words.add(chr(x))
        stop_words.add(chr(y))
        x += 1
        y += 1
    tokens = word_tokenize(text)
    result = [i for i in tokens if not i in stop_words]
    return result

# %% [markdown]
# ## Tokenizing the text

# %%
tokenized_T=word_tokenize(T)
tokenized_T
# Out:
# ['operation',
#  'interstellar',
#  'produced',
#  'by',
#  'greg',
#  'weeks',
#  'mary',
#  'meehan',
#  'and',
#  'the',
#  'online',
#  'distributed',
#  'proofreading',
#  'team',
#  'at',
#  'httpwwwpgdpnet',
#  'operation',
#  'interstellar',
#  '_by_',
#  'george',
#  'o',
#  'smith',
#  'century',
#  'publications',
#  'chicago',
#  'published',
#  'by',
#  'century',
#  'publications',
#  'n',
#  'clark',
#  'st',
#  'chicago',
#  'ill',
#  '_printed',
#  'in',
#  'the',
#  'united',
#  'states',
#  'of',
#  'america_',
#  'characters',
#  'and',
#  'situations',
#  'in',
#  'this',
#  'book',
#  'are',
#  'fictional',
#  'and',
#  'any',
#  'similarity',
#  'to',
#  'actual',
#  'persons',
#  'or',
#  'places',
#  'is',
#  'purely',
#  'coincidental',
#  'permission',
#  'to',
#  'use',
#  'some',
#  'of',
#  'the',
#  'refrains',
#  'from',
#  'the',
#  'ballad',
#  'the',
#  'cyclotronists',
#  'nightmare',
#  'by',
#  'arthur',
#  'roberts',
#  'of',
#  'the',
#  'state',
#  'university',
#  'of',
#  'iowa',
#  'was',
#  'graciously',
#  'granted',
#  'and',
#  'is',
#  'hereby',
#  'acknowledged',
#  'with',
#  'sincere',
#  'appreciation',
#  'cover',
#  'by',
#  'malcolm',
#  'smith',
#  '_copyright',
#  'century',
#  'publications_',
#  'transcribers',
#  'note',
#  'extensive',
#  'research',
#  'did',
#  'not',
#  'uncover',
#  'any',
#  'evidence',
#  'that',
#  'the',
#  'us',
#  'copyright',
#  'on',
#  'this',
#  'publication',
#  'was',
#  'renewed',
#  'grayson',
#  'walked',
#  'the',
#  'city',
#  'street',
#  'slowly',
#  'he',
#  'was',
#  'sauntering',
#  'towards',
#  'the',
#  'spaceport',
#  'but',
#  'he',
#  'was',
#  'in',
#  'no',
#  'hurry',
#  'he',
#  'had',
#  'allowed',
#  'himself',
#  'plenty',
#  'of',
#  'time',
#  'to',
#  'breathe',
#  'the',
#  'fresh',
#  'spring',
#  'air',
#  'to',
#  'listen',
#  'to',
#  'the',
#  'myriad',
#  'of',
#  'sounds',
#  'made',
#  'by',
#  'his',
#  'fellow',
#  'men',
#  'and',
#  'to',
#  'revel',
#  'in',
#  'the',
#  'grand',
#  'freedom',
#  'that',
#  'being',
#  'out',
#  'in',
#  'the',
#  'open',
#  'gave',
#  'him',
#  'soon',
#  'enough',
#  'he',
#  'would',
#  'be',
#  'breathing',
#  'canned',
#  'air',
#  'pungent',
#  'with',
#  'the',
#  'odor',
#  'of',
#  'compressor',
#  'oil',
#  'and',
#  'the',
#  'tang',
#  'of',
#  'the',
#  'greenery',
#  'used',
#  'to',
#  'replenish',
#  'the',
#  'oxygen',
#  'unable',
#  'to',
#  'walk',
#  'freely',
#  'more',
#  'than',
#  'a',
#  'few',
#  'dozen',
#  'steps',
#  'and',
#  'unable',
#  'to',
#  'see',
#  'what',
#  'lies',
#  'beyond',
#  'his',
#  'viewports',
#  'occasionally',
#  'his',
#  'eyes',
#  'looked',
#  'along',
#  'the',
#  'low',
#  'southern',
#  'sky',
#  'towards',
#  'alpha',
#  'centauri',
#  'proxima',
#  'of',
#  'course',
#  'could',
#  'not',
#  'be',
#  'resolved',
#  'by',
#  'the',
#  'naked',
#  'eye',
#  'much',
#  'less',
#  'the',
#  'stinking',
#  'little',
#  'overheated',
#  'mote',
#  'that',
#  'rotated',
#  'about',
#  'proxima',
#  'obviously',
#  'unfit',
#  'for',
#  'human',
#  'life',
#  'and',
#  'patently',
#  'incapable',
#  'of',
#  'spawning',
#  'life',
#  'of',
#  'its',
#  'own',
#  'it',
#  'was',
#  'paul',
#  'graysons',
#  'destination',
#  'and',
#  'would',
#  'be',
#  'his',
#  'home',
#  'for',
#  'a',
#  'few',
#  'days',
#  'or',
#  'a',
#  'few',
#  'weeks',
#  'depending',
#  'entirely',
#  'upon',
#  'whether',
#  'things',
#  'went',
#  'good',
#  'or',
#  'bad',
#  'only',
#  'during',
#  'the',
#  'last',
#  'four',
#  'out',
#  'of',
#  'two',
#  'thousand',
#  'millions',
#  'of',
#  'years',
#  'of',
#  'its',
#  'life',
#  'had',
#  'this',
#  'planet',
#  'been',
#  'useful',
#  'man',
#  'needed',
#  'a',
#  'place',
#  'to',
#  'stand',
#  'not',
#  'to',
#  'move',
#  'the',
#  'earth',
#  'with',
#  'archimedess',
#  'lever',
#  'but',
#  'to',
#  'survey',
#  'the',
#  'galaxy',
#  'proxima',
#  'centauri',
#  'i',
#  'was',
#  'the',
#  'only',
#  'planet',
#  'in',
#  'the',
#  'trinary',
#  'and',
#  'as',
#  'bad',
#  'as',
#  'it',
#  'was',
#  'it',
#  'was',
#  'useful',
#  'for',
#  'a',
#  'space',
#  'station',
#  'in',
#  'an',
#  'hour',
#  'paul',
#  'grayson',
#  'would',
#  'be',
#  'locked',
#  'in',
#  'a',
#  'capsule',
#  'of',
#  'metal',
#  'hurling',
#  'himself',
#  'through',
#  'space',
#  'towards',
#  'proxima',
#  'i',
#  'he',
#  'was',
#  'looking',
#  'forward',
#  'to',
#  'ten',
#  'days',
#  'cooped',
#  'up',
#  'in',
#  'a',
#  'spacecraft',
#  'of',
#  'the',
#  'type',
#  'furnished',
#  'by',
#  'the',
#  'bureau',
#  'of',
#  'astrogation',
#  'to',
#  'its',
#  'engineers',
#  'which',
#  'was',
#  'a',
#  'far',
#  'cry',
#  'from',
#  'the',
#  'sumptuous',
#  'craft',
#  'run',
#  'by',
#  'the',
#  'big',
#  'brass',
#  'his',
#  'confines',
#  'would',
#  'be',
#  'lined',
#  'with',
#  'functional',
#  'scientific',
#  'equipment',
#  'his',
#  'air',
#  'supply',
#  'would',
#  'be',
#  'medically',
#  'acceptable',
#  'but',
#  'aesthetically',
#  'horrible',
#  'and',
#  'his',
#  'vision',
#  'limited',
#  'to',
#  'the',
#  'cabin',
#  'for',
#  'beyond',
#  'the',
#  'viewports',
#  'would',
#  'be',
#  'only',
#  'the',
#  'formless',
#  'endless',
#  'abysmal',
#  'blackness',
#  'of',
#  'absolutely',
#  'nothing',
#  'while',
#  'the',
#  'ship',
#  'mounted',
#  'into',
#  'multiples',
#  'of',
#  'the',
#  'speed',
#  'of',
#  'light',
#  'then',
#  'days',
#  'in',
#  'a',
#  'building',
#  'filled',
#  'to',
#  'the',
#  'dome',
#  'with',
#  'power',
#  'equipment',
#  'and',
#  'radio',
#  'gear',
#  'timing',
#  'mechanism',
#  'and',
#  'recorders',
#  'and',
#  'a',
#  'refrigerator',
#  'setup',
#  'that',
#  'struggled',
#  'with',
#  'the',
#  'awesome',
#  'heat',
#  'poured',
#  'into',
#  'proxima',
#  'i',
#  'by',
#  'its',
#  'closeby',
#  'luminary',
#  'but',
#  'which',
#  'succeeded',
#  'only',
#  'in',
#  'lowering',
#  'the',
#  'temperature',
#  'to',
#  'the',
#  'point',
#  'where',
#  'the',
#  'potting',
#  'compound',
#  'in',
#  'the',
#  'transformers',
#  'did',
#  'not',
#  'run',
#  'out',
#  'where',
#  'the',
#  'calibrating',
#  'resistors',
#  'would',
#  'not',
#  'change',
#  'their',
#  'values',
#  'where',
#  'the',
#  'recording',
#  'machines',
#  'would',
#  'still',
#  'make',
#  'a',
#  'record',
#  'and',
#  'then',
#  'again',
#  'more',
#  'days',
#  'in',
#  'the',
#  'ship',
#  'before',
#  'it',
#  'returned',
#  'to',
#  'earth',
#  'call',
#  'it',
#  'thirty',
#  'days',
#  'and',
#  'understand',
#  'why',
#  'paul',
#  'grayson',
#  'sauntered',
#  'along',
#  'killing',
#  'time',
#  'in',
#  'the',
#  'fresh',
#  'air',
#  'before',
#  'taking',
#  'off',
#  'paul',
#  'grinned',
#  'four',
#  'years',
#  'ago',
#  'he',
#  'had',
#  'arrived',
#  'a',
#  'full',
#  'hour',
#  'early',
#  'and',
#  'wasted',
#  'the',
#  'hour',
#  'in',
#  'the',
#  'smelly',
#  'ship',
#  'instead',
#  'of',
#  'filling',
#  'his',
#  'lungs',
#  'with',
#  'clean',
#  'fresh',
#  'air',
#  'never',
#  'again',
#  'he',
#  'would',
#  'arrive',
#  'a',
#  'full',
#  'five',
#  'minutes',
#  'before',
#  'checkin',
#  'time',
#  'he',
#  'heard',
#  'some',
#  'radio',
#  'music',
#  'its',
#  'tone',
#  'stripped',
#  'of',
#  'high',
#  'frequencies',
#  'from',
#  'its',
#  'passage',
#  'through',
#  'the',
#  'slit',
#  'of',
#  'a',
#  'partiallyopened',
#  'window',
#  'he',
#  'sniffed',
#  'the',
#  'air',
#  'and',
#  'laughed',
#  'because',
#  'someone',
#  'was',
#  'cooking',
#  'corned',
#  'beef',
#  'and',
#  'cabbage',
#  'then',
#  'he',
#  'was',
#  'out',
#  'of',
#  'the',
#  'range',
#  'of',
#  'the',
#  'radio',
#  'music',
#  'paul',
#  'liked',
#  'music',
#  'he',
#  'hummed',
#  'a',
#  'tune',
#  'as',
#  'he',
#  'walked',
#  'and',
#  'then',
#  'as',
#  'the',
#  'fancy',
#  'struck',
#  'him',
#  'he',
#  'started',
#  'to',
#  'sing',
#  'it',
#  'was',
#  'faint',
#  'singing',
#  'it',
#  'would',
#  'not',
#  'have',
#  'carried',
#  'more',
#  'than',
#  'a',
#  'few',
#  'feet',
#  'but',
#  'it',
#  'sufficed',
#  'for',
#  'paul',
#  'it',
#  'was',
#  'a',
#  'refrain',
#  'from',
#  'an',
#  'early',
#  'atomicage',
#  'ballad',
#  '_round',
#  'and',
#  'round',
#  'and',
#  'round',
#  'go',
#  'the',
#  'deuterons',
#  'round',
#  'and',
#  'round',
#  'the',
#  'magnet',
#  'swings',
#  'them',
#  'round',
#  'and',
#  'round',
#  'and',
#  'round',
#  'go',
#  'the',
#  'deuterons',
#  'smack',
#  'in',
#  'the',
#  'target',
#  'goes',
#  'the',
#  'ion',
#  'beam_',
#  'paul',
#  'stopped',
#  'his',
#  'song',
#  'because',
#  'the',
#  'interesting',
#  'click',
#  'of',
#  'high',
#  'heels',
#  'on',
#  'the',
#  'sidewalk',
#  'pointed',
#  'to',
#  'the',
#  'approach',
#  'of',
#  'someone',
#  'who',
#  'might',
#  'view',
#  '_a',
#  'cappella_',
#  'singing',
#  'as',
#  'an',
#  'indication',
#  'of',
#  'inebriation',
#  'she',
#  'was',
#  'coming',
#  'towards',
#  'him',
#  'walking',
#  'on',
#  'the',
#  'same',
#  'side',
#  'of',
#  'the',
#  'sidewalk',
#  'her',
#  'step',
#  'was',
#  'quick',
#  'and',
#  'lithe',
#  'and',
#  'the',
#  'slight',
#  'breeze',
#  'outlined',
#  'her',
#  'frock',
#  'against',
#  'her',
#  'body',
#  'revealing',
#  'and',
#  'at',
#  'the',
#  'same',
#  'time',
#  'concealing',
#  'just',
#  'enough',
#  'to',
#  'quicken',
#  'the',
#  'pulse',
#  'and',
#  'awaken',
#  'the',
#  'interest',
#  'paul',
#  'was',
#  'thirty',
#  'and',
#  'unmarried',
#  'and',
#  'experienced',
#  'enough',
#  'to',
#  'catalogue',
#  'her',
#  'shrewdly',
#  'no',
#  'crude',
#  'attempt',
#  'at',
#  'pickup',
#  'would',
#  'work',
#  'on',
#  'this',
#  'woman',
#  'she',
#  'was',
#  'sure',
#  'of',
#  'herself',
#  'and',
#  'obviously',
#  'could',
#  'not',
#  'want',
#  'for',
#  'admirers',
#  'it',
#  'would',
#  'take',
#  'careful',
#  'strategy',
#  'over',
#  'a',
#  'period',
#  'of',
#  'time',
#  'to',
#  'get',
#  'to',
#  'first',
#  'base',
#  'with',
#  'a',
#  'woman',
#  'like',
#  'her',
#  'an',
#  'inept',
#  'campaigner',
#  'would',
#  'be',
#  'called',
#  'out',
#  'on',
#  'strikes',
#  'and',
#  'paul',
#  'grayson',
#  'had',
#  'to',
#  'be',
#  'on',
#  'the',
#  'way',
#  'to',
#  'centauri',
#  'within',
#  'the',
#  'hour',
#  'which',
#  'automatically',
#  'eliminated',
#  'the',
#  'initial',
#  'step',
#  'in',
#  'any',
#  'plausible',
#  'scheme',
#  'to',
#  'wrangle',
#  'an',
#  'introduction',
#  'paul',
#  'grayson',
#  'grinned',
#  'ruefully',
#  'it',
#  'seemed',
#  'to',
#  'him',
#  'that',
#  'when',
#  'he',
#  'had',
#  'hours',
#  'to',
#  'spend',
#  'and',
#  'nothing',
#  'to',
#  'do',
#  'the',
#  'streets',
#  'were',
#  'barren',
#  'of',
#  'presentable',
#  'women',
#  'while',
#  'the',
#  'most',
#  'interesting',
#  'specimens',
#  'of',
#  'womanhood',
#  'smiled',
#  'and',
#  'offered',
#  'their',
#  'charms',
#  'when',
#  'he',
#  'was',
#  'en',
#  'route',
#  'towards',
#  'some',
#  'schedule',
#  'that',
#  'could',
#  'not',
#  'be',
#  'delayed',
#  'this',
#  'was',
#  'woman',
#  'enough',
#  'to',
#  'make',
#  'a',
#  'man',
#  'forget',
#  'his',
#  'timetablesalmost',
#  'she',
#  'came',
#  'forward',
#  'her',
#  'face',
#  'lighted',
#  'by',
#  'the',
#  'street',
#  'lamp',
#  'that',
#  'paul',
#  'had',
#  'just',
#  'passed',
#  'blueeyed',
#  'and',
#  'fairskinned',
#  'her',
#  'hurried',
#  'route',
#  'was',
#  'on',
#  'collision',
#  'course',
#  'with',
#  ...]

# %% [markdown]
# ## Text tokenized and stopwords removed

# %%
cleaned_text=stopwords_text(T)
cleaned_text
# Out:
# ['operation',
#  'interstellar',
#  'produced',
#  'greg',
#  'weeks',
#  'mary',
#  'meehan',
#  'online',
#  'distributed',
#  'proofreading',
#  'team',
#  'httpwwwpgdpnet',
#  'operation',
#  'interstellar',
#  '_by_',
#  'george',
#  'smith',
#  'century',
#  'publications',
#  'chicago',
#  'published',
#  'century',
#  'publications',
#  'clark',
#  'st',
#  'chicago',
#  'ill',
#  '_printed',
#  'united',
#  'states',
#  'america_',
#  'characters',
#  'situations',
#  'book',
#  'fictional',
#  'similarity',
#  'actual',
#  'persons',
#  'places',
#  'purely',
#  'coincidental',
#  'permission',
#  'use',
#  'refrains',
#  'ballad',
#  'cyclotronists',
#  'nightmare',
#  'arthur',
#  'roberts',
#  'state',
#  'university',
#  'iowa',
#  'graciously',
#  'granted',
#  'hereby',
#  'acknowledged',
#  'sincere',
#  'appreciation',
#  'cover',
#  'malcolm',
#  'smith',
#  '_copyright',
#  'century',
#  'publications_',
#  'transcribers',
#  'note',
#  'extensive',
#  'research',
#  'uncover',
#  'evidence',
#  'us',
#  'copyright',
#  'publication',
#  'renewed',
#  'grayson',
#  'walked',
#  'city',
#  'street',
#  'slowly',
#  'sauntering',
#  'towards',
#  'spaceport',
#  'hurry',
#  'allowed',
#  'plenty',
#  'time',
#  'breathe',
#  'fresh',
#  'spring',
#  'air',
#  'listen',
#  'myriad',
#  'sounds',
#  'made',
#  'fellow',
#  'men',
#  'revel',
#  'grand',
#  'freedom',
#  'open',
#  'gave',
#  'soon',
#  'enough',
#  'would',
#  'breathing',
#  'canned',
#  'air',
#  'pungent',
#  'odor',
#  'compressor',
#  'oil',
#  'tang',
#  'greenery',
#  'used',
#  'replenish',
#  'oxygen',
#  'unable',
#  'walk',
#  'freely',
#  'dozen',
#  'steps',
#  'unable',
#  'see',
#  'lies',
#  'beyond',
#  'viewports',
#  'occasionally',
#  'eyes',
#  'looked',
#  'along',
#  'low',
#  'southern',
#  'sky',
#  'towards',
#  'alpha',
#  'centauri',
#  'proxima',
#  'course',
#  'could',
#  'resolved',
#  'naked',
#  'eye',
#  'much',
#  'less',
#  'stinking',
#  'little',
#  'overheated',
#  'mote',
#  'rotated',
#  'proxima',
#  'obviously',
#  'unfit',
#  'human',
#  'life',
#  'patently',
#  'incapable',
#  'spawning',
#  'life',
#  'paul',
#  'graysons',
#  'destination',
#  'would',
#  'home',
#  'days',
#  'weeks',
#  'depending',
#  'entirely',
#  'upon',
#  'whether',
#  'things',
#  'went',
#  'good',
#  'bad',
#  'last',
#  'four',
#  'two',
#  'thousand',
#  'millions',
#  'years',
#  'life',
#  'planet',
#  'useful',
#  'man',
#  'needed',
#  'place',
#  'stand',
#  'move',
#  'earth',
#  'archimedess',
#  'lever',
#  'survey',
#  'galaxy',
#  'proxima',
#  'centauri',
#  'planet',
#  'trinary',
#  'bad',
#  'useful',
#  'space',
#  'station',
#  'hour',
#  'paul',
#  'grayson',
#  'would',
#  'locked',
#  'capsule',
#  'metal',
#  'hurling',
#  'space',
#  'towards',
#  'proxima',
#  'looking',
#  'forward',
#  'ten',
#  'days',
#  'cooped',
#  'spacecraft',
#  'type',
#  'furnished',
#  'bureau',
#  'astrogation',
#  'engineers',
#  'far',
#  'cry',
#  'sumptuous',
#  'craft',
#  'run',
#  'big',
#  'brass',
#  'confines',
#  'would',
#  'lined',
#  'functional',
#  'scientific',
#  'equipment',
#  'air',
#  'supply',
#  'would',
#  'medically',
#  'acceptable',
#  'aesthetically',
#  'horrible',
#  'vision',
#  'limited',
#  'cabin',
#  'beyond',
#  'viewports',
#  'would',
#  'formless',
#  'endless',
#  'abysmal',
#  'blackness',
#  'absolutely',
#  'nothing',
#  'ship',
#  'mounted',
#  'multiples',
#  'speed',
#  'light',
#  'days',
#  'building',
#  'filled',
#  'dome',
#  'power',
#  'equipment',
#  'radio',
#  'gear',
#  'timing',
#  'mechanism',
#  'recorders',
#  'refrigerator',
#  'setup',
#  'struggled',
#  'awesome',
#  'heat',
#  'poured',
#  'proxima',
#  'closeby',
#  'luminary',
#  'succeeded',
#  'lowering',
#  'temperature',
#  'point',
#  'potting',
#  'compound',
#  'transformers',
#  'run',
#  'calibrating',
#  'resistors',
#  'would',
#  'change',
#  'values',
#  'recording',
#  'machines',
#  'would',
#  'still',
#  'make',
#  'record',
#  'days',
#  'ship',
#  'returned',
#  'earth',
#  'call',
#  'thirty',
#  'days',
#  'understand',
#  'paul',
#  'grayson',
#  'sauntered',
#  'along',
#  'killing',
#  'time',
#  'fresh',
#  'air',
#  'taking',
#  'paul',
#  'grinned',
#  'four',
#  'years',
#  'ago',
#  'arrived',
#  'full',
#  'hour',
#  'early',
#  'wasted',
#  'hour',
#  'smelly',
#  'ship',
#  'instead',
#  'filling',
#  'lungs',
#  'clean',
#  'fresh',
#  'air',
#  'never',
#  'would',
#  'arrive',
#  'full',
#  'five',
#  'minutes',
#  'checkin',
#  'time',
#  'heard',
#  'radio',
#  'music',
#  'tone',
#  'stripped',
#  'high',
#  'frequencies',
#  'passage',
#  'slit',
#  'partiallyopened',
#  'window',
#  'sniffed',
#  'air',
#  'laughed',
#  'someone',
#  'cooking',
#  'corned',
#  'beef',
#  'cabbage',
#  'range',
#  'radio',
#  'music',
#  'paul',
#  'liked',
#  'music',
#  'hummed',
#  'tune',
#  'walked',
#  'fancy',
#  'struck',
#  'started',
#  'sing',
#  'faint',
#  'singing',
#  'would',
#  'carried',
#  'feet',
#  'sufficed',
#  'paul',
#  'refrain',
#  'early',
#  'atomicage',
#  'ballad',
#  '_round',
#  'round',
#  'round',
#  'go',
#  'deuterons',
#  'round',
#  'round',
#  'magnet',
#  'swings',
#  'round',
#  'round',
#  'round',
#  'go',
#  'deuterons',
#  'smack',
#  'target',
#  'goes',
#  'ion',
#  'beam_',
#  'paul',
#  'stopped',
#  'song',
#  'interesting',
#  'click',
#  'high',
#  'heels',
#  'sidewalk',
#  'pointed',
#  'approach',
#  'someone',
#  'might',
#  'view',
#  '_a',
#  'cappella_',
#  'singing',
#  'indication',
#  'inebriation',
#  'coming',
#  'towards',
#  'walking',
#  'side',
#  'sidewalk',
#  'step',
#  'quick',
#  'lithe',
#  'slight',
#  'breeze',
#  'outlined',
#  'frock',
#  'body',
#  'revealing',
#  'time',
#  'concealing',
#  'enough',
#  'quicken',
#  'pulse',
#  'awaken',
#  'interest',
#  'paul',
#  'thirty',
#  'unmarried',
#  'experienced',
#  'enough',
#  'catalogue',
#  'shrewdly',
#  'crude',
#  'attempt',
#  'pickup',
#  'would',
#  'work',
#  'woman',
#  'sure',
#  'obviously',
#  'could',
#  'want',
#  'admirers',
#  'would',
#  'take',
#  'careful',
#  'strategy',
#  'period',
#  'time',
#  'get',
#  'first',
#  'base',
#  'woman',
#  'like',
#  'inept',
#  'campaigner',
#  'would',
#  'called',
#  'strikes',
#  'paul',
#  'grayson',
#  'way',
#  'centauri',
#  'within',
#  'hour',
#  'automatically',
#  'eliminated',
#  'initial',
#  'step',
#  'plausible',
#  'scheme',
#  'wrangle',
#  'introduction',
#  'paul',
#  'grayson',
#  'grinned',
#  'ruefully',
#  'seemed',
#  'hours',
#  'spend',
#  'nothing',
#  'streets',
#  'barren',
#  'presentable',
#  'women',
#  'interesting',
#  'specimens',
#  'womanhood',
#  'smiled',
#  'offered',
#  'charms',
#  'en',
#  'route',
#  'towards',
#  'schedule',
#  'could',
#  'delayed',
#  'woman',
#  'enough',
#  'make',
#  'man',
#  'forget',
#  'timetablesalmost',
#  'came',
#  'forward',
#  'face',
#  'lighted',
#  'street',
#  'lamp',
#  'paul',
#  'passed',
#  'blueeyed',
#  'fairskinned',
#  'hurried',
#  'route',
#  'collision',
#  'course',
#  'minute',
#  'shake',
#  'head',
#  'neither',
#  'time',
#  'inclination',
#  'attempt',
#  'anything',
#  'crude',
#  'striking',
#  'acquaintance',
#  'barring',
#  'path',
#  'paul',
#  'angled',
#  'course',
#  'aside',
#  'angled',
#  'hello',
#  'said',
#  'brightly',
#  'thought',
#  'youd',
#  'along',
#  'sooner',
#  'paul',
#  'grayson',
#  'gulped',
#  'obviously',
#  'mistook',
#  'someone',
#  'else',
#  'faint',
#  'feeling',
#  'jealousy',
#  'ran',
#  'lucky',
#  'man',
#  'owned',
#  'affections',
#  'street',
#  'lamp',
#  'behind',
#  'must',
#  'cast',
#  'heavy',
#  'shadows',
#  'across',
#  'face',
#  'making',
#  'identification',
#  'difficult',
#  'opened',
#  'mouth',
#  'explain',
#  'away',
#  'mistake',
#  'girl',
#  'came',
#  'hardly',
#  'slackening',
#  'pace',
#  'last',
#  'possible',
#  'moment',
#  'instead',
#  'speaking',
#  'paul',
#  'found',
#  'parted',
#  'mouth',
#  'met',
#  'lips',
#  'warm',
#  'arms',
#  'came',
#  'around',
#  'quick',
#  'embrace',
#  'arms',
#  'instinctively',
#  'closed',
#  'waist',
#  'paul',
#  'kissed',
#  'back',
#  'cheerfully',
#  'accepting',
#  'pleasure',
#  'error',
#  'sort',
#  'devilish',
#  'glee',
#  'stepped',
#  'back',
#  'im',
#  'sorry',
#  'said',
#  'guy',
#  'thought',
#  'looked',
#  'blink',
#  'expression',
#  'changed',
#  'surprise',
#  'mouth',
#  'opened',
#  'scream',
#  'eyes',
#  'flicked',
#  'away',
#  'centered',
#  'left',
#  'shoulder',
#  'paul',
#  'started',
#  'whirl',
#  'someone',
#  'dropped',
#  'north',
#  'pole',
#  'back',
#  'skull',
#  'chilled',
#  'completely',
#  'scream',
#  'rang',
#  'ears',
#  'fell',
#  'forward',
#  'vaguely',
#  'felt',
#  'silk',
#  'dress',
#  'outstretched',
#  'hands',
#  'cheek',
#  'sidewalk',
#  'rose',
#  'grind',
#  'face',
#  'something',
#  'pulled',
#  'coat',
#  'felt',
#  'nothing',
#  'frightened',
#  'scream',
#  'woman',
#  'rang',
#  'ears',
#  'shrill',
#  'angry',
#  'fearful',
#  'never',
#  'ending',
#  'paul',
#  'realized',
#  'siren',
#  'wail',
#  'scream',
#  'ringing',
#  'ears',
#  'girl',
#  'sitting',
#  'asprawl',
#  'sidewalk',
#  'head',
#  'thighs',
#  'rubbing',
#  'nape',
#  'neck',
#  'fingertips',
#  'quietly',
#  'erasing',
#  'pain',
#  'bit',
#  'bit',
#  'threshold',
#  'ringing',
#  'ears',
#  'diminished',
#  'field',
#  'vision',
#  'increased',
#  'darting',
#  'lights',
#  'went',
#  'away',
#  'paul',
#  'grayson',
#  'could',
#  'hear',
#  'sound',
#  'running',
#  'feet',
#  'babble',
#  'voices',
#  'happened',
#  'man',
#  'clipped',
#  'thug',
#  'saw',
#  'came',
#  'voices',
#  'mad',
#  'garble',
#  'scrambled',
#  'speeches',
#  'right',
#  'front',
#  'eyes',
#  'babble',
#  'broke',
#  'many',
#  'varied',
#  'subjects',
#  'curiosity',
#  'morbid',
#  'samaritan',
#  'anger',
#  'righteous',
#  'superficial',
#  'directed',
#  'things',
#  'make',
#  'happenings',
#  'possible',
#  'suggestions',
#  'sensible',
#  'absurd',
#  'offers',
#  'welcome',
#  'ridiculous',
#  'paul',
#  'groaned',
#  'tried',
#  'lift',
#  'hand',
#  'raw',
#  'spot',
#  'chin',
#  'sidewalk',
#  'removed',
#  'hide',
#  'woman',
#  'looked',
#  'smiled',
#  'wan',
#  'apprehensive',
#  'manner',
#  'youre',
#  'right',
#  'paul',
#  'struggled',
#  'sit',
#  'made',
#  'help',
#  'wave',
#  'pain',
#  'rose',
#  'localized',
#  'head',
#  'forty',
#  'degrees',
#  'right',
#  'latitude',
#  'made',
#  'want',
#  'carry',
#  'head',
#  'angle',
#  'neck',
#  'ducked',
#  'level',
#  'knot',
#  'pain',
#  'hands',
#  'helped',
#  'feet',
#  'led',
#  'across',
#  'sidewalk',
#  'became',
#  'stronger',
#  'moment',
#  'shook',
#  'head',
#  'clear',
#  'winced',
#  'motion',
#  'caused',
#  'knot',
#  'pain',
#  'vibrate',
#  'nastily',
#  'happened',
#  'asked',
#  'quavering',
#  'voice',
#  'sounded',
#  'like',
#  'someone',
#  'elses',
#  'voice',
#  'surprised',
#  'sound',
#  'repeated',
#  'question',
#  'still',
#  'sounded',
#  'like',
#  'someone',
#  'elses',
#  'voice',
#  'wondering',
#  'voice',
#  'would',
#  'sound',
#  'like',
#  'rest',
#  'life',
#  'girl',
#  'explained',
#  'happened',
#  'paul',
#  'missed',
#  'asked',
#  'another',
#  'question',
#  'see',
#  'said',
#  'voice',
#  'regretful',
#  'yet',
#  'tinted',
#  'dash',
#  'amusement',
#  'sort',
#  'rose',
#  'shadow',
#  'behind',
#  'youyoure',
#  'tall',
#  'man',
#  'know',
#  'saw',
#  'ragged',
#  'silhouette',
#  'hit',
#  'fell',
#  'screamed',
#  'grabbed',
#  'wallet',
#  'voice',
#  'trailed',
#  'away',
#  'unhappily',
#  'paul',
#  'smiled',
#  'nothing',
#  'personal',
#  'papers',
#  'replaceable',
#  'dollars',
#  'id',
#  'handed',
#  'rather',
#  'get',
#  'clip',
#  'skull',
#  'bad',
#  'couldnt',
#  'see',
#  'touch',
#  'amusement',
#  'came',
#  'eyes',
#  'closed',
#  'sort',
#  'paul',
#  'smiled',
#  'inwardly',
#  'welcoming',
#  'footpad',
#  'contents',
#  'wallet',
#  'accepting',
#  'bop',
#  'bean',
#  'price',
#  'pay',
#  'introduction',
#  'girl',
#  'someone',
#  'crowd',
#  'said',
#  'youd',
#  'better',
#  'come',
#  'inside',
#  'feel',
#  'right',
#  'paul',
#  'shook',
#  'head',
#  'happy',
#  'find',
#  'knot',
#  'inside',
#  'diminished',
#  'faint',
#  'pinpoint',
#  'voice',
#  'sounding',
#  'like',
#  'ive',
#  'got',
#  'go',
#  'said',
#  'wail',
#  'sirens',
#  'came',
#  'police',
#  'car',
#  'dashed',
#  'curb',
#  'spilled',
#  'policemen',
#  'doors',
#  'came',
#  'warily',
#  'whats',
#  'going',
#  'demanded',
#  'sergeant',
#  'paul',
#  'explained',
#  'youd',
#  'better',
#  'come',
#  'station',
#  'lodge',
#  'complaint',
#  'paul',
#  'shook',
#  'head',
#  'im',
#  'paul',
#  'grayson',
#  'bureau',
#  'astrogation',
#  'said',
#  'could',
#  'prove',
#  'crook',
#  'identification',
#  'papers',
#  'im',
#  'due',
#  'take',
#  'space',
#  'within',
#  'paul',
#  'looked',
#  ...]

# %% [markdown]
# ## Function to calculate frequency of the tokens

# %%
def freq(tokens):
# frequency of tokens
    freq = {}
    for t in tokens:
        if t in freq:
            freq[t]+=1
        else:
            freq[t]=1
    return freq

# %%
mapped_freq=freq(cleaned_text)

# %% [markdown]
# ## Tokens mapped to their frequencies

# %%
mapped_freq
# Out:
# {'operation': 5,
#  'interstellar': 20,
#  'produced': 2,
#  'greg': 1,
#  'weeks': 12,
#  'mary': 1,
#  'meehan': 1,
#  'online': 1,
#  'distributed': 2,
#  'proofreading': 1,
#  'team': 1,
#  'httpwwwpgdpnet': 1,
#  '_by_': 1,
#  'george': 1,
#  'smith': 2,
#  'century': 4,
#  'publications': 2,
#  'chicago': 2,
#  'published': 1,
#  'clark': 1,
#  'st': 1,
#  'ill': 42,
#  '_printed': 1,
#  'united': 2,
#  'states': 3,
#  'america_': 1,
#  'characters': 5,
#  'situations': 1,
#  'book': 3,
#  'fictional': 1,
#  'similarity': 1,
#  'actual': 2,
#  'persons': 1,
#  'places': 3,
#  'purely': 1,
#  'coincidental': 1,
#  'permission': 2,
#  'use': 20,
#  'refrains': 1,
#  'ballad': 2,
#  'cyclotronists': 2,
#  'nightmare': 2,
#  'arthur': 1,
#  'roberts': 1,
#  'state': 14,
#  'university': 1,
#  'iowa': 1,
#  'graciously': 3,
#  'granted': 1,
#  'hereby': 1,
#  'acknowledged': 1,
#  'sincere': 1,
#  'appreciation': 1,
#  'cover': 3,
#  'malcolm': 1,
#  '_copyright': 1,
#  'publications_': 1,
#  'transcribers': 1,
#  'note': 3,
#  'extensive': 2,
#  'research': 7,
#  'uncover': 1,
#  'evidence': 39,
#  'us': 16,
#  'copyright': 1,
#  'publication': 1,
#  'renewed': 1,
#  'grayson': 157,
#  'walked': 3,
#  'city': 5,
#  'street': 19,
#  'slowly': 9,
#  'sauntering': 2,
#  'towards': 35,
#  'spaceport': 21,
#  'hurry': 4,
#  'allowed': 1,
#  'plenty': 9,
#  'time': 132,
#  'breathe': 1,
#  'fresh': 5,
#  'spring': 3,
#  'air': 40,
#  'listen': 6,
#  'myriad': 5,
#  'sounds': 3,
#  'made': 75,
#  'fellow': 2,
#  'men': 58,
#  'revel': 1,
#  'grand': 6,
#  'freedom': 6,
#  'open': 11,
#  'gave': 14,
#  'soon': 18,
#  'enough': 55,
#  'would': 194,
#  'breathing': 3,
#  'canned': 2,
#  'pungent': 1,
#  'odor': 2,
#  'compressor': 2,
#  'oil': 1,
#  'tang': 1,
#  'greenery': 3,
#  'used': 28,
#  'replenish': 1,
#  'oxygen': 1,
#  'unable': 4,
#  'walk': 9,
#  'freely': 2,
#  'dozen': 3,
#  'steps': 3,
#  'see': 49,
#  'lies': 4,
#  'beyond': 13,
#  'viewports': 3,
#  'occasionally': 4,
#  'eyes': 21,
#  'looked': 77,
#  'along': 30,
#  'low': 6,
#  'southern': 2,
#  'sky': 11,
#  'alpha': 49,
#  'centauri': 24,
#  'proxima': 69,
#  'course': 49,
#  'could': 141,
#  'resolved': 2,
#  'naked': 4,
#  'eye': 27,
#  'much': 25,
#  'less': 26,
#  'stinking': 1,
#  'little': 27,
#  'overheated': 1,
#  'mote': 2,
#  'rotated': 1,
#  'obviously': 13,
#  'unfit': 1,
#  'human': 8,
#  'life': 35,
#  'patently': 3,
#  'incapable': 2,
#  'spawning': 1,
#  'paul': 604,
#  'graysons': 36,
#  'destination': 2,
#  'home': 23,
#  'days': 29,
#  'depending': 3,
#  'entirely': 7,
#  'upon': 43,
#  'whether': 26,
#  'things': 15,
#  'went': 78,
#  'good': 39,
#  'bad': 12,
#  'last': 32,
#  'four': 39,
#  'two': 62,
#  'thousand': 15,
#  'millions': 4,
#  'years': 77,
#  'planet': 48,
#  'useful': 3,
#  'man': 128,
#  'needed': 6,
#  'place': 29,
#  'stand': 9,
#  'move': 8,
#  'earth': 15,
#  'archimedess': 1,
#  'lever': 4,
#  'survey': 25,
#  'galaxy': 24,
#  'trinary': 3,
#  'space': 104,
#  'station': 81,
#  'hour': 21,
#  'locked': 5,
#  'capsule': 2,
#  'metal': 9,
#  'hurling': 2,
#  'looking': 10,
#  'forward': 17,
#  'ten': 34,
#  'cooped': 2,
#  'spacecraft': 69,
#  'type': 9,
#  'furnished': 4,
#  'bureau': 12,
#  'astrogation': 10,
#  'engineers': 1,
#  'far': 48,
#  'cry': 7,
#  'sumptuous': 1,
#  'craft': 6,
#  'run': 30,
#  'big': 21,
#  'brass': 1,
#  'confines': 1,
#  'lined': 3,
#  'functional': 3,
#  'scientific': 5,
#  'equipment': 25,
#  'supply': 4,
#  'medically': 1,
#  'acceptable': 2,
#  'aesthetically': 1,
#  'horrible': 2,
#  'vision': 2,
#  'limited': 4,
#  'cabin': 1,
#  'formless': 1,
#  'endless': 1,
#  'abysmal': 1,
#  'blackness': 4,
#  'absolutely': 5,
#  'nothing': 42,
#  'ship': 120,
#  'mounted': 1,
#  'multiples': 1,
#  'speed': 12,
#  'light': 81,
#  'building': 9,
#  'filled': 12,
#  'dome': 9,
#  'power': 11,
#  'radio': 96,
#  'gear': 17,
#  'timing': 20,
#  'mechanism': 2,
#  'recorders': 2,
#  'refrigerator': 1,
#  'setup': 4,
#  'struggled': 4,
#  'awesome': 3,
#  'heat': 1,
#  'poured': 1,
#  'closeby': 2,
#  'luminary': 1,
#  'succeeded': 2,
#  'lowering': 1,
#  'temperature': 1,
#  'point': 39,
#  'potting': 1,
#  'compound': 1,
#  'transformers': 1,
#  'calibrating': 1,
#  'resistors': 1,
#  'change': 4,
#  'values': 1,
#  'recording': 21,
#  'machines': 1,
#  'still': 36,
#  'make': 68,
#  'record': 6,
#  'returned': 11,
#  'call': 28,
#  'thirty': 4,
#  'understand': 17,
#  'sauntered': 2,
#  'killing': 2,
#  'taking': 10,
#  'grinned': 5,
#  'ago': 28,
#  'arrived': 10,
#  'full': 12,
#  'early': 8,
#  'wasted': 3,
#  'smelly': 1,
#  'instead': 23,
#  'filling': 2,
#  'lungs': 1,
#  'clean': 4,
#  'never': 19,
#  'arrive': 4,
#  'five': 23,
#  'minutes': 28,
#  'checkin': 1,
#  'heard': 17,
#  'music': 5,
#  'tone': 9,
#  'stripped': 1,
#  'high': 27,
#  'frequencies': 5,
#  'passage': 2,
#  'slit': 2,
#  'partiallyopened': 1,
#  'window': 5,
#  'sniffed': 2,
#  'laughed': 23,
#  'someone': 47,
#  'cooking': 1,
#  'corned': 1,
#  'beef': 1,
#  'cabbage': 1,
#  'range': 3,
#  'liked': 4,
#  'hummed': 1,
#  'tune': 4,
#  'fancy': 3,
#  'struck': 3,
#  'started': 37,
#  'sing': 2,
#  'faint': 7,
#  'singing': 2,
#  'carried': 6,
#  'feet': 16,
#  'sufficed': 1,
#  'refrain': 1,
#  'atomicage': 1,
#  '_round': 4,
#  'round': 32,
#  'go': 72,
#  'deuterons': 6,
#  'magnet': 4,
#  'swings': 4,
#  'smack': 4,
#  'target': 8,
#  'goes': 5,
#  'ion': 1,
#  'beam_': 1,
#  'stopped': 14,
#  'song': 3,
#  'interesting': 4,
#  'click': 2,
#  'heels': 1,
#  'sidewalk': 9,
#  'pointed': 3,
#  'approach': 2,
#  'might': 61,
#  'view': 6,
#  '_a': 1,
#  'cappella_': 1,
#  'indication': 3,
#  'inebriation': 1,
#  'coming': 9,
#  'walking': 5,
#  'side': 35,
#  'step': 8,
#  'quick': 16,
#  'lithe': 3,
#  'slight': 6,
#  'breeze': 1,
#  'outlined': 1,
#  'frock': 1,
#  'body': 12,
#  'revealing': 1,
#  'concealing': 1,
#  'quicken': 1,
#  'pulse': 1,
#  'awaken': 2,
#  'interest': 12,
#  'unmarried': 1,
#  'experienced': 4,
#  'catalogue': 1,
#  'shrewdly': 1,
#  'crude': 9,
#  'attempt': 16,
#  'pickup': 1,
#  'work': 46,
#  'woman': 31,
#  'sure': 19,
#  'want': 37,
#  'admirers': 1,
#  'take': 53,
#  'careful': 3,
#  'strategy': 1,
#  'period': 6,
#  'get': 85,
#  'first': 69,
#  'base': 4,
#  'like': 84,
#  'inept': 1,
#  'campaigner': 1,
#  'called': 18,
#  'strikes': 1,
#  'way': 61,
#  'within': 10,
#  'automatically': 3,
#  'eliminated': 2,
#  'initial': 5,
#  'plausible': 3,
#  'scheme': 1,
#  'wrangle': 2,
#  'introduction': 2,
#  'ruefully': 6,
#  'seemed': 12,
#  'hours': 42,
#  'spend': 1,
#  'streets': 2,
#  'barren': 1,
#  'presentable': 1,
#  'women': 4,
#  'specimens': 1,
#  'womanhood': 1,
#  'smiled': 49,
#  'offered': 3,
#  'charms': 1,
#  'en': 2,
#  'route': 4,
#  'schedule': 2,
#  'delayed': 5,
#  'forget': 9,
#  'timetablesalmost': 1,
#  'came': 113,
#  'face': 38,
#  'lighted': 1,
#  'lamp': 2,
#  'passed': 19,
#  'blueeyed': 1,
#  'fairskinned': 1,
#  'hurried': 2,
#  'collision': 2,
#  'minute': 14,
#  'shake': 3,
#  'head': 64,
#  'neither': 6,
#  'inclination': 1,
#  'anything': 24,
#  'striking': 1,
#  'acquaintance': 3,
#  'barring': 1,
#  'path': 2,
#  'angled': 2,
#  'aside': 14,
#  'hello': 4,
#  'said': 198,
#  'brightly': 2,
#  'thought': 29,
#  'youd': 9,
#  'sooner': 2,
#  'gulped': 7,
#  'mistook': 1,
#  'else': 16,
#  'feeling': 8,
#  'jealousy': 2,
#  'ran': 9,
#  'lucky': 3,
#  'owned': 3,
#  'affections': 1,
#  'behind': 24,
#  'must': 40,
#  'cast': 2,
#  'heavy': 9,
#  'shadows': 2,
#  'across': 61,
#  'making': 19,
#  'identification': 19,
#  'difficult': 2,
#  'opened': 12,
#  'mouth': 7,
#  'explain': 16,
#  'away': 60,
#  'mistake': 2,
#  'girl': 10,
#  'hardly': 6,
#  'slackening': 1,
#  'pace': 1,
#  'possible': 16,
#  'moment': 36,
#  'speaking': 6,
#  'found': 35,
#  'parted': 1,
#  'met': 14,
#  'lips': 7,
#  'warm': 7,
#  'arms': 10,
#  'around': 43,
#  'embrace': 1,
#  'instinctively': 1,
#  'closed': 15,
#  'waist': 7,
#  'kissed': 6,
#  'back': 75,
#  'cheerfully': 2,
#  'accepting': 3,
#  'pleasure': 4,
#  'error': 26,
#  'sort': 28,
#  'devilish': 1,
#  'glee': 2,
#  'stepped': 5,
#  'im': 53,
#  'sorry': 3,
#  'guy': 25,
#  'blink': 2,
#  'expression': 4,
#  'changed': 6,
#  'surprise': 2,
#  'scream': 6,
#  'flicked': 1,
#  'centered': 2,
#  'left': 32,
#  'shoulder': 8,
#  'whirl': 1,
#  'dropped': 15,
#  'north': 1,
#  'pole': 2,
#  'skull': 8,
#  'chilled': 3,
#  'completely': 24,
#  'rang': 7,
#  'ears': 6,
#  'fell': 13,
#  'vaguely': 5,
#  'felt': 15,
#  'silk': 2,
#  'dress': 5,
#  'outstretched': 1,
#  'hands': 24,
#  'cheek': 5,
#  'rose': 8,
#  'grind': 1,
#  'something': 45,
#  'pulled': 5,
#  'coat': 1,
#  'frightened': 3,
#  'shrill': 3,
#  'angry': 5,
#  'fearful': 1,
#  'ending': 4,
#  'realized': 9,
#  'siren': 7,
#  'wail': 3,
#  'ringing': 7,
#  'sitting': 8,
#  'asprawl': 2,
#  'thighs': 1,
#  'rubbing': 1,
#  'nape': 1,
#  'neck': 3,
#  'fingertips': 3,
#  'quietly': 14,
#  'erasing': 1,
#  'pain': 5,
#  'bit': 43,
#  'threshold': 1,
#  'diminished': 7,
#  'field': 2,
#  'increased': 2,
#  'darting': 1,
#  'lights': 7,
#  'hear': 21,
#  'sound': 14,
#  'running': 30,
#  'babble': 2,
#  'voices': 3,
#  'happened': 19,
#  'clipped': 12,
#  'thug': 1,
#  'saw': 9,
#  'mad': 14,
#  'garble': 1,
#  'scrambled': 2,
#  'speeches': 2,
#  'right': 42,
#  'front': 11,
#  'broke': 10,
#  'many': 27,
#  'varied': 1,
#  'subjects': 1,
#  'curiosity': 4,
#  'morbid': 1,
#  'samaritan': 1,
#  'anger': 4,
#  'righteous': 1,
#  'superficial': 2,
#  'directed': 5,
#  'happenings': 1,
#  'suggestions': 1,
#  'sensible': 3,
#  'absurd': 1,
#  'offers': 3,
#  'welcome': 1,
#  'ridiculous': 4,
#  'groaned': 8,
#  'tried': 34,
#  'lift': 1,
#  'hand': 38,
#  'raw': 1,
#  'spot': 7,
#  'chin': 3,
#  'removed': 5,
#  'hide': 1,
#  'wan': 1,
#  'apprehensive': 1,
#  'manner': 5,
#  'youre': 29,
#  'sit': 7,
#  'help': 10,
#  'wave': 15,
#  'localized': 2,
#  'forty': 9,
#  'degrees': 2,
#  'latitude': 5,
#  'carry': 6,
#  'angle': 14,
#  'ducked': 1,
#  'level': 6,
#  'knot': 4,
#  'helped': 3,
#  'led': 8,
#  'became': 8,
#  'stronger': 1,
#  'shook': 28,
#  'clear': 7,
#  'winced': 1,
#  'motion': 5,
#  'caused': 11,
#  'vibrate': 1,
#  'nastily': 1,
#  'asked': 34,
#  'quavering': 2,
#  'voice': 60,
#  'sounded': 5,
#  'elses': 2,
#  'surprised': 3,
#  'repeated': 2,
#  'question': 14,
#  'wondering': 7,
#  'rest': 17,
#  'explained': 12,
#  'missed': 11,
#  'another': 59,
#  'regretful': 1,
#  'yet': 19,
#  'tinted': 1,
#  'dash': 1,
#  'amusement': 2,
#  'shadow': 2,
#  'youyoure': 1,
#  'tall': 5,
#  'know': 101,
#  'ragged': 3,
#  'silhouette': 1,
#  'hit': 20,
#  'screamed': 3,
#  'grabbed': 5,
#  'wallet': 9,
#  'trailed': 5,
#  'unhappily': 10,
#  'personal': 14,
#  'papers': 6,
#  'replaceable': 1,
#  'dollars': 3,
#  'id': 26,
#  'handed': 6,
#  'rather': 9,
#  'clip': 4,
#  'couldnt': 9,
#  'touch': 7,
#  'inwardly': 1,
#  'welcoming': 1,
#  'footpad': 5,
#  'contents': 1,
#  'bop': 1,
#  'bean': 2,
#  'price': 1,
#  'pay': 3,
#  'crowd': 4,
#  'better': 21,
#  'come': 40,
#  'inside': 6,
#  'feel': 5,
#  'happy': 9,
#  'find': 32,
#  'pinpoint': 1,
#  'sounding': 1,
#  'ive': 48,
#  'got': 62,
#  'sirens': 1,
#  'police': 29,
#  'car': 42,
#  'dashed': 2,
#  'curb': 3,
#  'spilled': 1,
#  'policemen': 3,
#  'doors': 4,
#  'warily': 2,
#  'whats': 12,
#  'going': 46,
#  'demanded': 11,
#  'sergeant': 29,
#  'lodge': 1,
#  'complaint': 3,
#  'prove': 6,
#  'crook': 8,
#  'due': 6,
#  'watchwithin': 1,
#  'finished': 8,
#  'well': 70,
#  'require': 3,
#  'cant': 13,
#  'pleaded': 1,
#  'lord': 2,
#  'identify': 5,
#  'criminal': 7,
#  'hell': 23,
#  'contact': 35,
#  'hitting': 3,
#  'blackjack': 1,
#  'blurred': 1,
#  'wearing': 1,
#  'dark': 11,
#  'clothingwhich': 1,
#  'easily': 7,
#  'spoke': 3,
#  'main': 11,
#  'office': 17,
#  'lieutenant': 1,
#  'says': 2,
#  'depositions': 1,
#  'thatll': 2,
#  'save': 8,
#  'dope': 2,
#  'records': 4,
#  'miss': 15,
#  'nora': 156,
#  'phillips': 61,
#  'one': 234,
#  'keep': 22,
#  'passing': 1,
#  'hes': 9,
#  'overdue': 1,
#  'tommy': 2,
#  'morgan': 3,
#  'date': 5,
#  'meet': 6,
#  'tell': 35,
#  'return': 9,
#  'matter': 19,
#  'taken': 12,
#  'care': 8,
#  'toby': 19,
#  'ask': 9,
#  'everybody': 8,
#  'comes': 7,
#  'mr': 3,
#  'ride': 1,
#  'official': 13,
#  'information': 14,
#  'strictly': 4,
#  'waste': 3,
#  'mental': 3,
#  'address': 7,
#  'telephone': 21,
#  'number': 20,
#  'decided': 6,
#  'incident': 1,
#  'reason': 24,
#  'renew': 1,
#  'easy': 9,
#  'telling': 6,
#  'trip': 6,
#  'formal': 1,
#  'youll': 19,
#  'glad': 9,
#  'told': 11,
#  'turned': 40,
#  'nodded': 24,
#  'useless': 7,
#  'measure': 8,
#  'distance': 36,
#  'accuracy': 1,
#  'heliocentric': 1,
#  'parallax': 1,
#  'permit': 7,
#  'fine': 21,
#  'decimal': 2,
#  'even': 40,
#  'finer': 2,
#  'degree': 4,
#  'beam': 30,
#  'arriving': 3,
#  'nottoolong': 1,
#  'nice': 7,
#  'detail': 3,
#  'perfection': 7,
#  'suppose': 10,
#  'ultimately': 2,
#  'aiming': 13,
#  'neosol': 43,
#  'suggested': 10,
#  'thats': 28,
#  'idea': 47,
#  'hundred': 29,
#  'fortythree': 1,
#  'count': 3,
#  'corrected': 1,
#  'three': 36,
#  'seven': 12,
#  'greatest': 2,
#  'separates': 1,
#  'stars': 29,
#  'weve': 15,
#  'network': 20,
#  'beams': 6,
#  'crisscrossing': 1,
#  'pathway': 1,
#  'oh': 9,
#  'admitted': 3,
#  'smile': 11,
#  'triangulation': 4,
#  'theyre': 6,
#  'mostly': 2,
#  'checkbeams': 2,
#  'final': 15,
#  'neoterra': 54,
#  'meantime': 3,
#  'refine': 2,
#  'charts': 2,
#  'using': 6,
#  'start': 16,
#  'gets': 8,
#  'able': 20,
#  'theres': 12,
#  'sense': 4,
#  'waiting': 15,
#  'half': 15,
#  'certain': 22,
#  'fly': 3,
#  'bump': 2,
#  'let': 41,
#  'job': 31,
#  'quickly': 7,
#  'died': 14,
#  'others': 9,
#  'trained': 5,
#  'case': 15,
#  'insistence': 1,
#  'vigorous': 3,
#  'reasons': 11,
#  'lame': 1,
#  'important': 11,
#  'person': 4,
#  'haedaecker': 109,
#  'wind': 3,
#  'excuse': 2,
#  'arent': 2,
#  'outside': 14,
#  'solar': 13,
#  'system': 18,
#  'zwave': 175,
#  'cross': 12,
#  'statement': 4,
#  'thrown': 2,
#  'display': 3,
#  'knowledge': 5,
#  'technician': 5,
#  'also': 11,
#  'leader': 1,
#  'conversation': 11,
#  'bite': 1,
#  'haedaeckers': 35,
#  'theory': 52,
#  'added': 11,
#  'isnt': 13,
#  'silence': 4,
#  'propagates': 1,
#  'region': 4,
#  'influence': 1,
#  'activity': 2,
#  'moments': 1,
#  'talked': 3,
#  'volubly': 1,
#  'fill': 5,
#  'without': 29,
#  'questioning': 1,
#  'support': 1,
#  'missing': 4,
#  'plain': 15,
#  'nose': 13,
#  'talk': 11,
#  'ease': 2,
#  'zero': 3,
#  'laboratory': 8,
#  'pluto': 8,
#  'lab': 1,
#  'mercury': 1,
#  'boys': 8,
#  'working': 15,
#  'poisonous': 1,
#  'atmosphere': 7,
#  'jupiter': 1,
#  'extraterran': 2,
#  'paleontologists': 1,
#  'combing': 1,
#  'venus': 7,
#  'radiation': 2,
#  'sent': 7,
#  'gang': 12,
#  'try': 26,
#  'planets': 14,
#  'sirius': 1,
#  'fiddling': 2,
#  'tuning': 2,
#  'whisper': 3,
#  'sol': 37,
#  'via': 6,
#  'thinking': 14,
#  'experiment': 7,
#  'anybody': 9,
#  'interrupt': 2,
#  'velocity': 19,
#  'long': 56,
#  'fair': 1,
#  'radius': 1,
#  'ways': 2,
#  'superdrive': 12,
#  'raced': 14,
#  'orbit': 5,
#  'quite': 22,
#  'lost': 11,
#  'measurements': 2,
#  'unsuccessful': 1,
#  'speech': 6,
#  'lie': 6,
#  'times': 6,
#  'andi': 1,
#  'think': 30,
#  'monththe': 1,
#  'dies': 1,
#  'abruptly': 2,
#  'falls': 1,
#  'cliff': 2,
#  'apparent': 2,
#  'attenuation': 1,
#  'strong': 5,
#  'signal': 31,
#  'peculiar': 1,
#  'thing': 44,
#  'driver': 9,
#  'brought': 11,
#  'screeching': 1,
#  'halt': 3,
#  'folks': 3,
#  'chirped': 1,
#  'pointedly': 2,
#  'amiably': 1,
#  'inner': 7,
#  '_so': 1,
#  'baby_': 1,
#  'uturned': 1,
#  'broad': 8,
#  'roadway': 1,
#  'headed': 6,
#  'pick': 12,
#  'officer': 4,
#  'set': 44,
#  'sentry': 1,
#  'duty': 4,
#  'waved': 4,
#  'pavement': 1,
#  'administration': 2,
#  'everything': 22,
#  'pleased': 5,
#  'vastly': 2,
#  'gone': 20,
#  'delectable': 2,
#  'armful': 2,
#  'femininity': 1,
#  'chauffeured': 1,
#  'none': 13,
#  'department': 8,
#  'complete': 32,
#  'planned': 2,
#  'retort': 2,
#  'perfect': 4,
#  'anticipating': 1,
#  'humorous': 1,
#  'sarcasm': 1,
#  'mode': 1,
#  'arrival': 21,
#  'hoped': 8,
#  'crush': 1,
#  'verbal': 3,
#  'volley': 1,
#  'unanswerable': 1,
#  'repartee': 1,
#  'usually': 3,
#  'pauls': 49,
#  'fount': 1,
#  'boundless': 1,
#  'wit': 3,
#  'trifle': 2,
#  'slow': 4,
#  'following': 12,
#  'definition': 1,
#  'bon': 1,
#  'mot': 1,
#  'prepared': 8,
#  'swung': 5,
#  'door': 39,
#  'airily': 1,
#  'strode': 5,
#  'tongue': 4,
#  ...}

# %% [markdown]
# ## Function to make the frequency graph

# %%
def freq_graph(tokens):
#frequency graph
    FreqDist(tokens)
    all_fdist = FreqDist(tokens).most_common(60)

    all_fdist = pd.Series(dict(all_fdist))

    fig, ax = plt.subplots(figsize=(10,10))

    all_plot = sns.barplot(x=all_fdist.index, y=all_fdist.values, ax=ax)
    plt.xticks(rotation=90)

# %%
freq_graph(cleaned_text)

# %% [markdown]
# ## Creating the WordCloud

# %%
cloud=WordCloud()
wordCloud=cloud.generate_from_frequencies(mapped_freq)
plt.imshow(wordCloud)
plt.figure(figsize=(20,35))
plt.show()

# %% [markdown]
# ## Pos Tagging the cleaned text

# %%
posTagged=nltk.pos_tag(cleaned_text)

# %%
posTagged
# Out:
# [('operation', 'NN'),
#  ('interstellar', 'NN'),
#  ('produced', 'VBD'),
#  ('greg', 'JJ'),
#  ('weeks', 'NNS'),
#  ('mary', 'JJ'),
#  ('meehan', 'NNS'),
#  ('online', 'VBP'),
#  ('distributed', 'VBN'),
#  ('proofreading', 'VBG'),
#  ('team', 'NN'),
#  ('httpwwwpgdpnet', 'NN'),
#  ('operation', 'NN'),
#  ('interstellar', 'JJ'),
#  ('_by_', 'NNP'),
#  ('george', 'NN'),
#  ('smith', 'JJ'),
#  ('century', 'NN'),
#  ('publications', 'NNS'),
#  ('chicago', 'VBP'),
#  ('published', 'JJ'),
#  ('century', 'NN'),
#  ('publications', 'NNS'),
#  ('clark', 'VBP'),
#  ('st', 'JJ'),
#  ('chicago', 'NN'),
#  ('ill', 'NN'),
#  ('_printed', 'VBD'),
#  ('united', 'JJ'),
#  ('states', 'NNS'),
#  ('america_', 'VBP'),
#  ('characters', 'NNS'),
#  ('situations', 'NNS'),
#  ('book', 'NN'),
#  ('fictional', 'JJ'),
#  ('similarity', 'NN'),
#  ('actual', 'JJ'),
#  ('persons', 'NNS'),
#  ('places', 'NNS'),
#  ('purely', 'RB'),
#  ('coincidental', 'JJ'),
#  ('permission', 'NN'),
#  ('use', 'NN'),
#  ('refrains', 'VBZ'),
#  ('ballad', 'JJ'),
#  ('cyclotronists', 'NNS'),
#  ('nightmare', 'VBP'),
#  ('arthur', 'JJ'),
#  ('roberts', 'NNS'),
#  ('state', 'NN'),
#  ('university', 'NN'),
#  ('iowa', 'NN'),
#  ('graciously', 'RB'),
#  ('granted', 'VBN'),
#  ('hereby', 'RB'),
#  ('acknowledged', 'VBN'),
#  ('sincere', 'JJ'),
#  ('appreciation', 'NN'),
#  ('cover', 'NN'),
#  ('malcolm', 'NN'),
#  ('smith', 'JJ'),
#  ('_copyright', 'JJ'),
#  ('century', 'NN'),
#  ('publications_', 'NN'),
#  ('transcribers', 'NNS'),
#  ('note', 'VBP'),
#  ('extensive', 'JJ'),
#  ('research', 'NN'),
#  ('uncover', 'NN'),
#  ('evidence', 'NN'),
#  ('us', 'PRP'),
#  ('copyright', 'JJ'),
#  ('publication', 'NN'),
#  ('renewed', 'VBN'),
#  ('grayson', 'JJ'),
#  ('walked', 'VBD'),
#  ('city', 'NN'),
#  ('street', 'NN'),
#  ('slowly', 'RB'),
#  ('sauntering', 'JJ'),
#  ('towards', 'NNS'),
#  ('spaceport', 'NN'),
#  ('hurry', 'NN'),
#  ('allowed', 'VBD'),
#  ('plenty', 'JJ'),
#  ('time', 'NN'),
#  ('breathe', 'NN'),
#  ('fresh', 'JJ'),
#  ('spring', 'NN'),
#  ('air', 'NN'),
#  ('listen', 'JJ'),
#  ('myriad', 'NN'),
#  ('sounds', 'NNS'),
#  ('made', 'VBD'),
#  ('fellow', 'JJ'),
#  ('men', 'NNS'),
#  ('revel', 'VBP'),
#  ('grand', 'JJ'),
#  ('freedom', 'NN'),
#  ('open', 'JJ'),
#  ('gave', 'VBD'),
#  ('soon', 'RB'),
#  ('enough', 'RB'),
#  ('would', 'MD'),
#  ('breathing', 'VB'),
#  ('canned', 'JJ'),
#  ('air', 'NN'),
#  ('pungent', 'JJ'),
#  ('odor', 'NN'),
#  ('compressor', 'NN'),
#  ('oil', 'NN'),
#  ('tang', 'NN'),
#  ('greenery', 'NN'),
#  ('used', 'VBN'),
#  ('replenish', 'JJ'),
#  ('oxygen', 'NN'),
#  ('unable', 'JJ'),
#  ('walk', 'NN'),
#  ('freely', 'RB'),
#  ('dozen', 'NN'),
#  ('steps', 'NNS'),
#  ('unable', 'JJ'),
#  ('see', 'VBP'),
#  ('lies', 'VBZ'),
#  ('beyond', 'IN'),
#  ('viewports', 'NNS'),
#  ('occasionally', 'RB'),
#  ('eyes', 'NNS'),
#  ('looked', 'VBD'),
#  ('along', 'RB'),
#  ('low', 'JJ'),
#  ('southern', 'JJ'),
#  ('sky', 'NN'),
#  ('towards', 'NNS'),
#  ('alpha', 'VBP'),
#  ('centauri', 'JJ'),
#  ('proxima', 'NN'),
#  ('course', 'NN'),
#  ('could', 'MD'),
#  ('resolved', 'VB'),
#  ('naked', 'JJ'),
#  ('eye', 'NN'),
#  ('much', 'RB'),
#  ('less', 'RBR'),
#  ('stinking', 'JJ'),
#  ('little', 'JJ'),
#  ('overheated', 'JJ'),
#  ('mote', 'NN'),
#  ('rotated', 'VBD'),
#  ('proxima', 'JJ'),
#  ('obviously', 'RB'),
#  ('unfit', 'JJ'),
#  ('human', 'JJ'),
#  ('life', 'NN'),
#  ('patently', 'RB'),
#  ('incapable', 'JJ'),
#  ('spawning', 'VBG'),
#  ('life', 'NN'),
#  ('paul', 'NN'),
#  ('graysons', 'NNS'),
#  ('destination', 'NN'),
#  ('would', 'MD'),
#  ('home', 'VB'),
#  ('days', 'NNS'),
#  ('weeks', 'NNS'),
#  ('depending', 'VBG'),
#  ('entirely', 'RB'),
#  ('upon', 'IN'),
#  ('whether', 'IN'),
#  ('things', 'NNS'),
#  ('went', 'VBD'),
#  ('good', 'JJ'),
#  ('bad', 'JJ'),
#  ('last', 'JJ'),
#  ('four', 'CD'),
#  ('two', 'CD'),
#  ('thousand', 'NN'),
#  ('millions', 'NNS'),
#  ('years', 'NNS'),
#  ('life', 'NN'),
#  ('planet', 'NN'),
#  ('useful', 'JJ'),
#  ('man', 'NN'),
#  ('needed', 'VBD'),
#  ('place', 'NN'),
#  ('stand', 'NN'),
#  ('move', 'NN'),
#  ('earth', 'NN'),
#  ('archimedess', 'RB'),
#  ('lever', 'RB'),
#  ('survey', 'NN'),
#  ('galaxy', 'NN'),
#  ('proxima', 'NN'),
#  ('centauri', 'NN'),
#  ('planet', 'NN'),
#  ('trinary', 'JJ'),
#  ('bad', 'JJ'),
#  ('useful', 'JJ'),
#  ('space', 'NN'),
#  ('station', 'NN'),
#  ('hour', 'NN'),
#  ('paul', 'NN'),
#  ('grayson', 'NN'),
#  ('would', 'MD'),
#  ('locked', 'VB'),
#  ('capsule', 'NN'),
#  ('metal', 'NN'),
#  ('hurling', 'VBG'),
#  ('space', 'NN'),
#  ('towards', 'NNS'),
#  ('proxima', 'VBP'),
#  ('looking', 'VBG'),
#  ('forward', 'RB'),
#  ('ten', 'JJ'),
#  ('days', 'NNS'),
#  ('cooped', 'VBD'),
#  ('spacecraft', 'NN'),
#  ('type', 'NN'),
#  ('furnished', 'VBD'),
#  ('bureau', 'NN'),
#  ('astrogation', 'NN'),
#  ('engineers', 'NNS'),
#  ('far', 'RB'),
#  ('cry', 'VBP'),
#  ('sumptuous', 'JJ'),
#  ('craft', 'NN'),
#  ('run', 'VB'),
#  ('big', 'JJ'),
#  ('brass', 'NN'),
#  ('confines', 'NNS'),
#  ('would', 'MD'),
#  ('lined', 'VBD'),
#  ('functional', 'JJ'),
#  ('scientific', 'JJ'),
#  ('equipment', 'NN'),
#  ('air', 'NN'),
#  ('supply', 'NN'),
#  ('would', 'MD'),
#  ('medically', 'RB'),
#  ('acceptable', 'VB'),
#  ('aesthetically', 'RB'),
#  ('horrible', 'JJ'),
#  ('vision', 'NN'),
#  ('limited', 'VBD'),
#  ('cabin', 'JJ'),
#  ('beyond', 'IN'),
#  ('viewports', 'NNS'),
#  ('would', 'MD'),
#  ('formless', 'VB'),
#  ('endless', 'JJ'),
#  ('abysmal', 'JJ'),
#  ('blackness', 'NN'),
#  ('absolutely', 'RB'),
#  ('nothing', 'NN'),
#  ('ship', 'NN'),
#  ('mounted', 'VBD'),
#  ('multiples', 'NNS'),
#  ('speed', 'VB'),
#  ('light', 'JJ'),
#  ('days', 'NNS'),
#  ('building', 'NN'),
#  ('filled', 'VBD'),
#  ('dome', 'JJ'),
#  ('power', 'NN'),
#  ('equipment', 'NN'),
#  ('radio', 'NN'),
#  ('gear', 'NN'),
#  ('timing', 'VBG'),
#  ('mechanism', 'NN'),
#  ('recorders', 'NNS'),
#  ('refrigerator', 'VBP'),
#  ('setup', 'NN'),
#  ('struggled', 'VBD'),
#  ('awesome', 'JJ'),
#  ('heat', 'NN'),
#  ('poured', 'VBD'),
#  ('proxima', 'JJ'),
#  ('closeby', 'NN'),
#  ('luminary', 'JJ'),
#  ('succeeded', 'VBD'),
#  ('lowering', 'JJ'),
#  ('temperature', 'NN'),
#  ('point', 'NN'),
#  ('potting', 'VBG'),
#  ('compound', 'NN'),
#  ('transformers', 'NNS'),
#  ('run', 'VBP'),
#  ('calibrating', 'VBG'),
#  ('resistors', 'NNS'),
#  ('would', 'MD'),
#  ('change', 'VB'),
#  ('values', 'NNS'),
#  ('recording', 'VBG'),
#  ('machines', 'NNS'),
#  ('would', 'MD'),
#  ('still', 'RB'),
#  ('make', 'VB'),
#  ('record', 'NN'),
#  ('days', 'NNS'),
#  ('ship', 'VBP'),
#  ('returned', 'JJ'),
#  ('earth', 'NN'),
#  ('call', 'NN'),
#  ('thirty', 'NN'),
#  ('days', 'NNS'),
#  ('understand', 'VBP'),
#  ('paul', 'JJ'),
#  ('grayson', 'NN'),
#  ('sauntered', 'VBD'),
#  ('along', 'IN'),
#  ('killing', 'VBG'),
#  ('time', 'NN'),
#  ('fresh', 'JJ'),
#  ('air', 'NN'),
#  ('taking', 'VBG'),
#  ('paul', 'NN'),
#  ('grinned', 'VBD'),
#  ('four', 'CD'),
#  ('years', 'NNS'),
#  ('ago', 'RB'),
#  ('arrived', 'VBD'),
#  ('full', 'JJ'),
#  ('hour', 'NN'),
#  ('early', 'RB'),
#  ('wasted', 'VBD'),
#  ('hour', 'NN'),
#  ('smelly', 'RB'),
#  ('ship', 'JJ'),
#  ('instead', 'RB'),
#  ('filling', 'VBG'),
#  ('lungs', 'NNS'),
#  ('clean', 'JJ'),
#  ('fresh', 'JJ'),
#  ('air', 'NN'),
#  ('never', 'RB'),
#  ('would', 'MD'),
#  ('arrive', 'VB'),
#  ('full', 'JJ'),
#  ('five', 'CD'),
#  ('minutes', 'NNS'),
#  ('checkin', 'JJ'),
#  ('time', 'NN'),
#  ('heard', 'NN'),
#  ('radio', 'NN'),
#  ('music', 'NN'),
#  ('tone', 'NN'),
#  ('stripped', 'VBD'),
#  ('high', 'JJ'),
#  ('frequencies', 'NNS'),
#  ('passage', 'VBP'),
#  ('slit', 'NN'),
#  ('partiallyopened', 'VBN'),
#  ('window', 'NN'),
#  ('sniffed', 'VBD'),
#  ('air', 'NN'),
#  ('laughed', 'VBD'),
#  ('someone', 'NN'),
#  ('cooking', 'NN'),
#  ('corned', 'VBD'),
#  ('beef', 'NN'),
#  ('cabbage', 'NN'),
#  ('range', 'NN'),
#  ('radio', 'NN'),
#  ('music', 'NN'),
#  ('paul', 'NN'),
#  ('liked', 'VBD'),
#  ('music', 'NN'),
#  ('hummed', 'VBN'),
#  ('tune', 'NN'),
#  ('walked', 'VBD'),
#  ('fancy', 'JJ'),
#  ('struck', 'NN'),
#  ('started', 'VBD'),
#  ('sing', 'VBG'),
#  ('faint', 'NN'),
#  ('singing', 'NN'),
#  ('would', 'MD'),
#  ('carried', 'VB'),
#  ('feet', 'NNS'),
#  ('sufficed', 'VBN'),
#  ('paul', 'NN'),
#  ('refrain', 'NN'),
#  ('early', 'JJ'),
#  ('atomicage', 'NN'),
#  ('ballad', 'NN'),
#  ('_round', 'NNP'),
#  ('round', 'NN'),
#  ('round', 'NN'),
#  ('go', 'VBP'),
#  ('deuterons', 'NNS'),
#  ('round', 'VBP'),
#  ('round', 'JJ'),
#  ('magnet', 'NN'),
#  ('swings', 'NNS'),
#  ('round', 'VBP'),
#  ('round', 'NN'),
#  ('round', 'NN'),
#  ('go', 'VBP'),
#  ('deuterons', 'NNS'),
#  ('smack', 'VBP'),
#  ('target', 'NN'),
#  ('goes', 'VBZ'),
#  ('ion', 'JJ'),
#  ('beam_', 'NN'),
#  ('paul', 'NN'),
#  ('stopped', 'VBD'),
#  ('song', 'RB'),
#  ('interesting', 'VBG'),
#  ('click', 'NN'),
#  ('high', 'JJ'),
#  ('heels', 'NNS'),
#  ('sidewalk', 'VBP'),
#  ('pointed', 'VBN'),
#  ('approach', 'NN'),
#  ('someone', 'NN'),
#  ('might', 'MD'),
#  ('view', 'VB'),
#  ('_a', 'NNP'),
#  ('cappella_', 'NN'),
#  ('singing', 'VBG'),
#  ('indication', 'NN'),
#  ('inebriation', 'NN'),
#  ('coming', 'VBG'),
#  ('towards', 'NNS'),
#  ('walking', 'VBG'),
#  ('side', 'NN'),
#  ('sidewalk', 'JJ'),
#  ('step', 'NN'),
#  ('quick', 'RB'),
#  ('lithe', 'VBD'),
#  ('slight', 'JJ'),
#  ('breeze', 'NN'),
#  ('outlined', 'VBD'),
#  ('frock', 'NN'),
#  ('body', 'NN'),
#  ('revealing', 'JJ'),
#  ('time', 'NN'),
#  ('concealing', 'VBG'),
#  ('enough', 'JJ'),
#  ('quicken', 'JJ'),
#  ('pulse', 'RB'),
#  ('awaken', 'JJ'),
#  ('interest', 'NN'),
#  ('paul', 'NN'),
#  ('thirty', 'NN'),
#  ('unmarried', 'VBD'),
#  ('experienced', 'JJ'),
#  ('enough', 'RB'),
#  ('catalogue', 'NN'),
#  ('shrewdly', 'RB'),
#  ('crude', 'JJ'),
#  ('attempt', 'NN'),
#  ('pickup', 'NN'),
#  ('would', 'MD'),
#  ('work', 'VB'),
#  ('woman', 'NN'),
#  ('sure', 'JJ'),
#  ('obviously', 'RB'),
#  ('could', 'MD'),
#  ('want', 'VB'),
#  ('admirers', 'NNS'),
#  ('would', 'MD'),
#  ('take', 'VB'),
#  ('careful', 'JJ'),
#  ('strategy', 'NN'),
#  ('period', 'NN'),
#  ('time', 'NN'),
#  ('get', 'VB'),
#  ('first', 'JJ'),
#  ('base', 'NN'),
#  ('woman', 'NN'),
#  ('like', 'IN'),
#  ('inept', 'JJ'),
#  ('campaigner', 'NN'),
#  ('would', 'MD'),
#  ('called', 'VB'),
#  ('strikes', 'NNS'),
#  ('paul', 'VB'),
#  ('grayson', 'JJ'),
#  ('way', 'NN'),
#  ('centauri', 'NN'),
#  ('within', 'IN'),
#  ('hour', 'NN'),
#  ('automatically', 'RB'),
#  ('eliminated', 'VBD'),
#  ('initial', 'JJ'),
#  ('step', 'NN'),
#  ('plausible', 'JJ'),
#  ('scheme', 'NN'),
#  ('wrangle', 'NN'),
#  ('introduction', 'NN'),
#  ('paul', 'NN'),
#  ('grayson', 'NN'),
#  ('grinned', 'VBD'),
#  ('ruefully', 'RB'),
#  ('seemed', 'VBN'),
#  ('hours', 'NNS'),
#  ('spend', 'VBP'),
#  ('nothing', 'NN'),
#  ('streets', 'NNS'),
#  ('barren', 'VBP'),
#  ('presentable', 'JJ'),
#  ('women', 'NNS'),
#  ('interesting', 'VBG'),
#  ('specimens', 'NNS'),
#  ('womanhood', 'NN'),
#  ('smiled', 'VBD'),
#  ('offered', 'VBN'),
#  ('charms', 'NNS'),
#  ('en', 'IN'),
#  ('route', 'NN'),
#  ('towards', 'NNS'),
#  ('schedule', 'NN'),
#  ('could', 'MD'),
#  ('delayed', 'VB'),
#  ('woman', 'NN'),
#  ('enough', 'JJ'),
#  ('make', 'NN'),
#  ('man', 'NN'),
#  ('forget', 'VB'),
#  ('timetablesalmost', 'NN'),
#  ('came', 'VBD'),
#  ('forward', 'RB'),
#  ('face', 'NN'),
#  ('lighted', 'VBD'),
#  ('street', 'NN'),
#  ('lamp', 'NN'),
#  ('paul', 'NN'),
#  ('passed', 'VBD'),
#  ('blueeyed', 'VBN'),
#  ('fairskinned', 'VBN'),
#  ('hurried', 'VBN'),
#  ('route', 'JJ'),
#  ('collision', 'NN'),
#  ('course', 'NN'),
#  ('minute', 'NN'),
#  ('shake', 'VBP'),
#  ('head', 'NN'),
#  ('neither', 'CC'),
#  ('time', 'NN'),
#  ('inclination', 'NN'),
#  ('attempt', 'NN'),
#  ('anything', 'NN'),
#  ('crude', 'JJ'),
#  ('striking', 'VBG'),
#  ('acquaintance', 'NN'),
#  ('barring', 'VBG'),
#  ('path', 'NN'),
#  ('paul', 'NN'),
#  ('angled', 'VBD'),
#  ('course', 'NN'),
#  ('aside', 'RB'),
#  ('angled', 'VBD'),
#  ('hello', 'NN'),
#  ('said', 'VBD'),
#  ('brightly', 'RB'),
#  ('thought', 'VBN'),
#  ('youd', 'RB'),
#  ('along', 'IN'),
#  ('sooner', 'NN'),
#  ('paul', 'NN'),
#  ('grayson', 'NN'),
#  ('gulped', 'VBD'),
#  ('obviously', 'RB'),
#  ('mistook', 'JJ'),
#  ('someone', 'NN'),
#  ('else', 'RB'),
#  ('faint', 'NN'),
#  ('feeling', 'NN'),
#  ('jealousy', 'NN'),
#  ('ran', 'VBD'),
#  ('lucky', 'JJ'),
#  ('man', 'NN'),
#  ('owned', 'VBD'),
#  ('affections', 'NNS'),
#  ('street', 'NN'),
#  ('lamp', 'VBP'),
#  ('behind', 'IN'),
#  ('must', 'MD'),
#  ('cast', 'VB'),
#  ('heavy', 'JJ'),
#  ('shadows', 'NNS'),
#  ('across', 'IN'),
#  ('face', 'NN'),
#  ('making', 'VBG'),
#  ('identification', 'NN'),
#  ('difficult', 'JJ'),
#  ('opened', 'VBD'),
#  ('mouth', 'JJ'),
#  ('explain', 'VB'),
#  ('away', 'RB'),
#  ('mistake', 'JJ'),
#  ('girl', 'NN'),
#  ('came', 'VBD'),
#  ('hardly', 'RB'),
#  ('slackening', 'VBG'),
#  ('pace', 'NN'),
#  ('last', 'JJ'),
#  ('possible', 'JJ'),
#  ('moment', 'NN'),
#  ('instead', 'RB'),
#  ('speaking', 'VBG'),
#  ('paul', 'NN'),
#  ('found', 'VBD'),
#  ('parted', 'VBN'),
#  ('mouth', 'RB'),
#  ('met', 'VBN'),
#  ('lips', 'NNS'),
#  ('warm', 'JJ'),
#  ('arms', 'NNS'),
#  ('came', 'VBD'),
#  ('around', 'IN'),
#  ('quick', 'JJ'),
#  ('embrace', 'NN'),
#  ('arms', 'NNS'),
#  ('instinctively', 'RB'),
#  ('closed', 'VBD'),
#  ('waist', 'NN'),
#  ('paul', 'NN'),
#  ('kissed', 'VBD'),
#  ('back', 'RB'),
#  ('cheerfully', 'RB'),
#  ('accepting', 'VBG'),
#  ('pleasure', 'NN'),
#  ('error', 'NN'),
#  ('sort', 'NN'),
#  ('devilish', 'JJ'),
#  ('glee', 'NN'),
#  ('stepped', 'VBD'),
#  ('back', 'RB'),
#  ('im', 'JJ'),
#  ('sorry', 'NN'),
#  ('said', 'VBD'),
#  ('guy', 'JJ'),
#  ('thought', 'NN'),
#  ('looked', 'VBD'),
#  ('blink', 'JJ'),
#  ('expression', 'NN'),
#  ('changed', 'VBD'),
#  ('surprise', 'NN'),
#  ('mouth', 'NN'),
#  ('opened', 'VBD'),
#  ('scream', 'JJ'),
#  ('eyes', 'NNS'),
#  ('flicked', 'VBD'),
#  ('away', 'RB'),
#  ('centered', 'VBN'),
#  ('left', 'JJ'),
#  ('shoulder', 'NN'),
#  ('paul', 'NN'),
#  ('started', 'VBD'),
#  ('whirl', 'WP'),
#  ('someone', 'NN'),
#  ('dropped', 'VBD'),
#  ('north', 'JJ'),
#  ('pole', 'JJ'),
#  ('back', 'RB'),
#  ('skull', 'NN'),
#  ('chilled', 'VBD'),
#  ('completely', 'RB'),
#  ('scream', 'JJ'),
#  ('rang', 'NN'),
#  ('ears', 'NNS'),
#  ('fell', 'VBD'),
#  ('forward', 'RB'),
#  ('vaguely', 'RB'),
#  ('felt', 'VBD'),
#  ('silk', 'JJ'),
#  ('dress', 'NN'),
#  ('outstretched', 'VBD'),
#  ('hands', 'NNS'),
#  ('cheek', 'JJ'),
#  ('sidewalk', 'NN'),
#  ('rose', 'VBD'),
#  ('grind', 'JJ'),
#  ('face', 'NN'),
#  ('something', 'NN'),
#  ('pulled', 'VBD'),
#  ('coat', 'NN'),
#  ('felt', 'VBD'),
#  ('nothing', 'NN'),
#  ('frightened', 'VBN'),
#  ('scream', 'NN'),
#  ('woman', 'NN'),
#  ('rang', 'NN'),
#  ('ears', 'NNS'),
#  ('shrill', 'VBP'),
#  ('angry', 'JJ'),
#  ('fearful', 'JJ'),
#  ('never', 'RB'),
#  ('ending', 'VBG'),
#  ('paul', 'NN'),
#  ('realized', 'VBN'),
#  ('siren', 'JJ'),
#  ('wail', 'NN'),
#  ('scream', 'NN'),
#  ('ringing', 'VBG'),
#  ('ears', 'NNS'),
#  ('girl', 'JJ'),
#  ('sitting', 'VBG'),
#  ('asprawl', 'JJ'),
#  ('sidewalk', 'NN'),
#  ('head', 'NN'),
#  ('thighs', 'IN'),
#  ('rubbing', 'VBG'),
#  ('nape', 'NN'),
#  ('neck', 'NN'),
#  ('fingertips', 'NNS'),
#  ('quietly', 'RB'),
#  ('erasing', 'VBG'),
#  ('pain', 'NN'),
#  ('bit', 'NN'),
#  ('bit', 'NN'),
#  ('threshold', 'JJ'),
#  ('ringing', 'NN'),
#  ('ears', 'NNS'),
#  ('diminished', 'VBD'),
#  ('field', 'NN'),
#  ('vision', 'NN'),
#  ('increased', 'VBD'),
#  ('darting', 'VBG'),
#  ('lights', 'NNS'),
#  ('went', 'VBD'),
#  ('away', 'RB'),
#  ('paul', 'JJ'),
#  ('grayson', 'NN'),
#  ('could', 'MD'),
#  ('hear', 'VB'),
#  ('sound', 'JJ'),
#  ('running', 'VBG'),
#  ('feet', 'NNS'),
#  ('babble', 'JJ'),
#  ('voices', 'NNS'),
#  ('happened', 'VBD'),
#  ('man', 'NN'),
#  ('clipped', 'VBD'),
#  ('thug', 'JJ'),
#  ('saw', 'NN'),
#  ('came', 'VBD'),
#  ('voices', 'NNS'),
#  ('mad', 'JJ'),
#  ('garble', 'JJ'),
#  ('scrambled', 'VBN'),
#  ('speeches', 'NNS'),
#  ('right', 'RB'),
#  ('front', 'JJ'),
#  ('eyes', 'NNS'),
#  ('babble', 'JJ'),
#  ('broke', 'VBD'),
#  ('many', 'JJ'),
#  ('varied', 'JJ'),
#  ('subjects', 'NNS'),
#  ('curiosity', 'NN'),
#  ('morbid', 'NN'),
#  ('samaritan', 'NN'),
#  ('anger', 'NN'),
#  ('righteous', 'JJ'),
#  ('superficial', 'JJ'),
#  ('directed', 'VBN'),
#  ('things', 'NNS'),
#  ('make', 'VBP'),
#  ('happenings', 'NNS'),
#  ('possible', 'JJ'),
#  ('suggestions', 'NNS'),
#  ('sensible', 'JJ'),
#  ('absurd', 'JJ'),
#  ('offers', 'NNS'),
#  ('welcome', 'VBP'),
#  ('ridiculous', 'JJ'),
#  ('paul', 'NN'),
#  ('groaned', 'VBD'),
#  ('tried', 'JJ'),
#  ('lift', 'NN'),
#  ('hand', 'NN'),
#  ('raw', 'JJ'),
#  ('spot', 'NN'),
#  ('chin', 'NN'),
#  ('sidewalk', 'NN'),
#  ('removed', 'VBD'),
#  ('hide', 'JJ'),
#  ('woman', 'NN'),
#  ('looked', 'VBD'),
#  ('smiled', 'JJ'),
#  ('wan', 'NN'),
#  ('apprehensive', 'JJ'),
#  ('manner', 'NN'),
#  ('youre', 'NN'),
#  ('right', 'NN'),
#  ('paul', 'NN'),
#  ('struggled', 'VBD'),
#  ('sit', 'NN'),
#  ('made', 'VBN'),
#  ('help', 'NN'),
#  ('wave', 'VB'),
#  ('pain', 'NN'),
#  ('rose', 'VBD'),
#  ('localized', 'VBN'),
#  ('head', 'NN'),
#  ('forty', 'NN'),
#  ('degrees', 'NNS'),
#  ('right', 'RB'),
#  ('latitude', 'VBP'),
#  ('made', 'VBN'),
#  ('want', 'VBP'),
#  ('carry', 'JJ'),
#  ('head', 'NN'),
#  ('angle', 'NN'),
#  ('neck', 'NN'),
#  ('ducked', 'VBD'),
#  ('level', 'NN'),
#  ('knot', 'NN'),
#  ('pain', 'NN'),
#  ('hands', 'NNS'),
#  ('helped', 'VBD'),
#  ('feet', 'NNS'),
#  ('led', 'VBN'),
#  ('across', 'IN'),
#  ('sidewalk', 'NN'),
#  ('became', 'VBD'),
#  ('stronger', 'JJR'),
#  ('moment', 'NN'),
#  ('shook', 'NN'),
#  ('head', 'NN'),
#  ('clear', 'JJ'),
#  ('winced', 'JJ'),
#  ('motion', 'NN'),
#  ('caused', 'VBD'),
#  ('knot', 'NN'),
#  ('pain', 'NN'),
#  ('vibrate', 'VBP'),
#  ('nastily', 'RB'),
#  ('happened', 'VBN'),
#  ('asked', 'VBD'),
#  ('quavering', 'JJ'),
#  ('voice', 'NN'),
#  ('sounded', 'VBD'),
#  ('like', 'IN'),
#  ('someone', 'NN'),
#  ('elses', 'VBZ'),
#  ('voice', 'NN'),
#  ('surprised', 'VBD'),
#  ('sound', 'NN'),
#  ('repeated', 'VBN'),
#  ('question', 'NN'),
#  ('still', 'RB'),
#  ('sounded', 'VBN'),
#  ('like', 'IN'),
#  ('someone', 'NN'),
#  ('elses', 'VBZ'),
#  ('voice', 'NN'),
#  ('wondering', 'VBG'),
#  ('voice', 'NN'),
#  ('would', 'MD'),
#  ('sound', 'VB'),
#  ('like', 'IN'),
#  ('rest', 'JJS'),
#  ('life', 'NN'),
#  ('girl', 'NN'),
#  ('explained', 'VBD'),
#  ('happened', 'VBD'),
#  ('paul', 'NNS'),
#  ('missed', 'VBN'),
#  ('asked', 'VBD'),
#  ('another', 'DT'),
#  ('question', 'NN'),
#  ('see', 'NN'),
#  ('said', 'VBD'),
#  ('voice', 'NN'),
#  ('regretful', 'NN'),
#  ('yet', 'RB'),
#  ('tinted', 'VBN'),
#  ('dash', 'NN'),
#  ('amusement', 'NN'),
#  ('sort', 'NN'),
#  ('rose', 'VBD'),
#  ('shadow', 'NN'),
#  ('behind', 'IN'),
#  ('youyoure', 'NN'),
#  ('tall', 'JJ'),
#  ('man', 'NN'),
#  ('know', 'VBP'),
#  ('saw', 'VBZ'),
#  ('ragged', 'JJ'),
#  ('silhouette', 'NN'),
#  ('hit', 'NN'),
#  ('fell', 'VBD'),
#  ('screamed', 'VBN'),
#  ('grabbed', 'JJ'),
#  ('wallet', 'NN'),
#  ('voice', 'NN'),
#  ('trailed', 'VBD'),
#  ('away', 'RB'),
#  ('unhappily', 'JJ'),
#  ('paul', 'NN'),
#  ('smiled', 'VBD'),
#  ('nothing', 'NN'),
#  ('personal', 'JJ'),
#  ('papers', 'NNS'),
#  ('replaceable', 'JJ'),
#  ('dollars', 'NNS'),
#  ('id', 'VBP'),
#  ('handed', 'VBN'),
#  ('rather', 'RB'),
#  ('get', 'VB'),
#  ('clip', 'JJ'),
#  ('skull', 'NN'),
#  ('bad', 'JJ'),
#  ('couldnt', 'NN'),
#  ('see', 'VBP'),
#  ('touch', 'JJ'),
#  ('amusement', 'NN'),
#  ('came', 'VBD'),
#  ('eyes', 'NNS'),
#  ('closed', 'VBD'),
#  ('sort', 'NN'),
#  ('paul', 'NN'),
#  ('smiled', 'VBD'),
#  ('inwardly', 'RB'),
#  ('welcoming', 'VBG'),
#  ('footpad', 'JJ'),
#  ('contents', 'NNS'),
#  ('wallet', 'VBP'),
#  ('accepting', 'VBG'),
#  ('bop', 'NN'),
#  ('bean', 'JJ'),
#  ('price', 'NN'),
#  ('pay', 'NN'),
#  ('introduction', 'NN'),
#  ('girl', 'NN'),
#  ('someone', 'NN'),
#  ('crowd', 'NN'),
#  ('said', 'VBD'),
#  ('youd', 'RB'),
#  ('better', 'RBR'),
#  ('come', 'VB'),
#  ('inside', 'IN'),
#  ('feel', 'NN'),
#  ('right', 'RB'),
#  ('paul', 'NN'),
#  ('shook', 'NN'),
#  ('head', 'NN'),
#  ('happy', 'JJ'),
#  ('find', 'VBP'),
#  ('knot', 'JJ'),
#  ('inside', 'RB'),
#  ('diminished', 'VBD'),
#  ('faint', 'JJ'),
#  ('pinpoint', 'NN'),
#  ('voice', 'NN'),
#  ('sounding', 'VBG'),
#  ('like', 'IN'),
#  ('ive', 'JJ'),
#  ('got', 'VBD'),
#  ('go', 'NNS'),
#  ('said', 'VBD'),
#  ('wail', 'NN'),
#  ('sirens', 'NNS'),
#  ('came', 'VBD'),
#  ('police', 'JJ'),
#  ('car', 'NN'),
#  ('dashed', 'VBD'),
#  ('curb', 'NN'),
#  ('spilled', 'VBN'),
#  ('policemen', 'NNS'),
#  ('doors', 'NNS'),
#  ('came', 'VBD'),
#  ('warily', 'RB'),
#  ('whats', 'VBZ'),
#  ('going', 'VBG'),
#  ('demanded', 'VBN'),
#  ('sergeant', 'NN'),
#  ('paul', 'NN'),
#  ('explained', 'VBD'),
#  ('youd', 'RB'),
#  ('better', 'RBR'),
#  ('come', 'JJ'),
#  ('station', 'NN'),
#  ('lodge', 'NN'),
#  ('complaint', 'NN'),
#  ('paul', 'NN'),
#  ('shook', 'NN'),
#  ('head', 'NN'),
#  ('im', 'NN'),
#  ('paul', 'NN'),
#  ('grayson', 'NN'),
#  ('bureau', 'NN'),
#  ('astrogation', 'NN'),
#  ('said', 'VBD'),
#  ('could', 'MD'),
#  ('prove', 'VB'),
#  ('crook', 'NN'),
#  ('identification', 'NN'),
#  ('papers', 'NNS'),
#  ('im', 'VBP'),
#  ('due', 'JJ'),
#  ('take', 'VBP'),
#  ('space', 'NN'),
#  ('within', 'IN'),
#  ('paul', 'NN'),
#  ('looked', 'VBD'),
#  ...]

# %% [markdown]
# ## Visualising the POS TAGS

# %%
dict1 = {}
for key, value in posTagged:
    if(value not in dict1):
        dict1[value] = 1
    else:
        dict1[value] += 1

sorted_tags = dict(sorted(dict1.items(), key=lambda item:item[1], reverse=True))


N = 20
sorted_tags=dict(list(sorted_tags.items())[0:N])

plt.bar(sorted_tags.keys(), sorted_tags.values())
plt.xlabel('TAGS')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Writing a function to find out the largest chapter and seperate all chapters

# %%
def chapter_seperate(raw_text):
    
    #splitting the chapters from the raw text
    chapters = re.split(r'CHAPTER \d+', raw_text)
    
    
    #creating an array for chapter lengths
    chapter_lengths=[len(i) for i in chapters]
    
    #taking out the largest chapter text
    largest_chapter=chapters[pd.Series(chapter_lengths).idxmax()]
    return largest_chapter,chapters

# %%
largest_chapter,chapters=chapter_seperate(raw_text)
largest_chapter
# Out:
# '\n\n\nLike most human beings, Paul could comprehend the actions of someone\nof his own type. But he could not understand the mental machinations\nof people who had other motives and other interests in life. Nor could\nhe seem to make other people understand that his continued interest in\nthe Z-wave was only just and sensible. After all, he had never had an\nopportunity to try it.\n\nTo Paul it was just that simple. Just let him try it. He had so much\nfaith in it that he could not foresee his next reaction if failure\ncame. Paul did not consider failure as a possibility, but if he did\nfail, he would automatically begin insisting upon a chance to continue,\ninsisting that something had gone awry, or that there were factors that\nmust be studied.\n\nThis sort of attitude was acceptable to Paul, yet he could not\ncomprehend the contemplated action of the political factions he was\ninvolved with.\n\nFor instance, one faction was going to falsify evidence in order to\nswing an election. This seemed dishonest to Paul. He wondered just\nhow they could justify their act. The other faction was keeping him\nprisoner so that he could not furnish any evidence at all.\n\nBut eventually one side or the other was going to find that its\nevidence was in error. Then what? Supposing because he had been\nkidnaped by this particular gang and thus gave some concrete evidence\nof negative result, Hoagland and Westlake and the rest were\nelected--after which the Z-wave contact proved good? Or, if Huston\nand his crowd got elected on the strength of the Z-wave contact, and\nthen because Paul was captive and unable to make it work, there was no\nZ-wave communication with Terra.\n\nHow could they justify their claims in the face of the emptiness of\ntheir prophecies?\n\nPaul could not understand the political mind and the thinking of the\nman on the street. He could not even apply such thinking to his own\ncase. The fact that for eons, politicians have been making promises\nthat were unfulfilled after election did not register with Grayson.\n\nThe thing to do, of course, was to escape. Then he could work and\nbring out the truth--which to Paul was single-valued and positive--and\nthus do away with all of the half-truths, lies, and fingers-crossed\nstatements.\n\nBut how? He had to admit that he was not ill-treated. He believed\nthat both sides were willing to have Z-wave contact with Terra,\nfor commercial reasons, but he knew that only one side wanted\ncommunications now. Ergo the opposing side which were his captors\nwould treat him well in the hope of having him work for them once the\nelection was over.\n\nPaul shrugged. Whatever the cause, he would not cut off his nose to\nspite his face. His was no interest in political fray. He wanted to\nwork with the Z-wave.\n\nIn fact Westlake and Hoagland had one facet that looked reasonably\ngood. Their party was for autonomy, and if Paul worked for them, he\nwould be forever free of any legal attachment to Terra. And doubtless\nHaedaecker and the whole Bureau of Astrogation were out gunning for\nPaul Grayson if for no other reason than the stolen BurAst P.G.1. Were\nHuston and his coalition government to get in, Haedaecker could swing\na large club over the various integrated wings of government and make\nPaul\'s life precarious.\n\nSo Paul was on the fence so far as his work was concerned. In fact,\nat the present moment Paul did not think highly of either political\nambition, since their high ambition was tarred with a wide, full brush\nof downright thuggery.\n\nEscape, of course, was an easy word to say. It was true that Paul\'s\nincarceration was nothing like being cooped up in a jail cell. His door\nwas closed but not locked; he had plenty of time and opportunity to see\nand talk to both Nora and John Stacey, and to make friends with other\npolitical prisoners. Across the broad plain was a spaceport and some\nspacecraft that came and went, but going there and taking off presented\nthe problem of ge ...

# %% [markdown]
# ### Processing the largest chapter text

# %%
largest_chapter_text=text_preprocessing(largest_chapter)
print(largest_chapter_text)
# Out:
# like most human beings paul could comprehend the actions of someone of his own type but he could not understand the mental machinations of people who had other motives and other interests in life nor could he seem to make other people understand that his continued interest in the zwave was only just and sensible after all he had never had an opportunity to try it to paul it was just that simple just let him try it he had so much faith in it that he could not foresee his next reaction if failure came paul did not consider failure as a possibility but if he did fail he would automatically begin insisting upon a chance to continue insisting that something had gone awry or that there were factors that must be studied this sort of attitude was acceptable to paul yet he could not comprehend the contemplated action of the political factions he was involved with for instance one faction was going to falsify evidence in order to swing an election this seemed dishonest to paul he wondered just how they could justify their act the other faction was keeping him prisoner so that he could not furnish any evidence at all but eventually one side or the other was going to find that its evidence was in error then what supposing because he had been kidnaped by this particular gang and thus gave some concrete evidence of negative result hoagland and westlake and the rest were electedafter which the zwave contact proved good or if huston and his crowd got elected on the strength of the zwave contact and then because paul was captive and unable to make it work there was no zwave communication with terra how could they justify their claims in the face of the emptiness of their prophecies paul could not understand the political mind and the thinking of the man on the street he could not even apply such thinking to his own case the fact that for eons politicians have been making promises that were unfulfilled after election did not register with grayson the thing to do of course was to escape then he could work and bring out the truthwhich to paul was singlevalued and positiveand thus do away with all of the halftruths lies and fingerscrossed statements but how he had to admit that he was not illtreated he believed that both sides were willing to have zwave contact with terra for commercial reasons but he knew that only one side wanted communications now ergo the opposing side which were his captors would treat him well in the hope of having him work for them once the election was over paul shrugged whatever the cause he would not cut off his nose to spite his face his was no interest in political fray he wanted to work with the zwave in fact westlake and hoagland had one facet that looked reasonably good their party was for autonomy and if paul worked for them he would be forever free of any legal attachment to terra and doubtless haedaecker and the whole bureau of astrogation were out gunning for paul grayson if for no other reason than the stolen burast pg were huston and his coalition government to get in haedaecker could swing a large club over the various integrated wings of government and make pauls life precarious so paul was on the fence so far as his work was concerned in fact at the present moment paul did not think highly of either political ambition since their high ambition was tarred with a wide full brush of downright thuggery escape of course was an easy word to say it was true that pauls incarceration was nothing like being cooped up in a jail cell his door was closed but not locked he had plenty of time and opportunity to see and talk to both nora and john stacey and to make friends with other political prisoners across the broad plain was a spaceport and some spacecraft that came and went but going there and taking off presented the problem of getting away with it he was somewhat reminded of the signs reputed to be placed around the penal grounds on antarctica there were maps of the south polar region of terra with latitude longitu ...

# %% [markdown]
# ## Writing a function to calculate the bigram probabilities from a given text

# %%
def bigram_probability(text):
    
    words = text.split()
    # Counting the occurrences of bigrams
    bigrams=list(ngrams(words,2,pad_right=True))
    bigram_counts = Counter(bigrams)
    bigram_set=set(bigrams)

    # Calculating the probabilities
    
    #total number of unique bigrams
    total_bigrams = len(bigram_counts)
    bigram_probabilities = {bigram: count / total_bigrams for bigram, count in bigram_counts.items()}
    bigram_probabilities = dict(sorted(bigram_probabilities.items(),key=lambda item:item[1],reverse=True))
    
    return bigram_probabilities,bigram_set


def print_bigram_probabilities(bigram_probabilities):
    for bigram, probability in sorted(bigram_probabilities.items(),key=lambda item:item[1],reverse=True):
        print(f"Bigram: {bigram}, Probability: {probability:.6f}")

# %% [markdown]
# ## Calculating the bigram probabilities of the largest chapter

# %%
bigram_probabilities,bigram_set=bigram_probability(largest_chapter_text)
print_bigram_probabilities(bigram_probabilities)
# Out:
# Bigram: ('of', 'the'), Probability: 0.010303
# Bigram: ('it', 'was'), Probability: 0.004371
# Bigram: ('on', 'the'), Probability: 0.004059
# Bigram: ('and', 'the'), Probability: 0.003746
# Bigram: ('as', 'the'), Probability: 0.003434
# Bigram: ('with', 'the'), Probability: 0.003122
# Bigram: ('would', 'be'), Probability: 0.003122
# Bigram: ('in', 'the'), Probability: 0.002810
# Bigram: ('the', 'other'), Probability: 0.002810
# Bigram: ('at', 'the'), Probability: 0.002810
# Bigram: ('was', 'a'), Probability: 0.002810
# Bigram: ('the', 'zwave'), Probability: 0.002498
# Bigram: ('had', 'been'), Probability: 0.002498
# Bigram: ('and', 'then'), Probability: 0.002498
# Bigram: ('from', 'the'), Probability: 0.002498
# Bigram: ('to', 'the'), Probability: 0.002498
# Bigram: ('the', 'door'), Probability: 0.002498
# Bigram: ('he', 'could'), Probability: 0.002185
# Bigram: ('he', 'had'), Probability: 0.002185
# Bigram: ('did', 'not'), Probability: 0.002185
# Bigram: ('stacey', 'and'), Probability: 0.002185
# Bigram: ('across', 'the'), Probability: 0.002185
# Bigram: ('and', 'morrow'), Probability: 0.002185
# Bigram: ('the', 'ship'), Probability: 0.002185
# Bigram: ('could', 'not'), Probability: 0.001873
# Bigram: ('in', 'a'), Probability: 0.001873
# Bigram: ('to', 'make'), Probability: 0.001561
# Bigram: ('there', 'was'), Probability: 0.001561
# Bigram: ('to', 'his'), Probability: 0.001561
# Bigram: ('with', 'a'), Probability: 0.001561
# Bigram: ('out', 'of'), Probability: 0.001561
# Bigram: ('the', 'same'), Probability: 0.001561
# Bigram: ('able', 'to'), Probability: 0.001561
# Bigram: ('and', 'paul'), Probability: 0.001561
# Bigram: ('they', 'were'), Probability: 0.001561
# Bigram: ('time', 'to'), Probability: 0.001561
# Bigram: ('paul', 'could'), Probability: 0.001249
# Bigram: ('to', 'paul'), Probability: 0.001249
# Bigram: ('let', 'him'), Probability: 0.001249
# Bigram: ('that', 'he'), Probability: 0.001249
# Bigram: ('there', 'were'), Probability: 0.001249
# Bigram: ('he', 'was'), Probability: 0.001249
# Bigram: ('going', 'to'), Probability: 0.001249
# Bigram: ('so', 'that'), Probability: 0.001249
# Bigram: ('then', 'he'), Probability: 0.001249
# Bigram: ('to', 'get'), Probability: 0.001249
# Bigram: ('time', 'and'), Probability: 0.001249
# Bigram: ('same', 'time'), Probability: 0.001249
# Bigram: ('had', 'not'), Probability: 0.001249
# Bigram: ('the', 'first'), Probability: 0.001249
# Bigram: ('that', 'the'), Probability: 0.001249
# Bigram: ('through', 'the'), Probability: 0.001249
# Bigram: ('into', 'the'), Probability: 0.001249
# Bigram: ('no', 'time'), Probability: 0.001249
# Bigram: ('said', 'nora'), Probability: 0.001249
# Bigram: ('the', 'house'), Probability: 0.001249
# Bigram: ('the', 'plain'), Probability: 0.001249
# Bigram: ('away', 'from'), Probability: 0.001249
# Bigram: ('the', 'roar'), Probability: 0.001249
# Bigram: ('the', 'car'), Probability: 0.001249
# Bigram: ('his', 'own'), Probability: 0.000937
# Bigram: ('try', 'it'), Probability: 0.000937
# Bigram: ('it', 'he'), Probability: 0.000937
# Bigram: ('if', 'he'), Probability: 0.000937
# Bigram: ('he', 'would'), Probability: 0.000937
# Bigram: ('had', 'gone'), Probability: 0.000937
# Bigram: ('they', 'could'), Probability: 0.000937
# Bigram: ('zwave', 'contact'), Probability: 0.000937
# Bigram: ('huston', 'and'), Probability: 0.000937
# Bigram: ('and', 'his'), Probability: 0.000937
# Bigram: ('paul', 'was'), Probability: 0.000937
# Bigram: ('with', 'terra'), Probability: 0.000937
# Bigram: ('the', 'thing'), Probability: 0.000937
# Bigram: ('to', 'do'), Probability: 0.000937
# Bigram: ('of', 'course'), Probability: 0.000937
# Bigram: ('was', 'to'), Probability: 0.000937
# Bigram: ('all', 'of'), Probability: 0.000937
# Bigram: ('to', 'have'), Probability: 0.000937
# Bigram: ('the', 'whole'), Probability: 0.000937
# Bigram: ('and', 'went'), Probability: 0.000937
# Bigram: ('for', 'the'), Probability: 0.000937
# Bigram: ('the', 'only'), Probability: 0.000937
# Bigram: ('was', 'the'), Probability: 0.000937
# Bigram: ('that', 'was'), Probability: 0.000937
# Bigram: ('the', 'planet'), Probability: 0.000937
# Bigram: ('other', 'end'), Probability: 0.000937
# Bigram: ('the', 'galactic'), Probability: 0.000937
# Bigram: ('more', 'and'), Probability: 0.000937
# Bigram: ('far', 'from'), Probability: 0.000937
# Bigram: ('from', 'a'), Probability: 0.000937
# Bigram: ('between', 'the'), Probability: 0.000937
# Bigram: ('that', 'would'), Probability: 0.000937
# Bigram: ('light', 'years'), Probability: 0.000937
# Bigram: ('on', 'a'), Probability: 0.000937
# Bigram: ('that', 'it'), Probability: 0.000937
# Bigram: ('be', 'a'), Probability: 0.000937
# Bigram: ('he', 'said'), Probability: 0.000937
# Bigram: ('to', 'play'), Probability: 0.000937
# Bigram: ('much', 'later'), Probability: 0.000937
# Bigram: ('could', 'see'), Probability: 0.000937
# Bigram: ('it', 'would'), Probability: 0.000937
# Bigram: ('paul', 'and'), Probability: 0.000937
# Bigram: ('alarm', 'he'), Probability: 0.000937
# Bigram: ('my', 'door'), Probability: 0.000937
# Bigram: ('door', 'and'), Probability: 0.000937
# Bigram: ('of', 'a'), Probability: 0.000937
# Bigram: ('he', 'snapped'), Probability: 0.000937
# Bigram: ('roar', 'of'), Probability: 0.000937
# Bigram: ('the', 'engine'), Probability: 0.000937
# Bigram: ('the', 'spacelock'), Probability: 0.000937
# Bigram: ('the', 'control'), Probability: 0.000937
# Bigram: ('comprehend', 'the'), Probability: 0.000624
# Bigram: ('of', 'his'), Probability: 0.000624
# Bigram: ('but', 'he'), Probability: 0.000624
# Bigram: ('not', 'understand'), Probability: 0.000624
# Bigram: ('understand', 'the'), Probability: 0.000624
# Bigram: ('who', 'had'), Probability: 0.000624
# Bigram: ('interest', 'in'), Probability: 0.000624
# Bigram: ('opportunity', 'to'), Probability: 0.000624
# Bigram: ('to', 'try'), Probability: 0.000624
# Bigram: ('was', 'just'), Probability: 0.000624
# Bigram: ('in', 'it'), Probability: 0.000624
# Bigram: ('it', 'that'), Probability: 0.000624
# Bigram: ('his', 'next'), Probability: 0.000624
# Bigram: ('paul', 'did'), Probability: 0.000624
# Bigram: ('as', 'a'), Probability: 0.000624
# Bigram: ('he', 'did'), Probability: 0.000624
# Bigram: ('a', 'chance'), Probability: 0.000624
# Bigram: ('chance', 'to'), Probability: 0.000624
# Bigram: ('sort', 'of'), Probability: 0.000624
# Bigram: ('the', 'political'), Probability: 0.000624
# Bigram: ('faction', 'was'), Probability: 0.000624
# Bigram: ('was', 'going'), Probability: 0.000624
# Bigram: ('in', 'order'), Probability: 0.000624
# Bigram: ('order', 'to'), Probability: 0.000624
# Bigram: ('he', 'wondered'), Probability: 0.000624
# Bigram: ('justify', 'their'), Probability: 0.000624
# Bigram: ('was', 'keeping'), Probability: 0.000624
# Bigram: ('any', 'evidence'), Probability: 0.000624
# Bigram: ('one', 'side'), Probability: 0.000624
# Bigram: ('westlake', 'and'), Probability: 0.000624
# Bigram: ('contact', 'and'), Probability: 0.000624
# Bigram: ('was', 'no'), Probability: 0.000624
# Bigram: ('face', 'of'), Probability: 0.000624
# Bigram: ('the', 'fact'), Probability: 0.000624
# Bigram: ('fact', 'that'), Probability: 0.000624
# Bigram: ('with', 'grayson'), Probability: 0.000624
# Bigram: ('thing', 'to'), Probability: 0.000624
# Bigram: ('course', 'was'), Probability: 0.000624
# Bigram: ('away', 'with'), Probability: 0.000624
# Bigram: ('statements', 'but'), Probability: 0.000624
# Bigram: ('was', 'not'), Probability: 0.000624
# Bigram: ('willing', 'to'), Probability: 0.000624
# Bigram: ('knew', 'that'), Probability: 0.000624
# Bigram: ('only', 'one'), Probability: 0.000624
# Bigram: ('the', 'hope'), Probability: 0.000624
# Bigram: ('hope', 'of'), Probability: 0.000624
# Bigram: ('him', 'work'), Probability: 0.000624
# Bigram: ('for', 'them'), Probability: 0.000624
# Bigram: ('once', 'the'), Probability: 0.000624
# Bigram: ('would', 'not'), Probability: 0.000624
# Bigram: ('to', 'work'), Probability: 0.000624
# Bigram: ('work', 'with'), Probability: 0.000624
# Bigram: ('zwave', 'in'), Probability: 0.000624
# Bigram: ('in', 'fact'), Probability: 0.000624
# Bigram: ('facet', 'that'), Probability: 0.000624
# Bigram: ('terra', 'and'), Probability: 0.000624
# Bigram: ('paul', 'grayson'), Probability: 0.000624
# Bigram: ('a', 'large'), Probability: 0.000624
# Bigram: ('so', 'paul'), Probability: 0.000624
# Bigram: ('so', 'far'), Probability: 0.000624
# Bigram: ('not', 'think'), Probability: 0.000624
# Bigram: ('was', 'true'), Probability: 0.000624
# Bigram: ('up', 'in'), Probability: 0.000624
# Bigram: ('door', 'was'), Probability: 0.000624
# Bigram: ('but', 'not'), Probability: 0.000624
# Bigram: ('nora', 'and'), Probability: 0.000624
# Bigram: ('john', 'stacey'), Probability: 0.000624
# Bigram: ('the', 'broad'), Probability: 0.000624
# Bigram: ('broad', 'plain'), Probability: 0.000624
# Bigram: ('taking', 'off'), Probability: 0.000624
# Bigram: ('the', 'problem'), Probability: 0.000624
# Bigram: ('was', 'somewhat'), Probability: 0.000624
# Bigram: ('to', 'be'), Probability: 0.000624
# Bigram: ('polar', 'region'), Probability: 0.000624
# Bigram: ('terra', 'with'), Probability: 0.000624
# Bigram: ('the', 'distance'), Probability: 0.000624
# Bigram: ('the', 'year'), Probability: 0.000624
# Bigram: ('trying', 'to'), Probability: 0.000624
# Bigram: ('a', 'few'), Probability: 0.000624
# Bigram: ('nothing', 'in'), Probability: 0.000624
# Bigram: ('one', 'of'), Probability: 0.000624
# Bigram: ('before', 'he'), Probability: 0.000624
# Bigram: ('way', 'a'), Probability: 0.000624
# Bigram: ('a', 'man'), Probability: 0.000624
# Bigram: ('means', 'of'), Probability: 0.000624
# Bigram: ('of', 'communication'), Probability: 0.000624
# Bigram: ('they', 'did'), Probability: 0.000624
# Bigram: ('but', 'they'), Probability: 0.000624
# Bigram: ('the', 'radio'), Probability: 0.000624
# Bigram: ('radio', 'beacon'), Probability: 0.000624
# Bigram: ('the', 'prisoners'), Probability: 0.000624
# Bigram: ('end', 'of'), Probability: 0.000624
# Bigram: ('galactic', 'survey'), Probability: 0.000624
# Bigram: ('about', 'the'), Probability: 0.000624
# Bigram: ('time', 'that'), Probability: 0.000624
# Bigram: ('paul', 'had'), Probability: 0.000624
# Bigram: ('about', 'it'), Probability: 0.000624
# Bigram: ('they', 'had'), Probability: 0.000624
# Bigram: ('not', 'been'), Probability: 0.000624
# Bigram: ('been', 'able'), Probability: 0.000624
# Bigram: ('once', 'more'), Probability: 0.000624
# Bigram: ('his', 'map'), Probability: 0.000624
# Bigram: ('but', 'it'), Probability: 0.000624
# Bigram: ('and', 'it'), Probability: 0.000624
# Bigram: ('takes', 'a'), Probability: 0.000624
# Bigram: ('two', 'dots'), Probability: 0.000624
# Bigram: ('a', 'line'), Probability: 0.000624
# Bigram: ('the', 'idea'), Probability: 0.000624
# Bigram: ('there', 'with'), Probability: 0.000624
# Bigram: ('and', 'more'), Probability: 0.000624
# Bigram: ('it', 'is'), Probability: 0.000624
# Bigram: ('line', 'between'), Probability: 0.000624
# Bigram: ('would', 'have'), Probability: 0.000624
# Bigram: ('connection', 'between'), Probability: 0.000624
# Bigram: ('years', 'apart'), Probability: 0.000624
# Bigram: ('out', 'and'), Probability: 0.000624
# Bigram: ('went', 'on'), Probability: 0.000624
# Bigram: ('were', 'only'), Probability: 0.000624
# Bigram: ('instead', 'of'), Probability: 0.000624
# Bigram: ('with', 'one'), Probability: 0.000624
# Bigram: ('one', 'hundred'), Probability: 0.000624
# Bigram: ('forty', 'light'), Probability: 0.000624
# Bigram: ('about', 'ten'), Probability: 0.000624
# Bigram: ('and', 'one'), Probability: 0.000624
# Bigram: ('but', 'the'), Probability: 0.000624
# Bigram: ('for', 'a'), Probability: 0.000624
# Bigram: ('be', 'able'), Probability: 0.000624
# Bigram: ('a', 'sharp'), Probability: 0.000624
# Bigram: ('i', 'thought'), Probability: 0.000624
# Bigram: ('forgot', 'to'), Probability: 0.000624
# Bigram: ('to', 'mention'), Probability: 0.000624
# Bigram: ('you', 'did'), Probability: 0.000624
# Bigram: ('that', 'grayson'), Probability: 0.000624
# Bigram: ('grayson', 'was'), Probability: 0.000624
# Bigram: ('and', 'that'), Probability: 0.000624
# Bigram: ('that', 'you'), Probability: 0.000624
# Bigram: ('westlake', 'laughed'), Probability: 0.000624
# Bigram: ('grayson', 'and'), Probability: 0.000624
# Bigram: ('into', 'life'), Probability: 0.000624
# Bigram: ('located', 'the'), Probability: 0.000624
# Bigram: ('out', 'to'), Probability: 0.000624
# Bigram: ('him', 'up'), Probability: 0.000624
# Bigram: ('up', 'the'), Probability: 0.000624
# Bigram: ('the', 'boys'), Probability: 0.000624
# Bigram: ('boys', 'at'), Probability: 0.000624
# Bigram: ('morrow', 'in'), Probability: 0.000624
# Bigram: ('said', 'westlake'), Probability: 0.000624
# Bigram: ('westlake', 'how'), Probability: 0.000624
# Bigram: ('which', 'is'), Probability: 0.000624
# Bigram: ('anything', 'that'), Probability: 0.000624
# Bigram: ('mention', 'of'), Probability: 0.000624
# Bigram: ('is', 'the'), Probability: 0.000624
# Bigram: ('he', 'is'), Probability: 0.000624
# Bigram: ('grayson', 'will'), Probability: 0.000624
# Bigram: ('tried', 'to'), Probability: 0.000624
# Bigram: ('ive', 'read'), Probability: 0.000624
# Bigram: ('and', 'find'), Probability: 0.000624
# Bigram: ('find', 'it'), Probability: 0.000624
# Bigram: ('against', 'him'), Probability: 0.000624
# Bigram: ('a', 'ship'), Probability: 0.000624
# Bigram: ('and', 'well'), Probability: 0.000624
# Bigram: ('ship', 'took'), Probability: 0.000624
# Bigram: ('took', 'off'), Probability: 0.000624
# Bigram: ('off', 'for'), Probability: 0.000624
# Bigram: ('out', 'across'), Probability: 0.000624
# Bigram: ('that', 'one'), Probability: 0.000624
# Bigram: ('his', 'room'), Probability: 0.000624
# Bigram: ('and', 'again'), Probability: 0.000624
# Bigram: ('again', 'he'), Probability: 0.000624
# Bigram: ('the', 'encampment'), Probability: 0.000624
# Bigram: ('the', 'big'), Probability: 0.000624
# Bigram: ('beacon', 'station'), Probability: 0.000624
# Bigram: ('was', 'dark'), Probability: 0.000624
# Bigram: ('paul', 'looked'), Probability: 0.000624
# Bigram: ('room', 'the'), Probability: 0.000624
# Bigram: ('the', 'corridor'), Probability: 0.000624
# Bigram: ('door', 'open'), Probability: 0.000624
# Bigram: ('gone', 'out'), Probability: 0.000624
# Bigram: ('what', 'gives'), Probability: 0.000624
# Bigram: ('like', 'a'), Probability: 0.000624
# Bigram: ('as', 'he'), Probability: 0.000624
# Bigram: ('deep', 'breath'), Probability: 0.000624
# Bigram: ('burglar', 'alarm'), Probability: 0.000624
# Bigram: ('no', 'one'), Probability: 0.000624
# Bigram: ('either', 'morrow'), Probability: 0.000624
# Bigram: ('time', 'in'), Probability: 0.000624
# Bigram: ('this', 'is'), Probability: 0.000624
# Bigram: ('the', 'front'), Probability: 0.000624
# Bigram: ('opened', 'the'), Probability: 0.000624
# Bigram: ('paul', 'were'), Probability: 0.000624
# Bigram: ('the', 'floor'), Probability: 0.000624
# Bigram: ('over', 'her'), Probability: 0.000624
# Bigram: ('a', 'quick'), Probability: 0.000624
# Bigram: ('he', 'turned'), Probability: 0.000624
# Bigram: ('it', 'said'), Probability: 0.000624
# Bigram: ('said', 'stacey'), Probability: 0.000624
# Bigram: ('not', 'the'), Probability: 0.000624
# Bigram: ('stacey', 'not'), Probability: 0.000624
# Bigram: ('run', 'for'), Probability: 0.000624
# Bigram: ('for', 'it'), Probability: 0.000624
# Bigram: ('as', 'you'), Probability: 0.000624
# Bigram: ('you', 'can'), Probability: 0.000624
# Bigram: ('and', 'nora'), Probability: 0.000624
# Bigram: ('house', 'and'), Probability: 0.000624
# Bigram: ('were', 'almost'), Probability: 0.000624
# Bigram: ('the', 'spacecraft'), Probability: 0.000624
# Bigram: ('it', 'no'), Probability: 0.000624
# Bigram: ('there', 'came'), Probability: 0.000624
# Bigram: ('came', 'the'), Probability: 0.000624
# Bigram: ('nora', 'i'), Probability: 0.000624
# Bigram: ('i', 'forgive'), Probability: 0.000624
# Bigram: ('the', 'dormitory'), Probability: 0.000624
# Bigram: ('hit', 'the'), Probability: 0.000624
# Bigram: ('the', 'headlights'), Probability: 0.000624
# Bigram: ('headlights', 'swung'), Probability: 0.000624
# Bigram: ('swung', 'around'), Probability: 0.000624
# Bigram: ('then', 'the'), Probability: 0.000624
# Bigram: ('the', 'jeeps'), Probability: 0.000624
# Bigram: ('to', 'keep'), Probability: 0.000624
# Bigram: ('them', 'the'), Probability: 0.000624
# Bigram: ('reached', 'the'), Probability: 0.000624
# Bigram: ('over', 'his'), Probability: 0.000624
# Bigram: ('his', 'shoulder'), Probability: 0.000624
# Bigram: ('running', 'away'), Probability: 0.000624
# Bigram: ('spacelock', 'and'), Probability: 0.000624
# Bigram: ('morrow', 'came'), Probability: 0.000624
# Bigram: ('paul', 'then'), Probability: 0.000624
# Bigram: ('shot', 'pinged'), Probability: 0.000624
# Bigram: ('pinged', 'against'), Probability: 0.000624
# Bigram: ('against', 'the'), Probability: 0.000624
# Bigram: ('control', 'room'), Probability: 0.000624
# Bigram: ('the', 'high'), Probability: 0.000624
# Bigram: ('high', 'drive'), Probability: 0.000624
# Bigram: ('waited', 'and'), Probability: 0.000624
# Bigram: ('and', 'waited'), Probability: 0.000624
# Bigram: ('it', 'takes'), Probability: 0.000624
# Bigram: ('like', 'most'), Probability: 0.000312
# Bigram: ('most', 'human'), Probability: 0.000312
# Bigram: ('human', 'beings'), Probability: 0.000312
# Bigram: ('beings', 'paul'), Probability: 0.000312
# Bigram: ('could', 'comprehend'), Probability: 0.000312
# Bigram: ('the', 'actions'), Probability: 0.000312
# Bigram: ('actions', 'of'), Probability: 0.000312
# Bigram: ('of', 'someone'), Probability: 0.000312
# Bigram: ('someone', 'of'), Probability: 0.000312
# Bigram: ('own', 'type'), Probability: 0.000312
# Bigram: ('type', 'but'), Probability: 0.000312
# Bigram: ('the', 'mental'), Probability: 0.000312
# Bigram: ('mental', 'machinations'), Probability: 0.000312
# Bigram: ('machinations', 'of'), Probability: 0.000312
# Bigram: ('of', 'people'), Probability: 0.000312
# Bigram: ('people', 'who'), Probability: 0.000312
# Bigram: ('had', 'other'), Probability: 0.000312
# Bigram: ('other', 'motives'), Probability: 0.000312
# Bigram: ('motives', 'and'), Probability: 0.000312
# Bigram: ('and', 'other'), Probability: 0.000312
# Bigram: ('other', 'interests'), Probability: 0.000312
# Bigram: ('interests', 'in'), Probability: 0.000312
# Bigram: ('in', 'life'), Probability: 0.000312
# Bigram: ('life', 'nor'), Probability: 0.000312
# Bigram: ('nor', 'could'), Probability: 0.000312
# Bigram: ('could', 'he'), Probability: 0.000312
# Bigram: ('he', 'seem'), Probability: 0.000312
# Bigram: ('seem', 'to'), Probability: 0.000312
# Bigram: ('make', 'other'), Probability: 0.000312
# Bigram: ('other', 'people'), Probability: 0.000312
# Bigram: ('people', 'understand'), Probability: 0.000312
# Bigram: ('understand', 'that'), Probability: 0.000312
# Bigram: ('that', 'his'), Probability: 0.000312
# Bigram: ('his', 'continued'), Probability: 0.000312
# Bigram: ('continued', 'interest'), Probability: 0.000312
# Bigram: ('zwave', 'was'), Probability: 0.000312
# Bigram: ('was', 'only'), Probability: 0.000312
# Bigram: ('only', 'just'), Probability: 0.000312
# Bigram: ('just', 'and'), Probability: 0.000312
# Bigram: ('and', 'sensible'), Probability: 0.000312
# Bigram: ('sensible', 'after'), Probability: 0.000312
# Bigram: ('after', 'all'), Probability: 0.000312
# Bigram: ('all', 'he'), Probability: 0.000312
# Bigram: ('had', 'never'), Probability: 0.000312
# Bigram: ('never', 'had'), Probability: 0.000312
# Bigram: ('had', 'an'), Probability: 0.000312
# Bigram: ('an', 'opportunity'), Probability: 0.000312
# Bigram: ('it', 'to'), Probability: 0.000312
# Bigram: ('paul', 'it'), Probability: 0.000312
# Bigram: ('just', 'that'), Probability: 0.000312
# Bigram: ('that', 'simple'), Probability: 0.000312
# Bigram: ('simple', 'just'), Probability: 0.000312
# Bigram: ('just', 'let'), Probability: 0.000312
# Bigram: ('him', 'try'), Probability: 0.000312
# Bigram: ('had', 'so'), Probability: 0.000312
# Bigram: ('so', 'much'), Probability: 0.000312
# Bigram: ('much', 'faith'), Probability: 0.000312
# Bigram: ('faith', 'in'), Probability: 0.000312
# Bigram: ('not', 'foresee'), Probability: 0.000312
# Bigram: ('foresee', 'his'), Probability: 0.000312
# Bigram: ('next', 'reaction'), Probability: 0.000312
# Bigram: ('reaction', 'if'), Probability: 0.000312
# Bigram: ('if', 'failure'), Probability: 0.000312
# Bigram: ('failure', 'came'), Probability: 0.000312
# Bigram: ('came', 'paul'), Probability: 0.000312
# Bigram: ('not', 'consider'), Probability: 0.000312
# Bigram: ('consider', 'failure'), Probability: 0.000312
# Bigram: ('failure', 'as'), Probability: 0.000312
# Bigram: ('a', 'possibility'), Probability: 0.000312
# Bigram: ('possibility', 'but'), Probability: 0.000312
# Bigram: ('but', 'if'), Probability: 0.000312
# Bigram: ('did', 'fail'), Probability: 0.000312
# Bigram: ('fail', 'he'), Probability: 0.000312
# Bigram: ('would', 'automatically'), Probability: 0.000312
# Bigram: ('automatically', 'begin'), Probability: 0.000312
# Bigram: ('begin', 'insisting'), Probability: 0.000312
# Bigram: ('insisting', 'upon'), Probability: 0.000312
# Bigram: ('upon', 'a'), Probability: 0.000312
# Bigram: ('to', 'continue'), Probability: 0.000312
# Bigram: ('continue', 'insisting'), Probability: 0.000312
# Bigram: ('insisting', 'that'), Probability: 0.000312
# Bigram: ('that', 'something'), Probability: 0.000312
# Bigram: ('something', 'had'), Probability: 0.000312
# Bigram: ('gone', 'awry'), Probability: 0.000312
# Bigram: ('awry', 'or'), Probability: 0.000312
# Bigram: ('or', 'that'), Probability: 0.000312
# Bigram: ('that', 'there'), Probability: 0.000312
# Bigram: ('were', 'factors'), Probability: 0.000312
# Bigram: ('factors', 'that'), Probability: 0.000312
# Bigram: ('that', 'must'), Probability: 0.000312
# Bigram: ('must', 'be'), Probability: 0.000312
# Bigram: ('be', 'studied'), Probability: 0.000312
# Bigram: ('studied', 'this'), Probability: 0.000312
# Bigram: ('this', 'sort'), Probability: 0.000312
# Bigram: ('of', 'attitude'), Probability: 0.000312
# Bigram: ('attitude', 'was'), Probability: 0.000312
# Bigram: ('was', 'acceptable'), Probability: 0.000312
# Bigram: ('acceptable', 'to'), Probability: 0.000312
# Bigram: ('paul', 'yet'), Probability: 0.000312
# Bigram: ('yet', 'he'), Probability: 0.000312
# Bigram: ('not', 'comprehend'), Probability: 0.000312
# Bigram: ('the', 'contemplated'), Probability: 0.000312
# Bigram: ('contemplated', 'action'), Probability: 0.000312
# Bigram: ('action', 'of'), Probability: 0.000312
# Bigram: ('political', 'factions'), Probability: 0.000312
# Bigram: ('factions', 'he'), Probability: 0.000312
# Bigram: ('was', 'involved'), Probability: 0.000312
# Bigram: ('involved', 'with'), Probability: 0.000312
# Bigram: ('with', 'for'), Probability: 0.000312
# Bigram: ('for', 'instance'), Probability: 0.000312
# Bigram: ('instance', 'one'), Probability: 0.000312
# Bigram: ('one', 'faction'), Probability: 0.000312
# Bigram: ('to', 'falsify'), Probability: 0.000312
# Bigram: ('falsify', 'evidence'), Probability: 0.000312
# Bigram: ('evidence', 'in'), Probability: 0.000312
# Bigram: ('to', 'swing'), Probability: 0.000312
# Bigram: ('swing', 'an'), Probability: 0.000312
# Bigram: ('an', 'election'), Probability: 0.000312
# Bigram: ('election', 'this'), Probability: 0.000312
# Bigram: ('this', 'seemed'), Probability: 0.000312
# Bigram: ('seemed', 'dishonest'), Probability: 0.000312
# Bigram: ('dishonest', 'to'), Probability: 0.000312
# Bigram: ('paul', 'he'), Probability: 0.000312
# Bigram: ('wondered', 'just'), Probability: 0.000312
# Bigram: ('just', 'how'), Probability: 0.000312
# Bigram: ('how', 'they'), Probability: 0.000312
# Bigram: ('could', 'justify'), Probability: 0.000312
# Bigram: ('their', 'act'), Probability: 0.000312
# Bigram: ('act', 'the'), Probability: 0.000312
# Bigram: ('other', 'faction'), Probability: 0.000312
# Bigram: ('keeping', 'him'), Probability: 0.000312
# Bigram: ('him', 'prisoner'), Probability: 0.000312
# Bigram: ('prisoner', 'so'), Probability: 0.000312
# Bigram: ('not', 'furnish'), Probability: 0.000312
# Bigram: ('furnish', 'any'), Probability: 0.000312
# Bigram: ('evidence', 'at'), Probability: 0.000312
# Bigram: ('at', 'all'), Probability: 0.000312
# Bigram: ('all', 'but'), Probability: 0.000312
# Bigram: ('but', 'eventually'), Probability: 0.000312
# Bigram: ('eventually', 'one'), Probability: 0.000312
# Bigram: ('side', 'or'), Probability: 0.000312
# Bigram: ('or', 'the'), Probability: 0.000312
# Bigram: ('other', 'was'), Probability: 0.000312
# Bigram: ('to', 'find'), Probability: 0.000312
# Bigram: ('find', 'that'), Probability: 0.000312
# Bigram: ('that', 'its'), Probability: 0.000312
# Bigram: ('its', 'evidence'), Probability: 0.000312
# Bigram: ('evidence', 'was'), Probability: 0.000312
# Bigram: ('was', 'in'), Probability: 0.000312
# Bigram: ('in', 'error'), Probability: 0.000312
# Bigram: ('error', 'then'), Probability: 0.000312
# Bigram: ('then', 'what'), Probability: 0.000312
# Bigram: ('what', 'supposing'), Probability: 0.000312
# Bigram: ('supposing', 'because'), Probability: 0.000312
# Bigram: ('because', 'he'), Probability: 0.000312
# Bigram: ('been', 'kidnaped'), Probability: 0.000312
# Bigram: ('kidnaped', 'by'), Probability: 0.000312
# Bigram: ('by', 'this'), Probability: 0.000312
# Bigram: ('this', 'particular'), Probability: 0.000312
# Bigram: ('particular', 'gang'), Probability: 0.000312
# Bigram: ('gang', 'and'), Probability: 0.000312
# Bigram: ('and', 'thus'), Probability: 0.000312
# Bigram: ('thus', 'gave'), Probability: 0.000312
# Bigram: ('gave', 'some'), Probability: 0.000312
# Bigram: ('some', 'concrete'), Probability: 0.000312
# Bigram: ('concrete', 'evidence'), Probability: 0.000312
# Bigram: ('evidence', 'of'), Probability: 0.000312
# Bigram: ('of', 'negative'), Probability: 0.000312
# Bigram: ('negative', 'result'), Probability: 0.000312
# Bigram: ('result', 'hoagland'), Probability: 0.000312
# Bigram: ('hoagland', 'and'), Probability: 0.000312
# Bigram: ('and', 'westlake'), Probability: 0.000312
# Bigram: ('the', 'rest'), Probability: 0.000312
# Bigram: ('rest', 'were'), Probability: 0.000312
# Bigram: ('were', 'electedafter'), Probability: 0.000312
# Bigram: ('electedafter', 'which'), Probability: 0.000312
# Bigram: ('which', 'the'), Probability: 0.000312
# Bigram: ('contact', 'proved'), Probability: 0.000312
# Bigram: ('proved', 'good'), Probability: 0.000312
# Bigram: ('good', 'or'), Probability: 0.000312
# Bigram: ('or', 'if'), Probability: 0.000312
# Bigram: ('if', 'huston'), Probability: 0.000312
# Bigram: ('his', 'crowd'), Probability: 0.000312
# Bigram: ('crowd', 'got'), Probability: 0.000312
# Bigram: ('got', 'elected'), Probability: 0.000312
# Bigram: ('elected', 'on'), Probability: 0.000312
# Bigram: ('the', 'strength'), Probability: 0.000312
# Bigram: ('strength', 'of'), Probability: 0.000312
# Bigram: ('then', 'because'), Probability: 0.000312
# Bigram: ('because', 'paul'), Probability: 0.000312
# Bigram: ('was', 'captive'), Probability: 0.000312
# Bigram: ('captive', 'and'), Probability: 0.000312
# Bigram: ('and', 'unable'), Probability: 0.000312
# Bigram: ('unable', 'to'), Probability: 0.000312
# Bigram: ('make', 'it'), Probability: 0.000312
# Bigram: ('it', 'work'), Probability: 0.000312
# Bigram: ('work', 'there'), Probability: 0.000312
# Bigram: ('no', 'zwave'), Probability: 0.000312
# Bigram: ('zwave', 'communication'), Probability: 0.000312
# Bigram: ('communication', 'with'), Probability: 0.000312
# Bigram: ('terra', 'how'), Probability: 0.000312
# Bigram: ('how', 'could'), Probability: 0.000312
# Bigram: ('could', 'they'), Probability: 0.000312
# Bigram: ('they', 'justify'), Probability: 0.000312
# Bigram: ('their', 'claims'), Probability: 0.000312
# Bigram: ('claims', 'in'), Probability: 0.000312
# Bigram: ('the', 'face'), Probability: 0.000312
# Bigram: ('the', 'emptiness'), Probability: 0.000312
# Bigram: ('emptiness', 'of'), Probability: 0.000312
# Bigram: ('of', 'their'), Probability: 0.000312
# Bigram: ('their', 'prophecies'), Probability: 0.000312
# Bigram: ('prophecies', 'paul'), Probability: 0.000312
# Bigram: ('political', 'mind'), Probability: 0.000312
# Bigram: ('mind', 'and'), Probability: 0.000312
# Bigram: ('the', 'thinking'), Probability: 0.000312
# Bigram: ('thinking', 'of'), Probability: 0.000312
# Bigram: ('the', 'man'), Probability: 0.000312
# Bigram: ('man', 'on'), Probability: 0.000312
# Bigram: ('the', 'street'), Probability: 0.000312
# Bigram: ('street', 'he'), Probability: 0.000312
# Bigram: ('not', 'even'), Probability: 0.000312
# Bigram: ('even', 'apply'), Probability: 0.000312
# Bigram: ('apply', 'such'), Probability: 0.000312
# Bigram: ('such', 'thinking'), Probability: 0.000312
# Bigram: ('thinking', 'to'), Probability: 0.000312
# Bigram: ('own', 'case'), Probability: 0.000312
# Bigram: ('case', 'the'), Probability: 0.000312
# Bigram: ('that', 'for'), Probability: 0.000312
# Bigram: ('for', 'eons'), Probability: 0.000312
# Bigram: ('eons', 'politicians'), Probability: 0.000312
# Bigram: ('politicians', 'have'), Probability: 0.000312
# Bigram: ('have', 'been'), Probability: 0.000312
# Bigram: ('been', 'making'), Probability: 0.000312
# Bigram: ('making', 'promises'), Probability: 0.000312
# Bigram: ('promises', 'that'), Probability: 0.000312
# Bigram: ('that', 'were'), Probability: 0.000312
# Bigram: ('were', 'unfulfilled'), Probability: 0.000312
# Bigram: ('unfulfilled', 'after'), Probability: 0.000312
# Bigram: ('after', 'election'), Probability: 0.000312
# Bigram: ('election', 'did'), Probability: 0.000312
# Bigram: ('not', 'register'), Probability: 0.000312
# Bigram: ('register', 'with'), Probability: 0.000312
# Bigram: ('grayson', 'the'), Probability: 0.000312
# Bigram: ('do', 'of'), Probability: 0.000312
# Bigram: ('to', 'escape'), Probability: 0.000312
# Bigram: ('escape', 'then'), Probability: 0.000312
# Bigram: ('could', 'work'), Probability: 0.000312
# Bigram: ('work', 'and'), Probability: 0.000312
# Bigram: ('and', 'bring'), Probability: 0.000312
# Bigram: ('bring', 'out'), Probability: 0.000312
# Bigram: ('out', 'the'), Probability: 0.000312
# Bigram: ('the', 'truthwhich'), Probability: 0.000312
# Bigram: ('truthwhich', 'to'), Probability: 0.000312
# Bigram: ('was', 'singlevalued'), Probability: 0.000312
# Bigram: ('singlevalued', 'and'), Probability: 0.000312
# Bigram: ('and', 'positiveand'), Probability: 0.000312
# Bigram: ('positiveand', 'thus'), Probability: 0.000312
# Bigram: ('thus', 'do'), Probability: 0.000312
# Bigram: ('do', 'away'), Probability: 0.000312
# Bigram: ('with', 'all'), Probability: 0.000312
# Bigram: ('the', 'halftruths'), Probability: 0.000312
# Bigram: ('halftruths', 'lies'), Probability: 0.000312
# Bigram: ('lies', 'and'), Probability: 0.000312
# Bigram: ('and', 'fingerscrossed'), Probability: 0.000312
# Bigram: ('fingerscrossed', 'statements'), Probability: 0.000312
# Bigram: ('but', 'how'), Probability: 0.000312
# Bigram: ('how', 'he'), Probability: 0.000312
# Bigram: ('had', 'to'), Probability: 0.000312
# Bigram: ('to', 'admit'), Probability: 0.000312
# Bigram: ('admit', 'that'), Probability: 0.000312
# Bigram: ('not', 'illtreated'), Probability: 0.000312
# Bigram: ('illtreated', 'he'), Probability: 0.000312
# Bigram: ('he', 'believed'), Probability: 0.000312
# Bigram: ('believed', 'that'), Probability: 0.000312
# Bigram: ('that', 'both'), Probability: 0.000312
# Bigram: ('both', 'sides'), Probability: 0.000312
# Bigram: ('sides', 'were'), Probability: 0.000312
# Bigram: ('were', 'willing'), Probability: 0.000312
# Bigram: ('have', 'zwave'), Probability: 0.000312
# Bigram: ('contact', 'with'), Probability: 0.000312
# Bigram: ('terra', 'for'), Probability: 0.000312
# Bigram: ('for', 'commercial'), Probability: 0.000312
# Bigram: ('commercial', 'reasons'), Probability: 0.000312
# Bigram: ('reasons', 'but'), Probability: 0.000312
# Bigram: ('he', 'knew'), Probability: 0.000312
# Bigram: ('that', 'only'), Probability: 0.000312
# Bigram: ('side', 'wanted'), Probability: 0.000312
# Bigram: ('wanted', 'communications'), Probability: 0.000312
# Bigram: ('communications', 'now'), Probability: 0.000312
# Bigram: ('now', 'ergo'), Probability: 0.000312
# Bigram: ('ergo', 'the'), Probability: 0.000312
# Bigram: ('the', 'opposing'), Probability: 0.000312
# Bigram: ('opposing', 'side'), Probability: 0.000312
# Bigram: ('side', 'which'), Probability: 0.000312
# Bigram: ('which', 'were'), Probability: 0.000312
# Bigram: ('were', 'his'), Probability: 0.000312
# Bigram: ('his', 'captors'), Probability: 0.000312
# Bigram: ('captors', 'would'), Probability: 0.000312
# Bigram: ('would', 'treat'), Probability: 0.000312
# Bigram: ('treat', 'him'), Probability: 0.000312
# Bigram: ('him', 'well'), Probability: 0.000312
# Bigram: ('well', 'in'), Probability: 0.000312
# Bigram: ('of', 'having'), Probability: 0.000312
# Bigram: ('having', 'him'), Probability: 0.000312
# Bigram: ('work', 'for'), Probability: 0.000312
# Bigram: ('them', 'once'), Probability: 0.000312
# Bigram: ('the', 'election'), Probability: 0.000312
# Bigram: ('election', 'was'), Probability: 0.000312
# Bigram: ('was', 'over'), Probability: 0.000312
# Bigram: ('over', 'paul'), Probability: 0.000312
# Bigram: ('paul', 'shrugged'), Probability: 0.000312
# Bigram: ('shrugged', 'whatever'), Probability: 0.000312
# Bigram: ('whatever', 'the'), Probability: 0.000312
# Bigram: ('the', 'cause'), Probability: 0.000312
# Bigram: ('cause', 'he'), Probability: 0.000312
# Bigram: ('not', 'cut'), Probability: 0.000312
# Bigram: ('cut', 'off'), Probability: 0.000312
# Bigram: ('off', 'his'), Probability: 0.000312
# Bigram: ('his', 'nose'), Probability: 0.000312
# Bigram: ('nose', 'to'), Probability: 0.000312
# Bigram: ('to', 'spite'), Probability: 0.000312
# Bigram: ('spite', 'his'), Probability: 0.000312
# Bigram: ('his', 'face'), Probability: 0.000312
# Bigram: ('face', 'his'), Probability: 0.000312
# Bigram: ('his', 'was'), Probability: 0.000312
# Bigram: ('no', 'interest'), Probability: 0.000312
# Bigram: ('in', 'political'), Probability: 0.000312
# Bigram: ('political', 'fray'), Probability: 0.000312
# Bigram: ('fray', 'he'), Probability: 0.000312
# Bigram: ('he', 'wanted'), Probability: 0.000312
# Bigram: ('wanted', 'to'), Probability: 0.000312
# Bigram: ('fact', 'westlake'), Probability: 0.000312
# Bigram: ('and', 'hoagland'), Probability: 0.000312
# Bigram: ('hoagland', 'had'), Probability: 0.000312
# Bigram: ('had', 'one'), Probability: 0.000312
# Bigram: ('one', 'facet'), Probability: 0.000312
# Bigram: ('that', 'looked'), Probability: 0.000312
# Bigram: ('looked', 'reasonably'), Probability: 0.000312
# Bigram: ('reasonably', 'good'), Probability: 0.000312
# Bigram: ('good', 'their'), Probability: 0.000312
# Bigram: ('their', 'party'), Probability: 0.000312
# Bigram: ('party', 'was'), Probability: 0.000312
# Bigram: ('was', 'for'), Probability: 0.000312
# Bigram: ('for', 'autonomy'), Probability: 0.000312
# Bigram: ('autonomy', 'and'), Probability: 0.000312
# Bigram: ('and', 'if'), Probability: 0.000312
# Bigram: ('if', 'paul'), Probability: 0.000312
# Bigram: ('paul', 'worked'), Probability: 0.000312
# Bigram: ('worked', 'for'), Probability: 0.000312
# Bigram: ('them', 'he'), Probability: 0.000312
# Bigram: ('be', 'forever'), Probability: 0.000312
# Bigram: ('forever', 'free'), Probability: 0.000312
# Bigram: ('free', 'of'), Probability: 0.000312
# Bigram: ('of', 'any'), Probability: 0.000312
# Bigram: ('any', 'legal'), Probability: 0.000312
# Bigram: ('legal', 'attachment'), Probability: 0.000312
# Bigram: ('attachment', 'to'), Probability: 0.000312
# Bigram: ('to', 'terra'), Probability: 0.000312
# Bigram: ('and', 'doubtless'), Probability: 0.000312
# Bigram: ('doubtless', 'haedaecker'), Probability: 0.000312
# Bigram: ('haedaecker', 'and'), Probability: 0.000312
# Bigram: ('whole', 'bureau'), Probability: 0.000312
# Bigram: ('bureau', 'of'), Probability: 0.000312
# Bigram: ('of', 'astrogation'), Probability: 0.000312
# Bigram: ('astrogation', 'were'), Probability: 0.000312
# Bigram: ('were', 'out'), Probability: 0.000312
# Bigram: ('out', 'gunning'), Probability: 0.000312
# Bigram: ('gunning', 'for'), Probability: 0.000312
# Bigram: ('for', 'paul'), Probability: 0.000312
# Bigram: ('grayson', 'if'), Probability: 0.000312
# Bigram: ('if', 'for'), Probability: 0.000312
# Bigram: ('for', 'no'), Probability: 0.000312
# Bigram: ('no', 'other'), Probability: 0.000312
# Bigram: ('other', 'reason'), Probability: 0.000312
# Bigram: ('reason', 'than'), Probability: 0.000312
# Bigram: ('than', 'the'), Probability: 0.000312
# Bigram: ('the', 'stolen'), Probability: 0.000312
# Bigram: ('stolen', 'burast'), Probability: 0.000312
# Bigram: ('burast', 'pg'), Probability: 0.000312
# Bigram: ('pg', 'were'), Probability: 0.000312
# Bigram: ('were', 'huston'), Probability: 0.000312
# Bigram: ('his', 'coalition'), Probability: 0.000312
# Bigram: ('coalition', 'government'), Probability: 0.000312
# Bigram: ('government', 'to'), Probability: 0.000312
# Bigram: ('get', 'in'), Probability: 0.000312
# Bigram: ('in', 'haedaecker'), Probability: 0.000312
# Bigram: ('haedaecker', 'could'), Probability: 0.000312
# Bigram: ('could', 'swing'), Probability: 0.000312
# Bigram: ('swing', 'a'), Probability: 0.000312
# Bigram: ('large', 'club'), Probability: 0.000312
# Bigram: ('club', 'over'), Probability: 0.000312
# Bigram: ('over', 'the'), Probability: 0.000312
# Bigram: ('the', 'various'), Probability: 0.000312
# Bigram: ('various', 'integrated'), Probability: 0.000312
# Bigram: ('integrated', 'wings'), Probability: 0.000312
# Bigram: ('wings', 'of'), Probability: 0.000312
# Bigram: ('of', 'government'), Probability: 0.000312
# Bigram: ('government', 'and'), Probability: 0.000312
# Bigram: ('and', 'make'), Probability: 0.000312
# Bigram: ('make', 'pauls'), Probability: 0.000312
# Bigram: ('pauls', 'life'), Probability: 0.000312
# Bigram: ('life', 'precarious'), Probability: 0.000312
# Bigram: ('precarious', 'so'), Probability: 0.000312
# Bigram: ('was', 'on'), Probability: 0.000312
# Bigram: ('the', 'fence'), Probability: 0.000312
# Bigram: ('fence', 'so'), Probability: 0.000312
# Bigram: ('far', 'as'), Probability: 0.000312
# Bigram: ('as', 'his'), Probability: 0.000312
# Bigram: ('his', 'work'), Probability: 0.000312
# Bigram: ('work', 'was'), Probability: 0.000312
# Bigram: ('was', 'concerned'), Probability: 0.000312
# Bigram: ('concerned', 'in'), Probability: 0.000312
# Bigram: ('fact', 'at'), Probability: 0.000312
# Bigram: ('the', 'present'), Probability: 0.000312
# Bigram: ('present', 'moment'), Probability: 0.000312
# Bigram: ('moment', 'paul'), Probability: 0.000312
# Bigram: ('think', 'highly'), Probability: 0.000312
# Bigram: ('highly', 'of'), Probability: 0.000312
# Bigram: ('of', 'either'), Probability: 0.000312
# Bigram: ('either', 'political'), Probability: 0.000312
# Bigram: ('political', 'ambition'), Probability: 0.000312
# Bigram: ('ambition', 'since'), Probability: 0.000312
# Bigram: ('since', 'their'), Probability: 0.000312
# Bigram: ('their', 'high'), Probability: 0.000312
# Bigram: ('high', 'ambition'), Probability: 0.000312
# Bigram: ('ambition', 'was'), Probability: 0.000312
# Bigram: ('was', 'tarred'), Probability: 0.000312
# Bigram: ('tarred', 'with'), Probability: 0.000312
# Bigram: ('a', 'wide'), Probability: 0.000312
# Bigram: ('wide', 'full'), Probability: 0.000312
# Bigram: ('full', 'brush'), Probability: 0.000312
# Bigram: ('brush', 'of'), Probability: 0.000312
# Bigram: ('of', 'downright'), Probability: 0.000312
# Bigram: ('downright', 'thuggery'), Probability: 0.000312
# Bigram: ('thuggery', 'escape'), Probability: 0.000312
# Bigram: ('escape', 'of'), Probability: 0.000312
# Bigram: ('was', 'an'), Probability: 0.000312
# Bigram: ('an', 'easy'), Probability: 0.000312
# Bigram: ('easy', 'word'), Probability: 0.000312
# Bigram: ('word', 'to'), Probability: 0.000312
# Bigram: ('to', 'say'), Probability: 0.000312
# Bigram: ('say', 'it'), Probability: 0.000312
# Bigram: ('true', 'that'), Probability: 0.000312
# Bigram: ('that', 'pauls'), Probability: 0.000312
# Bigram: ('pauls', 'incarceration'), Probability: 0.000312
# Bigram: ('incarceration', 'was'), Probability: 0.000312
# Bigram: ('was', 'nothing'), Probability: 0.000312
# Bigram: ('nothing', 'like'), Probability: 0.000312
# Bigram: ('like', 'being'), Probability: 0.000312
# Bigram: ('being', 'cooped'), Probability: 0.000312
# Bigram: ('cooped', 'up'), Probability: 0.000312
# Bigram: ('a', 'jail'), Probability: 0.000312
# Bigram: ('jail', 'cell'), Probability: 0.000312
# Bigram: ('cell', 'his'), Probability: 0.000312
# Bigram: ('his', 'door'), Probability: 0.000312
# Bigram: ('was', 'closed'), Probability: 0.000312
# Bigram: ('closed', 'but'), Probability: 0.000312
# Bigram: ('not', 'locked'), Probability: 0.000312
# Bigram: ('locked', 'he'), Probability: 0.000312
# Bigram: ('had', 'plenty'), Probability: 0.000312
# Bigram: ('plenty', 'of'), Probability: 0.000312
# Bigram: ('of', 'time'), Probability: 0.000312
# Bigram: ('and', 'opportunity'), Probability: 0.000312
# Bigram: ('to', 'see'), Probability: 0.000312
# Bigram: ('see', 'and'), Probability: 0.000312
# Bigram: ('and', 'talk'), Probability: 0.000312
# Bigram: ('talk', 'to'), Probability: 0.000312
# Bigram: ('to', 'both'), Probability: 0.000312
# Bigram: ('both', 'nora'), Probability: 0.000312
# Bigram: ('and', 'john'), Probability: 0.000312
# Bigram: ('and', 'to'), Probability: 0.000312
# Bigram: ('make', 'friends'), Probability: 0.000312
# Bigram: ('friends', 'with'), Probability: 0.000312
# Bigram: ('with', 'other'), Probability: 0.000312
# Bigram: ('other', 'political'), Probability: 0.000312
# Bigram: ('political', 'prisoners'), Probability: 0.000312
# Bigram: ('prisoners', 'across'), Probability: 0.000312
# Bigram: ('plain', 'was'), Probability: 0.000312
# Bigram: ('a', 'spaceport'), Probability: 0.000312
# Bigram: ('spaceport', 'and'), Probability: 0.000312
# Bigram: ('and', 'some'), Probability: 0.000312
# Bigram: ('some', 'spacecraft'), Probability: 0.000312
# Bigram: ('spacecraft', 'that'), Probability: 0.000312
# Bigram: ('that', 'came'), Probability: 0.000312
# Bigram: ('came', 'and'), Probability: 0.000312
# Bigram: ('went', 'but'), Probability: 0.000312
# Bigram: ('but', 'going'), Probability: 0.000312
# Bigram: ('going', 'there'), Probability: 0.000312
# Bigram: ('there', 'and'), Probability: 0.000312
# Bigram: ('and', 'taking'), Probability: 0.000312
# Bigram: ('off', 'presented'), Probability: 0.000312
# Bigram: ('presented', 'the'), Probability: 0.000312
# Bigram: ('problem', 'of'), Probability: 0.000312
# Bigram: ('of', 'getting'), Probability: 0.000312
# Bigram: ('getting', 'away'), Probability: 0.000312
# Bigram: ('with', 'it'), Probability: 0.000312
# Bigram: ('somewhat', 'reminded'), Probability: 0.000312
# Bigram: ('reminded', 'of'), Probability: 0.000312
# Bigram: ('the', 'signs'), Probability: 0.000312
# Bigram: ('signs', 'reputed'), Probability: 0.000312
# Bigram: ('reputed', 'to'), Probability: 0.000312
# Bigram: ('be', 'placed'), Probability: 0.000312
# Bigram: ('placed', 'around'), Probability: 0.000312
# Bigram: ('around', 'the'), Probability: 0.000312
# Bigram: ('the', 'penal'), Probability: 0.000312
# Bigram: ('penal', 'grounds'), Probability: 0.000312
# Bigram: ('grounds', 'on'), Probability: 0.000312
# Bigram: ('on', 'antarctica'), Probability: 0.000312
# Bigram: ('antarctica', 'there'), Probability: 0.000312
# Bigram: ('were', 'maps'), Probability: 0.000312
# Bigram: ('maps', 'of'), Probability: 0.000312
# Bigram: ('the', 'south'), Probability: 0.000312
# Bigram: ('south', 'polar'), Probability: 0.000312
# Bigram: ('region', 'of'), Probability: 0.000312
# Bigram: ('of', 'terra'), Probability: 0.000312
# Bigram: ('with', 'latitude'), Probability: 0.000312
# Bigram: ('latitude', 'longitude'), Probability: 0.000312
# Bigram: ('longitude', 'and'), Probability: 0.000312
# Bigram: ('distance', 'in'), Probability: 0.000312
# Bigram: ('in', 'miles'), Probability: 0.000312
# Bigram: ('miles', 'from'), Probability: 0.000312
# Bigram: ('the', 'penitentiary'), Probability: 0.000312
# Bigram: ('penitentiary', 'to'), Probability: 0.000312
# Bigram: ('the', 'nearest'), Probability: 0.000312
# Bigram: ('nearest', 'shred'), Probability: 0.000312
# Bigram: ('shred', 'of'), Probability: 0.000312
# Bigram: ('of', 'civilization'), Probability: 0.000312
# Bigram: ('civilization', 'carefully'), Probability: 0.000312
# Bigram: ('carefully', 'and'), Probability: 0.000312
# Bigram: ('and', 'accurately'), Probability: 0.000312
# Bigram: ('accurately', 'marked'), Probability: 0.000312
# Bigram: ('marked', 'listed'), Probability: 0.000312
# Bigram: ('listed', 'below'), Probability: 0.000312
# Bigram: ('below', 'the'), Probability: 0.000312
# Bigram: ('the', 'maps'), Probability: 0.000312
# Bigram: ('maps', 'was'), Probability: 0.000312
# Bigram: ('a', 'roster'), Probability: 0.000312
# Bigram: ('roster', 'of'), Probability: 0.000312
# Bigram: ('of', 'average'), Probability: 0.000312
# Bigram: ('average', 'temperatures'), Probability: 0.000312
# Bigram: ('temperatures', 'for'), Probability: 0.000312
# Bigram: ('the', 'district'), Probability: 0.000312
# Bigram: ('district', 'at'), Probability: 0.000312
# Bigram: ('at', 'any'), Probability: 0.000312
# Bigram: ('any', 'time'), Probability: 0.000312
# Bigram: ('time', 'of'), Probability: 0.000312
# Bigram: ('year', 'and'), Probability: 0.000312
# Bigram: ('whole', 'thing'), Probability: 0.000312
# Bigram: ('thing', 'was'), Probability: 0.000312
# Bigram: ('a', 'great'), Probability: 0.000312
# Bigram: ('great', 'deterrent'), Probability: 0.000312
# Bigram: ('deterrent', 'to'), Probability: 0.000312
# Bigram: ('to', 'walking'), Probability: 0.000312
# Bigram: ('walking', 'out'), Probability: 0.000312
# Bigram: ('the', 'place'), Probability: 0.000312
# Bigram: ('place', 'and'), Probability: 0.000312
# Bigram: ('and', 'trying'), Probability: 0.000312
# Bigram: ('to', 'cross'), Probability: 0.000312
# Bigram: ('cross', 'a'), Probability: 0.000312
# Bigram: ('few', 'thousand'), Probability: 0.000312
# Bigram: ('thousand', 'miles'), Probability: 0.000312
# Bigram: ('miles', 'of'), Probability: 0.000312
# Bigram: ('of', 'very'), Probability: 0.000312
# Bigram: ('very', 'cold'), Probability: 0.000312
# Bigram: ('cold', 'nothing'), Probability: 0.000312
# Bigram: ('get', 'to'), Probability: 0.000312
# Bigram: ('to', 'one'), Probability: 0.000312
# Bigram: ('of', 'civilizations'), Probability: 0.000312
# Bigram: ('civilizations', 'southern'), Probability: 0.000312
# Bigram: ('southern', 'outpostswhere'), Probability: 0.000312
# Bigram: ('outpostswhere', 'the'), Probability: 0.000312
# Bigram: ('the', 'escapees'), Probability: 0.000312
# Bigram: ('escapees', 'name'), Probability: 0.000312
# Bigram: ('name', 'would'), Probability: 0.000312
# Bigram: ('be', 'posted'), Probability: 0.000312
# Bigram: ('posted', 'long'), Probability: 0.000312
# Bigram: ('long', 'before'), Probability: 0.000312
# Bigram: ('could', 'arrive'), Probability: 0.000312
# Bigram: ('arrive', 'the'), Probability: 0.000312
# Bigram: ('only', 'way'), Probability: 0.000312
# Bigram: ('man', 'could'), Probability: 0.000312
# Bigram: ('could', 'escape'), Probability: 0.000312
# Bigram: ('escape', 'was'), Probability: 0.000312
# Bigram: ('have', 'some'), Probability: 0.000312
# Bigram: ('some', 'means'), Probability: 0.000312
# Bigram: ('communication', 'so'), Probability: 0.000312
# Bigram: ('that', 'friends'), Probability: 0.000312
# Bigram: ('friends', 'could'), Probability: 0.000312
# Bigram: ('could', 'come'), Probability: 0.000312
# Bigram: ('come', 'to'), Probability: 0.000312
# Bigram: ('his', 'aid'), Probability: 0.000312
# Bigram: ('aid', 'pauls'), Probability: 0.000312
# Bigram: ('pauls', 'only'), Probability: 0.000312
# Bigram: ('only', 'method'), Probability: 0.000312
# Bigram: ('method', 'of'), Probability: 0.000312
# Bigram: ('of', 'contact'), Probability: 0.000312
# Bigram: ('contact', 'was'), Probability: 0.000312
# Bigram: ('zwave', 'they'), Probability: 0.000312
# Bigram: ('did', 'let'), Probability: 0.000312
# Bigram: ('let', 'paul'), Probability: 0.000312
# Bigram: ('paul', 'tinker'), Probability: 0.000312
# Bigram: ('tinker', 'and'), Probability: 0.000312
# Bigram: ('and', 'they'), Probability: 0.000312
# Bigram: ('they', 'even'), Probability: 0.000312
# Bigram: ('even', 'let'), Probability: 0.000312
# Bigram: ('work', 'but'), Probability: 0.000312
# Bigram: ('they', 'would'), Probability: 0.000312
# Bigram: ('not', 'let'), Probability: 0.000312
# Bigram: ('him', 'near'), Probability: 0.000312
# Bigram: ('near', 'zwave'), Probability: 0.000312
# Bigram: ('zwave', 'equipment'), Probability: 0.000312
# Bigram: ('equipment', 'that'), Probability: 0.000312
# Bigram: ('was', 'connected'), Probability: 0.000312
# Bigram: ('connected', 'with'), Probability: 0.000312
# Bigram: ('beacon', 'toby'), Probability: 0.000312
# Bigram: ('toby', 'morrow'), Probability: 0.000312
# Bigram: ('morrow', 'helped'), Probability: 0.000312
# Bigram: ('helped', 'paul'), Probability: 0.000312
# Bigram: ('paul', 'with'), Probability: 0.000312
# Bigram: ('with', 'calculations'), Probability: 0.000312
# Bigram: ('calculations', 'and'), Probability: 0.000312
# Bigram: ('and', 'theory'), Probability: 0.000312
# Bigram: ('theory', 'being'), Probability: 0.000312
# Bigram: ('being', 'the'), Probability: 0.000312
# Bigram: ('one', 'among'), Probability: 0.000312
# Bigram: ('among', 'the'), Probability: 0.000312
# Bigram: ('prisoners', 'who'), Probability: 0.000312
# Bigram: ('had', 'done'), Probability: 0.000312
# Bigram: ('done', 'any'), Probability: 0.000312
# Bigram: ('any', 'work'), Probability: 0.000312
# Bigram: ('grayson', 'morrow'), Probability: 0.000312
# Bigram: ('morrow', 'of'), Probability: 0.000312
# ...
# Bigram: ('tripped', 'over'), Probability: 0.000312
# Bigram: ('her', 'sprawling'), Probability: 0.000312
# Bigram: ('sprawling', 'ankle'), Probability: 0.000312
# Bigram: ('ankle', 'caught'), Probability: 0.000312
# Bigram: ('caught', 'the'), Probability: 0.000312
# Bigram: ('the', 'flipper'), Probability: 0.000312
# Bigram: ('flipper', 'switch'), Probability: 0.000312
# Bigram: ('switch', 'to'), Probability: 0.000312
# Bigram: ('door', 'as'), Probability: 0.000312
# Bigram: ('he', 'fell'), Probability: 0.000312
# Bigram: ('fell', 'and'), Probability: 0.000312
# Bigram: ('and', 'scrambled'), Probability: 0.000312
# Bigram: ('scrambled', 'to'), Probability: 0.000312
# Bigram: ('his', 'feet'), Probability: 0.000312
# Bigram: ('feet', 'as'), Probability: 0.000312
# Bigram: ('spacelock', 'door'), Probability: 0.000312
# Bigram: ('door', 'started'), Probability: 0.000312
# Bigram: ('started', 'to'), Probability: 0.000312
# Bigram: ('to', 'close'), Probability: 0.000312
# Bigram: ('close', 'the'), Probability: 0.000312
# Bigram: ('engine', 'still'), Probability: 0.000312
# Bigram: ('still', 'came'), Probability: 0.000312
# Bigram: ('came', 'through'), Probability: 0.000312
# Bigram: ('the', 'closing'), Probability: 0.000312
# Bigram: ('closing', 'slit'), Probability: 0.000312
# Bigram: ('slit', 'a'), Probability: 0.000312
# Bigram: ('a', 'shot'), Probability: 0.000312
# Bigram: ('the', 'steel'), Probability: 0.000312
# Bigram: ('steel', 'hull'), Probability: 0.000312
# Bigram: ('hull', 'paul'), Probability: 0.000312
# Bigram: ('paul', 'forgot'), Probability: 0.000312
# Bigram: ('forgot', 'about'), Probability: 0.000312
# Bigram: ('and', 'headed'), Probability: 0.000312
# Bigram: ('headed', 'up'), Probability: 0.000312
# Bigram: ('the', 'runway'), Probability: 0.000312
# Bigram: ('runway', 'to'), Probability: 0.000312
# Bigram: ('room', 'he'), Probability: 0.000312
# Bigram: ('he', 'hit'), Probability: 0.000312
# Bigram: ('control', 'panel'), Probability: 0.000312
# Bigram: ('panel', 'with'), Probability: 0.000312
# Bigram: ('with', 'both'), Probability: 0.000312
# Bigram: ('both', 'hands'), Probability: 0.000312
# Bigram: ('hands', 'flipped'), Probability: 0.000312
# Bigram: ('flipped', 'the'), Probability: 0.000312
# Bigram: ('the', 'warmup'), Probability: 0.000312
# Bigram: ('warmup', 'switch'), Probability: 0.000312
# Bigram: ('switch', 'and'), Probability: 0.000312
# Bigram: ('the', 'lowdrive'), Probability: 0.000312
# Bigram: ('lowdrive', 'at'), Probability: 0.000312
# Bigram: ('time', 'it'), Probability: 0.000312
# Bigram: ('a', 'ragged'), Probability: 0.000312
# Bigram: ('ragged', 'takeoff'), Probability: 0.000312
# Bigram: ('takeoff', 'with'), Probability: 0.000312
# Bigram: ('ship', 'rising'), Probability: 0.000312
# Bigram: ('rising', 'as'), Probability: 0.000312
# Bigram: ('the', 'driving'), Probability: 0.000312
# Bigram: ('driving', 'generators'), Probability: 0.000312
# Bigram: ('generators', 'warmed'), Probability: 0.000312
# Bigram: ('warmed', 'up'), Probability: 0.000312
# Bigram: ('up', 'instead'), Probability: 0.000312
# Bigram: ('of', 'taking'), Probability: 0.000312
# Bigram: ('off', 'with'), Probability: 0.000312
# Bigram: ('a', 'hot'), Probability: 0.000312
# Bigram: ('hot', 'drive'), Probability: 0.000312
# Bigram: ('drive', 'he'), Probability: 0.000312
# Bigram: ('he', 'waited'), Probability: 0.000312
# Bigram: ('waited', 'with'), Probability: 0.000312
# Bigram: ('one', 'hand'), Probability: 0.000312
# Bigram: ('hand', 'on'), Probability: 0.000312
# Bigram: ('drive', 'switch'), Probability: 0.000312
# Bigram: ('switch', 'waited'), Probability: 0.000312
# Bigram: ('waited', 'another'), Probability: 0.000312
# Bigram: ('another', 'shot'), Probability: 0.000312
# Bigram: ('the', 'hull'), Probability: 0.000312
# Bigram: ('hull', 'one'), Probability: 0.000312
# Bigram: ('one', 'glanced'), Probability: 0.000312
# Bigram: ('glanced', 'from'), Probability: 0.000312
# Bigram: ('the', 'viewdome'), Probability: 0.000312
# Bigram: ('viewdome', 'but'), Probability: 0.000312
# Bigram: ('was', 'at'), Probability: 0.000312
# Bigram: ('at', 'such'), Probability: 0.000312
# Bigram: ('such', 'an'), Probability: 0.000312
# Bigram: ('an', 'angle'), Probability: 0.000312
# Bigram: ('angle', 'that'), Probability: 0.000312
# Bigram: ('it', 'merely'), Probability: 0.000312
# Bigram: ('merely', 'nicked'), Probability: 0.000312
# Bigram: ('nicked', 'the'), Probability: 0.000312
# Bigram: ('the', 'ultrahard'), Probability: 0.000312
# Bigram: ('ultrahard', 'glass'), Probability: 0.000312
# Bigram: ('glass', 'but'), Probability: 0.000312
# Bigram: ('but', 'did'), Probability: 0.000312
# Bigram: ('not', 'crack'), Probability: 0.000312
# Bigram: ('crack', 'it'), Probability: 0.000312
# Bigram: ('it', 'it'), Probability: 0.000312
# Bigram: ('it', 'sang'), Probability: 0.000312
# Bigram: ('sang', 'off'), Probability: 0.000312
# Bigram: ('off', 'high'), Probability: 0.000312
# Bigram: ('high', 'into'), Probability: 0.000312
# Bigram: ('the', 'air'), Probability: 0.000312
# Bigram: ('air', 'stacey'), Probability: 0.000312
# Bigram: ('came', 'into'), Probability: 0.000312
# Bigram: ('room', 'panting'), Probability: 0.000312
# Bigram: ('panting', 'and'), Probability: 0.000312
# Bigram: ('and', 'halfcarrying'), Probability: 0.000312
# Bigram: ('halfcarrying', 'nora'), Probability: 0.000312
# Bigram: ('nora', 'between'), Probability: 0.000312
# Bigram: ('between', 'them'), Probability: 0.000312
# Bigram: ('them', 'what'), Probability: 0.000312
# Bigram: ('what', 'are'), Probability: 0.000312
# Bigram: ('are', 'we'), Probability: 0.000312
# Bigram: ('we', 'waiting'), Probability: 0.000312
# Bigram: ('waiting', 'for'), Probability: 0.000312
# Bigram: ('for', 'snapped'), Probability: 0.000312
# Bigram: ('snapped', 'stacey'), Probability: 0.000312
# Bigram: ('stacey', 'getting'), Probability: 0.000312
# Bigram: ('getting', 'up'), Probability: 0.000312
# Bigram: ('up', 'steam'), Probability: 0.000312
# Bigram: ('steam', 'what'), Probability: 0.000312
# Bigram: ('what', 'is'), Probability: 0.000312
# Bigram: ('is', 'this'), Probability: 0.000312
# Bigram: ('this', 'a'), Probability: 0.000312
# Bigram: ('a', 'stanley'), Probability: 0.000312
# Bigram: ('stanley', 'steamer'), Probability: 0.000312
# Bigram: ('steamer', 'just'), Probability: 0.000312
# Bigram: ('just', 'takes'), Probability: 0.000312
# Bigram: ('takes', 'as'), Probability: 0.000312
# Bigram: ('as', 'long'), Probability: 0.000312
# Bigram: ('long', 'grunted'), Probability: 0.000312
# Bigram: ('grunted', 'paul'), Probability: 0.000312
# Bigram: ('the', 'low'), Probability: 0.000312
# Bigram: ('low', 'drive'), Probability: 0.000312
# Bigram: ('drive', 'took'), Probability: 0.000312
# Bigram: ('took', 'hold'), Probability: 0.000312
# Bigram: ('hold', 'the'), Probability: 0.000312
# Bigram: ('ship', 'lifted'), Probability: 0.000312
# Bigram: ('lifted', 'uncertainly'), Probability: 0.000312
# Bigram: ('uncertainly', 'awkwardly'), Probability: 0.000312
# Bigram: ('awkwardly', 'quaveringly'), Probability: 0.000312
# Bigram: ('quaveringly', 'and'), Probability: 0.000312
# Bigram: ('and', 'slowly'), Probability: 0.000312
# Bigram: ('slowly', 'not'), Probability: 0.000312
# Bigram: ('the', 'quick'), Probability: 0.000312
# Bigram: ('quick', 'rushupwards'), Probability: 0.000312
# Bigram: ('rushupwards', 'of'), Probability: 0.000312
# Bigram: ('the', 'wellprepared'), Probability: 0.000312
# Bigram: ('wellprepared', 'ship'), Probability: 0.000312
# Bigram: ('ship', 'but'), Probability: 0.000312
# Bigram: ('but', 'as'), Probability: 0.000312
# Bigram: ('the', 'seconds'), Probability: 0.000312
# Bigram: ('seconds', 'passed'), Probability: 0.000312
# Bigram: ('passed', 'the'), Probability: 0.000312
# Bigram: ('ship', 'steadied'), Probability: 0.000312
# Bigram: ('steadied', 'the'), Probability: 0.000312
# Bigram: ('the', 'controls'), Probability: 0.000312
# Bigram: ('controls', 'got'), Probability: 0.000312
# Bigram: ('got', 'less'), Probability: 0.000312
# Bigram: ('less', 'mushy'), Probability: 0.000312
# Bigram: ('mushy', 'and'), Probability: 0.000312
# Bigram: ('the', 'drive'), Probability: 0.000312
# Bigram: ('drive', 'became'), Probability: 0.000312
# Bigram: ('became', 'more'), Probability: 0.000312
# Bigram: ('more', 'certain'), Probability: 0.000312
# Bigram: ('certain', 'a'), Probability: 0.000312
# Bigram: ('a', 'light'), Probability: 0.000312
# Bigram: ('light', 'flashed'), Probability: 0.000312
# Bigram: ('flashed', 'in'), Probability: 0.000312
# Bigram: ('in', 'through'), Probability: 0.000312
# Bigram: ('the', 'port'), Probability: 0.000312
# Bigram: ('port', 'their'), Probability: 0.000312
# Bigram: ('their', 'erstwhile'), Probability: 0.000312
# Bigram: ('erstwhile', 'jailers'), Probability: 0.000312
# Bigram: ('jailers', 'had'), Probability: 0.000312
# Bigram: ('had', 'aimed'), Probability: 0.000312
# Bigram: ('aimed', 'a'), Probability: 0.000312
# Bigram: ('a', 'spotlight'), Probability: 0.000312
# Bigram: ('spotlight', 'on'), Probability: 0.000312
# Bigram: ('ship', 'and'), Probability: 0.000312
# Bigram: ('and', 'with'), Probability: 0.000312
# Bigram: ('the', 'light'), Probability: 0.000312
# Bigram: ('light', 'there'), Probability: 0.000312
# Bigram: ('the', 'pattering'), Probability: 0.000312
# Bigram: ('pattering', 'of'), Probability: 0.000312
# Bigram: ('of', 'gunshot'), Probability: 0.000312
# Bigram: ('gunshot', 'a'), Probability: 0.000312
# Bigram: ('a', 'flat'), Probability: 0.000312
# Bigram: ('flat', 'bark'), Probability: 0.000312
# Bigram: ('bark', 'came'), Probability: 0.000312
# Bigram: ('came', 'from'), Probability: 0.000312
# Bigram: ('from', 'below'), Probability: 0.000312
# Bigram: ('below', 'and'), Probability: 0.000312
# Bigram: ('paul', 'braced'), Probability: 0.000312
# Bigram: ('braced', 'himself'), Probability: 0.000312
# Bigram: ('himself', 'for'), Probability: 0.000312
# Bigram: ('the', 'impact'), Probability: 0.000312
# Bigram: ('impact', 'that'), Probability: 0.000312
# Bigram: ('that', 'did'), Probability: 0.000312
# Bigram: ('not', 'come'), Probability: 0.000312
# Bigram: ('come', 'a'), Probability: 0.000312
# Bigram: ('a', 'miss'), Probability: 0.000312
# Bigram: ('miss', 'then'), Probability: 0.000312
# Bigram: ('snapped', 'the'), Probability: 0.000312
# Bigram: ('drive', 'and'), Probability: 0.000312
# Bigram: ('floor', 'leaped'), Probability: 0.000312
# Bigram: ('leaped', 'upward'), Probability: 0.000312
# Bigram: ('upward', 'under'), Probability: 0.000312
# Bigram: ('under', 'them'), Probability: 0.000312
# Bigram: ('them', 'chair'), Probability: 0.000312
# Bigram: ('chair', 'cushions'), Probability: 0.000312
# Bigram: ('cushions', 'flattened'), Probability: 0.000312
# Bigram: ('flattened', 'and'), Probability: 0.000312
# Bigram: ('then', 'filled'), Probability: 0.000312
# Bigram: ('filled', 'out'), Probability: 0.000312
# Bigram: ('out', 'again'), Probability: 0.000312
# Bigram: ('again', 'as'), Probability: 0.000312
# Bigram: ('the', 'hydraulic'), Probability: 0.000312
# Bigram: ('hydraulic', 'compensators'), Probability: 0.000312
# Bigram: ('compensators', 'went'), Probability: 0.000312
# Bigram: ('went', 'to'), Probability: 0.000312
# Bigram: ('work', 'behind'), Probability: 0.000312
# Bigram: ('behind', 'them'), Probability: 0.000312
# Bigram: ('planet', 'diminished'), Probability: 0.000312
# Bigram: ('diminished', 'in'), Probability: 0.000312
# Bigram: ('in', 'size'), Probability: 0.000312
# Bigram: ('size', 'visibly'), Probability: 0.000312
# Bigram: ('visibly', 'and'), Probability: 0.000312
# Bigram: ('then', 'at'), Probability: 0.000312
# Bigram: ('at', 'once'), Probability: 0.000312
# Bigram: ('the', 'viewport'), Probability: 0.000312
# Bigram: ('viewport', 'just'), Probability: 0.000312
# Bigram: ('just', 'became'), Probability: 0.000312
# Bigram: ('became', 'black'), Probability: 0.000312
# Bigram: ('black', 'and'), Probability: 0.000312
# Bigram: ('and', 'featureless'), Probability: 0.000312
# Bigram: ('featureless', 'outside'), Probability: 0.000312
# Bigram: ('outside', 'paul'), Probability: 0.000312
# Bigram: ('paul', 'leaned'), Probability: 0.000312
# Bigram: ('leaned', 'back'), Probability: 0.000312
# Bigram: ('back', 'in'), Probability: 0.000312
# Bigram: ('the', 'pilots'), Probability: 0.000312
# Bigram: ('pilots', 'chair'), Probability: 0.000312
# Bigram: ('chair', 'wow'), Probability: 0.000312
# Bigram: ('wow', 'he'), Probability: 0.000312
# Bigram: ('he', 'yelped'), Probability: 0.000312
# Bigram: ('yelped', 'made'), Probability: 0.000312
# Bigram: ('made', 'it'), Probability: 0.000312
# Bigram: ('stacey', 'paul'), Probability: 0.000312
# Bigram: ('paul', 'got'), Probability: 0.000312
# Bigram: ('got', 'up'), Probability: 0.000312
# Bigram: ('up', 'and'), Probability: 0.000312
# Bigram: ('went', 'over'), Probability: 0.000312
# Bigram: ('over', 'to'), Probability: 0.000312
# Bigram: ('to', 'nora'), Probability: 0.000312
# Bigram: ('i', 'wasnt'), Probability: 0.000312
# Bigram: ('wasnt', 'running'), Probability: 0.000312
# Bigram: ('from', 'you'), Probability: 0.000312
# Bigram: ('you', 'he'), Probability: 0.000312
# Bigram: ('said', 'plaintively'), Probability: 0.000312
# Bigram: ('plaintively', 'it'), Probability: 0.000312
# Bigram: ('takes', 'time'), Probability: 0.000312
# Bigram: ('get', 'the'), Probability: 0.000312
# Bigram: ('open', 'i'), Probability: 0.000312
# Bigram: ('forgive', 'you'), Probability: 0.000312
# Bigram: ('you', 'said'), Probability: 0.000312
# Bigram: ('nora', 'with'), Probability: 0.000312
# Bigram: ('a', 'smile'), Probability: 0.000312
# Bigram: ('smile', 'back'), Probability: 0.000312
# Bigram: ('back', 'below'), Probability: 0.000312
# Bigram: ('below', 'them'), Probability: 0.000312
# Bigram: ('them', 'westlake'), Probability: 0.000312
# Bigram: ('westlake', 'said'), Probability: 0.000312
# Bigram: ('said', 'youre'), Probability: 0.000312
# Bigram: ('youre', 'sure'), Probability: 0.000312
# Bigram: ('sure', 'you'), Probability: 0.000312
# Bigram: ('you', 'missed'), Probability: 0.000312
# Bigram: ('missed', 'im'), Probability: 0.000312
# Bigram: ('im', 'a'), Probability: 0.000312
# Bigram: ('a', 'master'), Probability: 0.000312
# Bigram: ('master', 'gunner'), Probability: 0.000312
# Bigram: ('gunner', 'said'), Probability: 0.000312
# Bigram: ('said', 'the'), Probability: 0.000312
# Bigram: ('other', 'it'), Probability: 0.000312
# Bigram: ('a', 'good'), Probability: 0.000312
# Bigram: ('good', 'gunner'), Probability: 0.000312
# Bigram: ('gunner', 'to'), Probability: 0.000312
# Bigram: ('to', 'miss'), Probability: 0.000312
# Bigram: ('miss', 'a'), Probability: 0.000312
# Bigram: ('ship', 'that'), Probability: 0.000312
# Bigram: ('that', 'big'), Probability: 0.000312
# Bigram: ('big', 'when'), Probability: 0.000312
# Bigram: ('when', 'it'), Probability: 0.000312
# Bigram: ('is', 'that'), Probability: 0.000312
# Bigram: ('that', 'close'), Probability: 0.000312
# Bigram: ('close', 'i'), Probability: 0.000312
# Bigram: ('i', 'missed'), Probability: 0.000312
# Bigram: ('missed', 'all'), Probability: 0.000312
# Bigram: ('all', 'right'), Probability: 0.000312
# Bigram: ('right', 'westlake'), Probability: 0.000312
# Bigram: ('westlake', 'smiled'), Probability: 0.000312
# Bigram: ('smiled', 'we'), Probability: 0.000312
# Bigram: ('we', 'sure'), Probability: 0.000312
# Bigram: ('sure', 'made'), Probability: 0.000312
# Bigram: ('made', 'that'), Probability: 0.000312
# Bigram: ('that', 'look'), Probability: 0.000312
# Bigram: ('look', 'good'), Probability: 0.000312
# Bigram: ('good', 'but'), Probability: 0.000312
# Bigram: ('but', 'god'), Probability: 0.000312
# Bigram: ('god', 'what'), Probability: 0.000312
# Bigram: ('what', 'a'), Probability: 0.000312
# Bigram: ('a', 'job'), Probability: 0.000312
# Bigram: ('job', 'of'), Probability: 0.000312
# Bigram: ('of', 'timing'), Probability: 0.000312
# Bigram: ('timing', 'i'), Probability: 0.000312
# Bigram: ('thought', 'we'), Probability: 0.000312
# Bigram: ('we', 'were'), Probability: 0.000312
# Bigram: ('were', 'going'), Probability: 0.000312
# Bigram: ('have', 'to'), Probability: 0.000312
# Bigram: ('to', 'blow'), Probability: 0.000312
# Bigram: ('blow', 'out'), Probability: 0.000312
# Bigram: ('out', 'a'), Probability: 0.000312
# Bigram: ('a', 'tire'), Probability: 0.000312
# Bigram: ('tire', 'to'), Probability: 0.000312
# Bigram: ('keep', 'from'), Probability: 0.000312
# Bigram: ('from', 'catching'), Probability: 0.000312
# Bigram: ('catching', 'them'), Probability: 0.000312
# Bigram: ('them', None), Probability: 0.000312

# %% [markdown]
# ### Taking out some other random chapter

# %%
random_chapter=rnd.choice(chapters)
random_chapter
# Out:
# '\n\n\n"I\'m pointing for Alpha Centauri," said Paul. "And so that\'s what we\ncalculate for."\n\nNora looked at the bays of neat equipment and shook her head. "Why not\naim at it and run?" she asked. "Surely you do not need this billion\ndollars\' worth of stuff to point out your destination."\n\n"We do," objected Paul. "You see, if I took off with my telescope\npointed along the axis of drive with the cross-hairs pointing at Alpha\nCentauri, I\'d be heading for the star where it was four years ago. I\nintend to be on the way for nine days. So I\'ll want to point the nose\nof the ship at the spot where Alpha will be nine days in the future\ninstead of four years in the past. Since Sol and Alpha drift in space,\nthe motion and velocities of both systems must be taken into account,\na correction-angle found, and then used to aim my ship. My telescope\nwill angle away from the ship\'s axis by that correction-angle. Add\nto that the fact that I am taking off from earth, which will give me\nsome angular velocity and some rotational velocity differing from an\nhypothetical take-off from Sol itself. Furthermore, I want Proxima\nCentauri instead of Alpha, and that must be taken into consideration\ntoo.\n\n"Then there is the question of velocity and time. We cannot see\nwhen we are exceeding the velocity of light. We must run at so many\nlight-velocities for so many seconds. A minor error in timing or\nvelocity will create a rather gross error in position at the end of the\nrun."\n\n"Oh," said Nora, but her tone indicated a lack of comprehension.\n\nPaul smiled. "One second of error at one light-velocity equals a\nhundred and eighty-six thousand miles of error. One second of error at\na hundred times the velocity of light equals eighteen millions of miles\nerror. Not much as cosmic distance goes, but a long way to walk."\n\nNora understood that, and said so.\n\nGrayson\'s data had been handed to him by Haedaecker. But apparently the\nlong-range calculations that had been temporarily halted were still\nhalted, for the operator was taking this opportunity of feeding some\nfuture flight-constant information to the big machine.\n\nIt was not a complex calculation as some computations may go, but\nthere were a myriad of factors. Terran latitude and longitude, the\ninstant of take-off as applied to the day and the year, an averaging\nof previous dispersion-factors noted from previous trips, velocities,\nvector angles, momentum, and others, all obtained from tables and\nentered in the machine before the start lever was pulled. The machine\nmulled the information over, tossed electrons back and forth, chewed\nand digested a ream of binary digits, and handed forth a strip of paper\nprinted with an entire set of coordinates in decimal angles.\n\nPaul showed Nora his folder of data. "The rest," he said, "is up to me."\n\nHe led Nora from the computation room, intending to hit the dining room\nfor coffee. Half-way across the lobby of the administration building he\nwas hailed by the autocall. He went to the telephone.\n\nIt was Stacey.\n\n"I\'ve a couple of things to let you think over," said Stacey.\n\n"So?"\n\n"I\'ve been on the job. I haven\'t much, but there are a few items you\nmight mull over."\n\n"Shoot."\n\n"One. Your deceased thief was an ex-convict, escaped from the penal\ncolony on Antarctica."\n\n"This I\'ve heard."\n\n"Then I suppose you know that the guy was cashiered from the Neoterra\nrun for smuggling."\n\n"Huh?" blurted Paul.\n\n"An ex-pilot, tossed out on his right ear for conduct hardly becoming a\nsafecracker and a thief, let alone an officer and a gentleman."\n\n"That I didn\'t know. How long ago?"\n\n"Five years, almost."\n\nIt was not quite the ten that Nora had claimed.\n\n"Well, that makes it--"\n\n"That ain\'t all," came Stacey\'s voice. "The weapons carried by the\nSpaceport guards are regulation Police Positives. Our erstwhile felon\nwas shot once, right between the eyes, with a forty-five, which\naccording to all of  ...

# %% [markdown]
# ### Preprocessing the random chapter text

# %%
random_chapter=text_preprocessing(random_chapter)
random_chapter
# Out:
# 'im pointing for alpha centauri said paul and so thats what we calculate for nora looked at the bays of neat equipment and shook her head why not aim at it and run she asked surely you do not need this billion dollars worth of stuff to point out your destination we do objected paul you see if i took off with my telescope pointed along the axis of drive with the crosshairs pointing at alpha centauri id be heading for the star where it was four years ago i intend to be on the way for nine days so ill want to point the nose of the ship at the spot where alpha will be nine days in the future instead of four years in the past since sol and alpha drift in space the motion and velocities of both systems must be taken into account a correctionangle found and then used to aim my ship my telescope will angle away from the ships axis by that correctionangle add to that the fact that i am taking off from earth which will give me some angular velocity and some rotational velocity differing from an hypothetical takeoff from sol itself furthermore i want proxima centauri instead of alpha and that must be taken into consideration too then there is the question of velocity and time we cannot see when we are exceeding the velocity of light we must run at so many lightvelocities for so many seconds a minor error in timing or velocity will create a rather gross error in position at the end of the run oh said nora but her tone indicated a lack of comprehension paul smiled one second of error at one lightvelocity equals a hundred and eightysix thousand miles of error one second of error at a hundred times the velocity of light equals eighteen millions of miles error not much as cosmic distance goes but a long way to walk nora understood that and said so graysons data had been handed to him by haedaecker but apparently the longrange calculations that had been temporarily halted were still halted for the operator was taking this opportunity of feeding some future flightconstant information to the big machine it was not a complex calculation as some computations may go but there were a myriad of factors terran latitude and longitude the instant of takeoff as applied to the day and the year an averaging of previous dispersionfactors noted from previous trips velocities vector angles momentum and others all obtained from tables and entered in the machine before the start lever was pulled the machine mulled the information over tossed electrons back and forth chewed and digested a ream of binary digits and handed forth a strip of paper printed with an entire set of coordinates in decimal angles paul showed nora his folder of data the rest he said is up to me he led nora from the computation room intending to hit the dining room for coffee halfway across the lobby of the administration building he was hailed by the autocall he went to the telephone it was stacey ive a couple of things to let you think over said stacey so ive been on the job i havent much but there are a few items you might mull over shoot one your deceased thief was an exconvict escaped from the penal colony on antarctica this ive heard then i suppose you know that the guy was cashiered from the neoterra run for smuggling huh blurted paul an expilot tossed out on his right ear for conduct hardly becoming a safecracker and a thief let alone an officer and a gentleman that i didnt know how long ago five years almost it was not quite the ten that nora had claimed well that makes it that aint all came staceys voice the weapons carried by the spaceport guards are regulation police positives our erstwhile felon was shot once right between the eyes with a fortyfive which according to all of the expert opinion came from an automatic at a distance of three feet plus or minus six inches know what that means im just digesting the information now you tell me it means that the excrook was killed by a party or parties unknown someone other than one of the guards furthermore he was facing his executione ...

# %% [markdown]
# ### Tokenizing the random chapter text

# %%
tokenized_chapter=word_tokenize(random_chapter)
tokenized_chapter
# Out:
# ['im',
#  'pointing',
#  'for',
#  'alpha',
#  'centauri',
#  'said',
#  'paul',
#  'and',
#  'so',
#  'thats',
#  'what',
#  'we',
#  'calculate',
#  'for',
#  'nora',
#  'looked',
#  'at',
#  'the',
#  'bays',
#  'of',
#  'neat',
#  'equipment',
#  'and',
#  'shook',
#  'her',
#  'head',
#  'why',
#  'not',
#  'aim',
#  'at',
#  'it',
#  'and',
#  'run',
#  'she',
#  'asked',
#  'surely',
#  'you',
#  'do',
#  'not',
#  'need',
#  'this',
#  'billion',
#  'dollars',
#  'worth',
#  'of',
#  'stuff',
#  'to',
#  'point',
#  'out',
#  'your',
#  'destination',
#  'we',
#  'do',
#  'objected',
#  'paul',
#  'you',
#  'see',
#  'if',
#  'i',
#  'took',
#  'off',
#  'with',
#  'my',
#  'telescope',
#  'pointed',
#  'along',
#  'the',
#  'axis',
#  'of',
#  'drive',
#  'with',
#  'the',
#  'crosshairs',
#  'pointing',
#  'at',
#  'alpha',
#  'centauri',
#  'id',
#  'be',
#  'heading',
#  'for',
#  'the',
#  'star',
#  'where',
#  'it',
#  'was',
#  'four',
#  'years',
#  'ago',
#  'i',
#  'intend',
#  'to',
#  'be',
#  'on',
#  'the',
#  'way',
#  'for',
#  'nine',
#  'days',
#  'so',
#  'ill',
#  'want',
#  'to',
#  'point',
#  'the',
#  'nose',
#  'of',
#  'the',
#  'ship',
#  'at',
#  'the',
#  'spot',
#  'where',
#  'alpha',
#  'will',
#  'be',
#  'nine',
#  'days',
#  'in',
#  'the',
#  'future',
#  'instead',
#  'of',
#  'four',
#  'years',
#  'in',
#  'the',
#  'past',
#  'since',
#  'sol',
#  'and',
#  'alpha',
#  'drift',
#  'in',
#  'space',
#  'the',
#  'motion',
#  'and',
#  'velocities',
#  'of',
#  'both',
#  'systems',
#  'must',
#  'be',
#  'taken',
#  'into',
#  'account',
#  'a',
#  'correctionangle',
#  'found',
#  'and',
#  'then',
#  'used',
#  'to',
#  'aim',
#  'my',
#  'ship',
#  'my',
#  'telescope',
#  'will',
#  'angle',
#  'away',
#  'from',
#  'the',
#  'ships',
#  'axis',
#  'by',
#  'that',
#  'correctionangle',
#  'add',
#  'to',
#  'that',
#  'the',
#  'fact',
#  'that',
#  'i',
#  'am',
#  'taking',
#  'off',
#  'from',
#  'earth',
#  'which',
#  'will',
#  'give',
#  'me',
#  'some',
#  'angular',
#  'velocity',
#  'and',
#  'some',
#  'rotational',
#  'velocity',
#  'differing',
#  'from',
#  'an',
#  'hypothetical',
#  'takeoff',
#  'from',
#  'sol',
#  'itself',
#  'furthermore',
#  'i',
#  'want',
#  'proxima',
#  'centauri',
#  'instead',
#  'of',
#  'alpha',
#  'and',
#  'that',
#  'must',
#  'be',
#  'taken',
#  'into',
#  'consideration',
#  'too',
#  'then',
#  'there',
#  'is',
#  'the',
#  'question',
#  'of',
#  'velocity',
#  'and',
#  'time',
#  'we',
#  'can',
#  'not',
#  'see',
#  'when',
#  'we',
#  'are',
#  'exceeding',
#  'the',
#  'velocity',
#  'of',
#  'light',
#  'we',
#  'must',
#  'run',
#  'at',
#  'so',
#  'many',
#  'lightvelocities',
#  'for',
#  'so',
#  'many',
#  'seconds',
#  'a',
#  'minor',
#  'error',
#  'in',
#  'timing',
#  'or',
#  'velocity',
#  'will',
#  'create',
#  'a',
#  'rather',
#  'gross',
#  'error',
#  'in',
#  'position',
#  'at',
#  'the',
#  'end',
#  'of',
#  'the',
#  'run',
#  'oh',
#  'said',
#  'nora',
#  'but',
#  'her',
#  'tone',
#  'indicated',
#  'a',
#  'lack',
#  'of',
#  'comprehension',
#  'paul',
#  'smiled',
#  'one',
#  'second',
#  'of',
#  'error',
#  'at',
#  'one',
#  'lightvelocity',
#  'equals',
#  'a',
#  'hundred',
#  'and',
#  'eightysix',
#  'thousand',
#  'miles',
#  'of',
#  'error',
#  'one',
#  'second',
#  'of',
#  'error',
#  'at',
#  'a',
#  'hundred',
#  'times',
#  'the',
#  'velocity',
#  'of',
#  'light',
#  'equals',
#  'eighteen',
#  'millions',
#  'of',
#  'miles',
#  'error',
#  'not',
#  'much',
#  'as',
#  'cosmic',
#  'distance',
#  'goes',
#  'but',
#  'a',
#  'long',
#  'way',
#  'to',
#  'walk',
#  'nora',
#  'understood',
#  'that',
#  'and',
#  'said',
#  'so',
#  'graysons',
#  'data',
#  'had',
#  'been',
#  'handed',
#  'to',
#  'him',
#  'by',
#  'haedaecker',
#  'but',
#  'apparently',
#  'the',
#  'longrange',
#  'calculations',
#  'that',
#  'had',
#  'been',
#  'temporarily',
#  'halted',
#  'were',
#  'still',
#  'halted',
#  'for',
#  'the',
#  'operator',
#  'was',
#  'taking',
#  'this',
#  'opportunity',
#  'of',
#  'feeding',
#  'some',
#  'future',
#  'flightconstant',
#  'information',
#  'to',
#  'the',
#  'big',
#  'machine',
#  'it',
#  'was',
#  'not',
#  'a',
#  'complex',
#  'calculation',
#  'as',
#  'some',
#  'computations',
#  'may',
#  'go',
#  'but',
#  'there',
#  'were',
#  'a',
#  'myriad',
#  'of',
#  'factors',
#  'terran',
#  'latitude',
#  'and',
#  'longitude',
#  'the',
#  'instant',
#  'of',
#  'takeoff',
#  'as',
#  'applied',
#  'to',
#  'the',
#  'day',
#  'and',
#  'the',
#  'year',
#  'an',
#  'averaging',
#  'of',
#  'previous',
#  'dispersionfactors',
#  'noted',
#  'from',
#  'previous',
#  'trips',
#  'velocities',
#  'vector',
#  'angles',
#  'momentum',
#  'and',
#  'others',
#  'all',
#  'obtained',
#  'from',
#  'tables',
#  'and',
#  'entered',
#  'in',
#  'the',
#  'machine',
#  'before',
#  'the',
#  'start',
#  'lever',
#  'was',
#  'pulled',
#  'the',
#  'machine',
#  'mulled',
#  'the',
#  'information',
#  'over',
#  'tossed',
#  'electrons',
#  'back',
#  'and',
#  'forth',
#  'chewed',
#  'and',
#  'digested',
#  'a',
#  'ream',
#  'of',
#  'binary',
#  'digits',
#  'and',
#  'handed',
#  'forth',
#  'a',
#  'strip',
#  'of',
#  'paper',
#  'printed',
#  'with',
#  'an',
#  'entire',
#  'set',
#  'of',
#  'coordinates',
#  'in',
#  'decimal',
#  'angles',
#  'paul',
#  'showed',
#  'nora',
#  'his',
#  'folder',
#  'of',
#  'data',
#  'the',
#  'rest',
#  'he',
#  'said',
#  'is',
#  'up',
#  'to',
#  'me',
#  'he',
#  'led',
#  'nora',
#  'from',
#  'the',
#  'computation',
#  'room',
#  'intending',
#  'to',
#  'hit',
#  'the',
#  'dining',
#  'room',
#  'for',
#  'coffee',
#  'halfway',
#  'across',
#  'the',
#  'lobby',
#  'of',
#  'the',
#  'administration',
#  'building',
#  'he',
#  'was',
#  'hailed',
#  'by',
#  'the',
#  'autocall',
#  'he',
#  'went',
#  'to',
#  'the',
#  'telephone',
#  'it',
#  'was',
#  'stacey',
#  'ive',
#  'a',
#  'couple',
#  'of',
#  'things',
#  'to',
#  'let',
#  'you',
#  'think',
#  'over',
#  'said',
#  'stacey',
#  'so',
#  'ive',
#  'been',
#  'on',
#  'the',
#  'job',
#  'i',
#  'havent',
#  'much',
#  'but',
#  'there',
#  'are',
#  'a',
#  'few',
#  'items',
#  'you',
#  'might',
#  'mull',
#  'over',
#  'shoot',
#  'one',
#  'your',
#  'deceased',
#  'thief',
#  'was',
#  'an',
#  'exconvict',
#  'escaped',
#  'from',
#  'the',
#  'penal',
#  'colony',
#  'on',
#  'antarctica',
#  'this',
#  'ive',
#  'heard',
#  'then',
#  'i',
#  'suppose',
#  'you',
#  'know',
#  'that',
#  'the',
#  'guy',
#  'was',
#  'cashiered',
#  'from',
#  'the',
#  'neoterra',
#  'run',
#  'for',
#  'smuggling',
#  'huh',
#  'blurted',
#  'paul',
#  'an',
#  'expilot',
#  'tossed',
#  'out',
#  'on',
#  'his',
#  'right',
#  'ear',
#  'for',
#  'conduct',
#  'hardly',
#  'becoming',
#  'a',
#  'safecracker',
#  'and',
#  'a',
#  'thief',
#  'let',
#  'alone',
#  'an',
#  'officer',
#  'and',
#  'a',
#  'gentleman',
#  'that',
#  'i',
#  'didnt',
#  'know',
#  'how',
#  'long',
#  'ago',
#  'five',
#  'years',
#  'almost',
#  'it',
#  'was',
#  'not',
#  'quite',
#  'the',
#  'ten',
#  'that',
#  'nora',
#  'had',
#  'claimed',
#  'well',
#  'that',
#  'makes',
#  'it',
#  'that',
#  'aint',
#  'all',
#  'came',
#  'staceys',
#  'voice',
#  'the',
#  'weapons',
#  'carried',
#  'by',
#  'the',
#  'spaceport',
#  'guards',
#  'are',
#  'regulation',
#  'police',
#  'positives',
#  'our',
#  'erstwhile',
#  'felon',
#  'was',
#  'shot',
#  'once',
#  'right',
#  'between',
#  'the',
#  'eyes',
#  'with',
#  'a',
#  'fortyfive',
#  'which',
#  'according',
#  'to',
#  'all',
#  'of',
#  'the',
#  'expert',
#  'opinion',
#  'came',
#  'from',
#  'an',
#  'automatic',
#  'at',
#  'a',
#  'distance',
#  'of',
#  'three',
#  'feet',
#  'plus',
#  'or',
#  'minus',
#  'six',
#  'inches',
#  'know',
#  'what',
#  'that',
#  'means',
#  'im',
#  'just',
#  'digesting',
#  'the',
#  'information',
#  'now',
#  'you',
#  'tell',
#  'me',
#  'it',
#  'means',
#  'that',
#  'the',
#  'excrook',
#  'was',
#  'killed',
#  'by',
#  'a',
#  'party',
#  'or',
#  'parties',
#  'unknown',
#  'someone',
#  'other',
#  'than',
#  'one',
#  'of',
#  'the',
#  'guards',
#  'furthermore',
#  'he',
#  'was',
#  'facing',
#  'his',
#  'executioner',
#  'not',
#  'taking',
#  'it',
#  'on',
#  'the',
#  'lam',
#  'how',
#  'do',
#  'you',
#  'make',
#  'that',
#  'it',
#  'doesnt',
#  'make',
#  'good',
#  'sense',
#  'sure',
#  'it',
#  'does',
#  'it',
#  'keystones',
#  'nicely',
#  'men',
#  'of',
#  'that',
#  'calibre',
#  'are',
#  'often',
#  'chilled',
#  'because',
#  'they',
#  'fumble',
#  'a',
#  'job',
#  'and',
#  'the',
#  'mainspring',
#  'doesnt',
#  'enjoy',
#  'the',
#  'prospect',
#  'of',
#  'having',
#  'a',
#  'fumbler',
#  'running',
#  'around',
#  'with',
#  'information',
#  'that',
#  'might',
#  'lead',
#  'to',
#  'the',
#  'capture',
#  'arrest',
#  'conviction',
#  'andor',
#  'demise',
#  'of',
#  'aforementioned',
#  'mainspring',
#  'they',
#  'made',
#  'one',
#  'error',
#  'they',
#  'should',
#  'have',
#  'used',
#  'a',
#  'thirtyeight',
#  'revolver',
#  'instead',
#  'of',
#  'a',
#  'fortyfive',
#  'automatic',
#  'the',
#  'fortyfive',
#  'is',
#  'a',
#  'gangsters',
#  'weapon',
#  'and',
#  'they',
#  'should',
#  'have',
#  'drilled',
#  'their',
#  'excompanion',
#  'from',
#  'behind',
#  'between',
#  'the',
#  'scapulae',
#  'to',
#  'make',
#  'it',
#  'look',
#  'as',
#  'though',
#  'the',
#  'guards',
#  'were',
#  'better',
#  'shots',
#  'than',
#  'they',
#  'really',
#  'are',
#  'thats',
#  'food',
#  'for',
#  'thought',
#  'said',
#  'paul',
#  'that',
#  'isnt',
#  'all',
#  'said',
#  'stacey',
#  'heres',
#  'one',
#  'more',
#  'bit',
#  'of',
#  'information',
#  'that',
#  'may',
#  'be',
#  'either',
#  'juicy',
#  'or',
#  'full',
#  'of',
#  'sawdust',
#  'depending',
#  'upon',
#  'how',
#  'you',
#  'taste',
#  'it',
#  'your',
#  'girl',
#  'friend',
#  'nora',
#  'phillips',
#  'was',
#  'born',
#  'and',
#  'raised',
#  'on',
#  'neoterra',
#  'youre',
#  'certain',
#  'of',
#  'that',
#  'so',
#  'the',
#  'bureau',
#  'of',
#  'vital',
#  'statistics',
#  'claims',
#  'but',
#  'how',
#  'negative',
#  'evidence',
#  'my',
#  'fine',
#  'scientist',
#  'negative',
#  'evidence',
#  'i',
#  'offer',
#  'you',
#  'two',
#  'alternatives',
#  'either',
#  'she',
#  'was',
#  'born',
#  'on',
#  'neoterra',
#  'or',
#  'she',
#  'is',
#  'employing',
#  'an',
#  'alias',
#  'pseudonym',
#  'or',
#  'nom',
#  'de',
#  'jour',
#  'staceys',
#  'french',
#  'lacked',
#  'a',
#  'certain',
#  'vocabulary',
#  'but',
#  'it',
#  'was',
#  'none',
#  'the',
#  'less',
#  'to',
#  'the',
#  'point',
#  'she',
#  'is',
#  'certainly',
#  'not',
#  'born',
#  'nora',
#  'phillips',
#  'of',
#  'terra',
#  'ill',
#  'let',
#  'you',
#  'pick',
#  'your',
#  'choice',
#  'but',
#  'enough',
#  'of',
#  'that',
#  'a',
#  'couple',
#  'of',
#  'hours',
#  'ago',
#  'she',
#  'received',
#  'a',
#  'telephone',
#  'call',
#  'nice',
#  'position',
#  'she',
#  'must',
#  'have',
#  'she',
#  'chinned',
#  'for',
#  'about',
#  'three',
#  'minutes',
#  'and',
#  'then',
#  'leaped',
#  'to',
#  'her',
#  'feet',
#  'and',
#  'took',
#  'off',
#  'like',
#  'jet',
#  'propelled',
#  'didnt',
#  'bother',
#  'to',
#  'say',
#  ...]

# %% [markdown]
# ### Writing a function to generate a random sentence from the chapter

# %%
def generate_random_sentence(tokens):
    
    #generating a random sentence of 8 to 10 words
    phrase_length = rnd.randint(8, 10)
    start_index = rnd.randint(0, len(tokenized_chapter) - phrase_length)
    random_sentence_words_list=tokenized_chapter[start_index:start_index+phrase_length]
    
    random_word_index=rnd.randint(1,len(random_sentence_words_list)-1)
    original_word=random_sentence_words_list[random_word_index]
    random_sentence_words_list[random_word_index]="______"
    consecutive_phrase = " ".join(random_sentence_words_list)
    
    #returning list of words in the random sentence , original word , and index of word before original word
    return random_sentence_words_list,original_word,random_word_index-1

# %% [markdown]
# ## Writing the Shannon Game function

# %%
def play_shannon_game(tokens,bigram_set):
    sentence,original,index=generate_random_sentence(tokenized_chapter)
    print("Random Sentence from the chapter-:")
    consecutive_phrase = " ".join(sentence)
    print(consecutive_phrase,"\n")
    
    selected_pairs = [pair for pair in bigram_set if pair[0] == sentence[index]]
    try:
        highest_value_pair = max(selected_pairs, key=lambda pair: bigram_probabilities.get(pair, 0))
        print(f"Most probable word according to bigram probability: {highest_value_pair[1]}")
        print("Original word: ",original)  
        print(".............................................\n\n")
        if highest_value_pair[1]==original:
            return True
        else:
            return False
        
    except ValueError as e:
        print(f"Bigram starting with ",{sentence[index]}," wasn't found in the training text.")
        print(".............................................\n\n")
        return False

# %%
play_shannon_game(tokenized_chapter,bigram_set)
# Out:
# Random Sentence from the chapter-:
# they looked ______ be to the eye there would
#
# Most probable word according to bigram probability: reasonably
# Original word:  to
# .............................................
# False

# %% [markdown]
# ## Writing a function to get the frequency of correctly and incorrectly identified words by the Shannon game guess

# %%
def freq_guess_performance(n):
    incorrect=0
    correct=0
    for i in range(500):
        result=play_shannon_game(tokenized_chapter,bigram_set)
        if result==True:
            correct=correct+1
        else:
            incorrect=incorrect+1
    return correct,incorrect

# %%
correct,incorrect=freq_guess_performance(500)
# Out:
# Random Sentence from the chapter-:
# or the ______ of a radio beacon on proxima
#
# Most probable word according to bigram probability: other
# Original word:  ruin
# .............................................
#
#
# Random Sentence from the chapter-:
# forget it you were doing your ______ but can
#
# Most probable word according to bigram probability: own
# Original word:  duty
# .............................................
#
#
# Random Sentence from the chapter-:
# said paul soberly he hung up turned ______ saw
#
# Most probable word according to bigram probability: away
# Original word:  and
# .............................................
#
#
# Random Sentence from the chapter-:
# i ______ why columbus had been kicked around for having
#
# Most probable word according to bigram probability: thought
# Original word:  but
# .............................................
#
#
# Random Sentence from the chapter-:
# that sounded ______ pure soap opera in space ive
#
# Bigram starting with  {'sounded'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# rotational velocity differing from an hypothetical ______ from sol
#
# Bigram starting with  {'hypothetical'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# was a satisfying emotional ______ intellectually it proved nothing
#
# Bigram starting with  {'emotional'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# job and the mainspring doesnt enjoy the ______ of having
#
# Most probable word according to bigram probability: other
# Original word:  prospect
# .............................................
#
#
# Random Sentence from the chapter-:
# that ______ the drivers above them the bulge of
#
# Most probable word according to bigram probability: the
# Original word:  held
# .............................................
#
#
# Random Sentence from the chapter-:
# information that might lead to the capture arrest conviction ______
#
# Bigram starting with  {'conviction'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# choice but enough ______ that a couple of
#
# Bigram starting with  {'enough'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# finding an inert victim and an hysterical woman ______
#
# Bigram starting with  {'woman'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# was when one ______ the star ships was scheduled
#
# Most probable word according to bigram probability: of
# Original word:  of
# .............................................
#
#
# Random Sentence from the chapter-:
# heavenly way a poor ten to ______ miles per
#
# Most probable word according to bigram probability: the
# Original word:  fifty
# .............................................
#
#
# Random Sentence from the chapter-:
# just a loose end i might ______ able
#
# Most probable word according to bigram probability: well
# Original word:  be
# .............................................
#
#
# Random Sentence from the chapter-:
# by you what kind ______ job do you
#
# Most probable word according to bigram probability: of
# Original word:  of
# .............................................
#
#
# Random Sentence from the chapter-:
# for certain she with you now uhhuh ______ thought
#
# Bigram starting with  {'uhhuh'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# the spotter craft would have moved ______ the
#
# Bigram starting with  {'moved'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# to face the spaceport ______ its that way she said
#
# Most probable word according to bigram probability: and
# Original word:  door
# .............................................
#
#
# Random Sentence from the chapter-:
# not be ______ by a misplaced hair or a
#
# Most probable word according to bigram probability: a
# Original word:  marred
# .............................................
#
#
# Random Sentence from the chapter-:
# rouge printed offset from her own ripe ______
#
# Bigram starting with  {'ripe'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# this billion dollars ______ of stuff to point out
#
# Bigram starting with  {'dollars'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# arrest conviction andor ______ of aforementioned mainspring they made
#
# Bigram starting with  {'andor'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# management of the ______ at all then where
#
# Most probable word according to bigram probability: other
# Original word:  joint
# .............................................
#
#
# Random Sentence from the chapter-:
# in space the motion and velocities of ______
#
# Most probable word according to bigram probability: the
# Original word:  both
# .............................................
#
#
# Random Sentence from the chapter-:
# the headache out of his skull ______ fingers
#
# Bigram starting with  {'skull'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# off on this line of sight ______ for it
#
# Bigram starting with  {'sight'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# his way nothing to do for two weeks ______ wait
#
# Most probable word according to bigram probability: went
# Original word:  but
# .............................................
#
#
# Random Sentence from the chapter-:
# would not employ the punishing judo holds ______
#
# Bigram starting with  {'holds'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# of finding an inert victim and an ______ woman
#
# Most probable word according to bigram probability: eye
# Original word:  hysterical
# .............................................
#
#
# Random Sentence from the chapter-:
# not too soft ______ are you there yeah
#
# Bigram starting with  {'soft'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# attack and thwarting any further ______ the criminal held for
#
# Bigram starting with  {'further'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# but galileo had ______ his screwy ideas whereas
#
# Most probable word according to bigram probability: been
# Original word:  publicized
# .............................................
#
#
# Random Sentence from the chapter-:
# jet propelled didnt bother to say anything to ______
#
# Most probable word according to bigram probability: the
# Original word:  the
# .............................................
#
#
# Random Sentence from the chapter-:
# of ______ mainspring they made one error they should have
#
# Most probable word according to bigram probability: the
# Original word:  aforementioned
# .............................................
#
#
# Random Sentence from the chapter-:
# gentle curve and ______ the place where the
#
# Most probable word according to bigram probability: the
# Original word:  about
# .............................................
#
#
# Random Sentence from the chapter-:
# the line of aim between terra and ______ calculated
#
# Most probable word according to bigram probability: the
# Original word:  the
# .............................................
#
#
# Random Sentence from the chapter-:
# executioner ______ taking it on the lam how
#
# Bigram starting with  {'executioner'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# the zwave to plan for the future when his ______
#
# Most probable word according to bigram probability: own
# Original word:  discoveries
# .............................................
#
#
# Random Sentence from the chapter-:
# girders in a ______ and efficient pattern the girders were
#
# Most probable word according to bigram probability: large
# Original word:  neat
# .............................................
#
#
# Random Sentence from the chapter-:
# her desires to ascertain her limit before he ______
#
# Most probable word according to bigram probability: could
# Original word:  took
# .............................................
#
#
# Random Sentence from the chapter-:
# haedaecker ______ apparently the longrange calculations that had been
#
# Most probable word according to bigram probability: while
# Original word:  but
# .............................................
#
#
# Random Sentence from the chapter-:
# a gangsters weapon ______ they should have drilled their
#
# Bigram starting with  {'weapon'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# into his arms forward ______ a goodbye kiss
#
# Bigram starting with  {'forward'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# couldnt stop me he chuckled ______ reached for her
#
# Most probable word according to bigram probability: and
# Original word:  he
# .............................................
#
#
# Random Sentence from the chapter-:
# were doing your duty but can you tell ______ did
#
# Bigram starting with  {'tell'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# do you hold ______ it isnt everybody that can pick
#
# Most probable word according to bigram probability: the
# Original word:  why
# .............................................
#
#
# Random Sentence from the chapter-:
# neoterra or she is employing an alias ______ or
#
# Bigram starting with  {'alias'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# about more ______ said paul soberly he hung up
#
# Most probable word according to bigram probability: and
# Original word:  than
# .............................................
#
#
# Random Sentence from the chapter-:
# it your girl friend nora phillips was born ______
#
# Bigram starting with  {'born'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# a thirtyeight revolver ______ of a fortyfive automatic the fortyfive
#
# Bigram starting with  {'revolver'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# the question of velocity and time we can not ______
#
# Most probable word according to bigram probability: understand
# Original word:  see
# .............................................
#
#
# Random Sentence from the chapter-:
# she said ______ was not a tone of
#
# Most probable word according to bigram probability: nora
# Original word:  it
# .............................................
#
#
# Random Sentence from the chapter-:
# round the ______ swings em round and round
#
# Most probable word according to bigram probability: other
# Original word:  magnet
# .............................................
#
#
# Random Sentence from the chapter-:
# billion dollars worth of stuff to point out your ______
#
# Most probable word according to bigram probability: own
# Original word:  destination
# .............................................
#
#
# Random Sentence from the chapter-:
# an automatic ______ a distance of three feet plus or
#
# Bigram starting with  {'automatic'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# not available lacking the spotter to use as ______ point
#
# Most probable word according to bigram probability: the
# Original word:  a
# .............................................
#
#
# Random Sentence from the chapter-:
# run ______ smuggling huh blurted paul an expilot tossed
#
# Most probable word according to bigram probability: for
# Original word:  for
# .............................................
#
#
# Random Sentence from the chapter-:
# job do you hold why it isnt ______ that can
#
# Bigram starting with  {'isnt'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# perform ______ acts in pauls name while paul was
#
# Bigram starting with  {'perform'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# hum ______ after a moment or two the
#
# Bigram starting with  {'hum'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# keeping ______ hale hearty healthy and imbued with ideas
#
# Most probable word according to bigram probability: an
# Original word:  paul
# .............................................
#
#
# Random Sentence from the chapter-:
# but im ______ by you what kind of
#
# Most probable word according to bigram probability: not
# Original word:  baffled
# .............................................
#
#
# Random Sentence from the chapter-:
# he was now in that ______ that surrounded every
#
# Most probable word according to bigram probability: the
# Original word:  blackness
# .............................................
#
#
# Random Sentence from the chapter-:
# the humming broke out into ______ fullthroated but
#
# Most probable word according to bigram probability: the
# Original word:  a
# .............................................
#
#
# Random Sentence from the chapter-:
# to find me an advantage and then sit ______ it
#
# Bigram starting with  {'sit'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# motion and velocities of both ______ must be
#
# Most probable word according to bigram probability: hands
# Original word:  systems
# .............................................
#
#
# Random Sentence from the chapter-:
# mcbride and webster attorneysatlaw ______ couldnt tap their telephone
#
# Bigram starting with  {'attorneysatlaw'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# furthermore i want proxima centauri instead ______ alpha and
#
# Most probable word according to bigram probability: of
# Original word:  of
# .............................................
#
#
# Random Sentence from the chapter-:
# ships drive could be used as a lineofsight aiming ______
#
# Bigram starting with  {'aiming'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# gentleman that i didnt ______ how long ago
#
# Bigram starting with  {'didnt'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# duty paul went over and ______ hi hello say
#
# Most probable word according to bigram probability: the
# Original word:  asked
# .............................................
#
#
# Random Sentence from the chapter-:
# that they couldnt ______ get their heads together close enough
#
# Bigram starting with  {'couldnt'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# nice position she must ______ she chinned for about three
#
# Most probable word according to bigram probability: have
# Original word:  have
# .............................................
#
#
# Random Sentence from the chapter-:
# the man who ______ me turned up with
#
# Most probable word according to bigram probability: had
# Original word:  clipped
# .............................................
#
#
# Random Sentence from the chapter-:
# guy who used my ______ last night have
#
# Most probable word according to bigram probability: door
# Original word:  identification
# .............................................
#
#
# Random Sentence from the chapter-:
# empirical knowledge for a ______ of millions of years paul
#
# Most probable word according to bigram probability: large
# Original word:  couple
# .............................................
#
#
# Random Sentence from the chapter-:
# are regulation ______ positives our erstwhile felon was shot
#
# Bigram starting with  {'regulation'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# thwarting any further plans the criminal ______ for them both
#
# Bigram starting with  {'criminal'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# enough to keep him ______ until the criminal could
#
# Most probable word according to bigram probability: up
# Original word:  quiet
# .............................................
#
#
# Random Sentence from the chapter-:
# of course there was galileo but galileo had ______ his
#
# Most probable word according to bigram probability: been
# Original word:  publicized
# .............................................
#
#
# Random Sentence from the chapter-:
# first instinctive move would give ______ away so paul
#
# Bigram starting with  {'give'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# work so what had ______ happened last night
#
# Most probable word according to bigram probability: been
# Original word:  really
# .............................................
#
#
# Random Sentence from the chapter-:
# arrive at terra to ______ an aiming point for the
#
# Most probable word according to bigram probability: the
# Original word:  provide
# .............................................
#
#
# Random Sentence from the chapter-:
# on stopping paul grayson she was ______ against
#
# Most probable word according to bigram probability: a
# Original word:  working
# .............................................
#
#
# Random Sentence from the chapter-:
# four light years ______ help the pilot the
#
# Most probable word according to bigram probability: apart
# Original word:  to
# .............................................
#
#
# Random Sentence from the chapter-:
# on his face i dont know why just ______
#
# Most probable word according to bigram probability: takes
# Original word:  a
# .............................................
#
#
# Random Sentence from the chapter-:
# a clear expanse of glass but more ______ the greenhouse
#
# Most probable word according to bigram probability: and
# Original word:  like
# .............................................
#
#
# Random Sentence from the chapter-:
# man in ______ finest of health of mind and
#
# Most probable word according to bigram probability: the
# Original word:  the
# .............................................
#
#
# Random Sentence from the chapter-:
# we do objected paul you see if ______ took off
#
# Most probable word according to bigram probability: he
# Original word:  i
# .............................................
#
#
# Random Sentence from the chapter-:
# idea of where ______ was going after the
#
# Most probable word according to bigram probability: the
# Original word:  she
# .............................................
#
#
# Random Sentence from the chapter-:
# a minor error in timing ______ velocity will create a
#
# Most probable word according to bigram probability: i
# Original word:  or
# .............................................
#
#
# Random Sentence from the chapter-:
# explain ______ part why the criminals little idea
#
# Bigram starting with  {'explain'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# dome of glass the spacecraft was aimed ______ the
#
# Most probable word according to bigram probability: a
# Original word:  if
# .............................................
#
#
# Random Sentence from the chapter-:
# guy was cashiered from ______ neoterra run for smuggling huh
#
# Most probable word according to bigram probability: the
# Original word:  the
# .............................................
#
#
# Random Sentence from the chapter-:
# for it when i ______ back do that
#
# Most probable word according to bigram probability: thought
# Original word:  get
# .............................................
#
#
# Random Sentence from the chapter-:
# round ______ magnet swings em round and round and
#
# Bigram starting with  {'round'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# move in their heavenly ______ a poor ten to fifty
#
# Bigram starting with  {'heavenly'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# she wanted paul ______ succeed and she actedif this
#
# Most probable word according to bigram probability: could
# Original word:  to
# .............................................
#
#
# Random Sentence from the chapter-:
# by the time the space travelling ______ reached the spot
#
# Bigram starting with  {'travelling'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# conduct hardly becoming ______ safecracker and a thief
#
# Bigram starting with  {'becoming'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# attack and thwarting any further plans the criminal held ______
#
# Most probable word according to bigram probability: her
# Original word:  for
# .............................................
#
#
# Random Sentence from the chapter-:
# round go the deuterons smack in ______ target
#
# Most probable word according to bigram probability: the
# Original word:  the
# .............................................
#
#
# Random Sentence from the chapter-:
# the man who clipped me turned up with ______ on
#
# Most probable word according to bigram probability: the
# Original word:  scratches
# .............................................
#
#
# Random Sentence from the chapter-:
# of that calibre are ______ chilled because they
#
# Most probable word according to bigram probability: we
# Original word:  often
# .............................................
#
#
# Random Sentence from the chapter-:
# star where it was four years ago ______
#
# Bigram starting with  {'ago'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# a tone of command it ______ more a tone
#
# Most probable word according to bigram probability: was
# Original word:  was
# .............................................
#
#
# Random Sentence from the chapter-:
# to perform ______ acts in pauls name while
#
# Bigram starting with  {'perform'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# a ______ voice she gave him a gentle shove
#
# Most probable word according to bigram probability: large
# Original word:  throaty
# .............................................
#
#
# Random Sentence from the chapter-:
# room for coffee halfway across the lobby ______
#
# Bigram starting with  {'lobby'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# enjoy the prospect of having ______ fumbler running around
#
# Most probable word according to bigram probability: him
# Original word:  a
# .............................................
#
#
# Random Sentence from the chapter-:
# be either juicy or full of sawdust ______ upon
#
# Bigram starting with  {'sawdust'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# dream to think of haedaecker and ______ zwave to plan
#
# Most probable word according to bigram probability: the
# Original word:  the
# .............................................
#
#
# Random Sentence from the chapter-:
# angles ______ showed nora his folder of data the
#
# Bigram starting with  {'angles'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# lipreader peering at her ______ a telescope from
#
# Most probable word according to bigram probability: outdistanced
# Original word:  through
# .............................................
#
#
# Random Sentence from the chapter-:
# an advantage and then sit on ______ until im safe
#
# Most probable word according to bigram probability: the
# Original word:  it
# .............................................
#
#
# Random Sentence from the chapter-:
# a lack of comprehension paul smiled ______ second
#
# Most probable word according to bigram probability: we
# Original word:  one
# .............................................
#
#
# Random Sentence from the chapter-:
# victim and an ______ woman discovered that the woman
#
# Most probable word according to bigram probability: eye
# Original word:  hysterical
# .............................................
#
#
# Random Sentence from the chapter-:
# for a large office of lawyers i ______ get
#
# Most probable word according to bigram probability: thought
# Original word:  can
# .............................................
#
#
# Random Sentence from the chapter-:
# each ______ held shutter flaps that would snap
#
# Most probable word according to bigram probability: pair
# Original word:  one
# .............................................
#
#
# Random Sentence from the chapter-:
# judo now if nora phillips knew judo ______
#
# Bigram starting with  {'judo'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# intend to ______ on the way for nine days
#
# Most probable word according to bigram probability: the
# Original word:  be
# .............................................
#
#
# Random Sentence from the chapter-:
# prospect of having a fumbler ______ around with
#
# Bigram starting with  {'fumbler'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# remove one of ______ errors that of the crude
#
# Most probable word according to bigram probability: the
# Original word:  the
# .............................................
#
#
# Random Sentence from the chapter-:
# turned him to ______ the spaceport door its that way
#
# Most probable word according to bigram probability: the
# Original word:  face
# .............................................
#
#
# Random Sentence from the chapter-:
# you what kind of job ______ you hold why
#
# Most probable word according to bigram probability: huston
# Original word:  do
# .............................................
#
#
# Random Sentence from the chapter-:
# and ______ rotational velocity differing from an hypothetical takeoff
#
# Most probable word according to bigram probability: the
# Original word:  some
# .............................................
#
#
# Random Sentence from the chapter-:
# fine ______ negative evidence i offer you two
#
# Bigram starting with  {'fine'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# with you now uhhuh paul thought ______ just
#
# Most probable word according to bigram probability: we
# Original word:  fast
# .............................................
#
#
# Random Sentence from the chapter-:
# off like jet propelled ______ bother to say
#
# Bigram starting with  {'propelled'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# space she said softly thats a strange ______ to say
#
# Bigram starting with  {'strange'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# automatic the fortyfive is ______ gangsters weapon and
#
# Most probable word according to bigram probability: the
# Original word:  a
# .............................................
#
#
# Random Sentence from the chapter-:
# give ______ for his efforts he received a pleasant
#
# Bigram starting with  {'give'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# entered in the machine before the start lever ______ pulled
#
# Bigram starting with  {'lever'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# could be ______ as a lineofsight aiming point
#
# Most probable word according to bigram probability: a
# Original word:  used
# .............................................
#
#
# Random Sentence from the chapter-:
# moved aside ______ light would have ceased and the star
#
# Most probable word according to bigram probability: just
# Original word:  the
# .............................................
#
#
# Random Sentence from the chapter-:
# account a correctionangle found and then used ______
#
# Bigram starting with  {'used'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# peering at her through a telescope from a ______
#
# Most probable word according to bigram probability: large
# Original word:  room
# .............................................
#
#
# Random Sentence from the chapter-:
# maybe it ______ be a good idea for him
#
# Most probable word according to bigram probability: was
# Original word:  might
# .............................................
#
#
# Random Sentence from the chapter-:
# an alias pseudonym or nom de jour ______ french lacked
#
# Bigram starting with  {'jour'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# experience ______ practise on the other hand nora phillips
#
# Bigram starting with  {'experience'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# french lacked ______ certain vocabulary but it was
#
# Bigram starting with  {'lacked'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# could learn to like this sort of ______ he
#
# Most probable word according to bigram probability: the
# Original word:  thing
# .............................................
#
#
# Random Sentence from the chapter-:
# one held ______ flaps that would snap closed if
#
# Most probable word according to bigram probability: her
# Original word:  shutter
# .............................................
#
#
# Random Sentence from the chapter-:
# the other hand nora phillips had behaved ______
#
# Bigram starting with  {'behaved'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# eye no marks not a trace paul ______ and
#
# Most probable word according to bigram probability: could
# Original word:  smiled
# .............................................
#
#
# Random Sentence from the chapter-:
# before the takeoff ______ the spotter would emit
#
# Most probable word according to bigram probability: with
# Original word:  time
# .............................................
#
#
# Random Sentence from the chapter-:
# if nora phillips knew judo paul smiled ______ he
#
# Most probable word according to bigram probability: we
# Original word:  faintly
# .............................................
#
#
# Random Sentence from the chapter-:
# so many seconds a ______ error in timing
#
# Most probable word according to bigram probability: large
# Original word:  minor
# .............................................
#
#
# Random Sentence from the chapter-:
# hand nora ______ had behaved as though she wanted
#
# Most probable word according to bigram probability: i
# Original word:  phillips
# .............................................
#
#
# Random Sentence from the chapter-:
# of glass the spacecraft ______ aimed if the stars
#
# Most probable word according to bigram probability: the
# Original word:  was
# .............................................
#
#
# Random Sentence from the chapter-:
# shutter ______ that would snap closed if the pane
#
# Bigram starting with  {'shutter'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# at the very top of this dome ______ glass
#
# Bigram starting with  {'dome'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# on it until im safe in space ______ shuddered
#
# Most probable word according to bigram probability: between
# Original word:  nora
# .............................................
#
#
# Random Sentence from the chapter-:
# negative evidence my fine ______ negative evidence i
#
# Bigram starting with  {'fine'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# the scope until it disappeared he was ______
#
# Most probable word according to bigram probability: a
# Original word:  now
# .............................................
#
#
# Random Sentence from the chapter-:
# to that the fact that ______ am taking off from
#
# Most probable word according to bigram probability: the
# Original word:  i
# .............................................
#
#
# Random Sentence from the chapter-:
# he told ______ im true to em all
#
# Most probable word according to bigram probability: to
# Original word:  her
# .............................................
#
#
# Random Sentence from the chapter-:
# used my identification last night have any ______
#
# Most probable word according to bigram probability: evidence
# Original word:  scratches
# .............................................
#
#
# Random Sentence from the chapter-:
# now if nora phillips knew judo it was ______ that
#
# Most probable word according to bigram probability: a
# Original word:  plausible
# .............................................
#
#
# Random Sentence from the chapter-:
# said ______ heres one more bit of information that may
#
# Most probable word according to bigram probability: nora
# Original word:  stacey
# .............................................
#
#
# Random Sentence from the chapter-:
# of that calibre are often chilled because ______ fumble
#
# Most probable word according to bigram probability: he
# Original word:  they
# .............................................
#
#
# Random Sentence from the chapter-:
# the pane of glass beside ______ became pierced
#
# Bigram starting with  {'beside'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# swing at it but its ______ too important okay
#
# Most probable word according to bigram probability: evidence
# Original word:  not
# .............................................
#
#
# Random Sentence from the chapter-:
# slenderness of her body ______ sculptured arms were molded with
#
# Bigram starting with  {'body'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# over and asked hi hello ______ im sorry about last
#
# Bigram starting with  {'hello'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# spacecraft or ______ ruin of a radio beacon
#
# Most probable word according to bigram probability: so
# Original word:  the
# .............................................
#
#
# Random Sentence from the chapter-:
# had been handed to him by haedaecker but ______
#
# Most probable word according to bigram probability: it
# Original word:  apparently
# .............................................
#
#
# Random Sentence from the chapter-:
# than four ______ years away that means that
#
# Bigram starting with  {'four'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# dame drive if we didnt ______ an idea
#
# Bigram starting with  {'didnt'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# and her lips were soft and ______ it was a
#
# Most probable word according to bigram probability: the
# Original word:  clinging
# .............................................
#
#
# Random Sentence from the chapter-:
# time the ______ would emit an atomic spotlight
#
# Most probable word according to bigram probability: other
# Original word:  spotter
# .............................................
#
#
# Random Sentence from the chapter-:
# point for the ______ pilot the ship could
#
# Most probable word according to bigram probability: other
# Original word:  space
# .............................................
#
#
# Random Sentence from the chapter-:
# for the star where it was ______ years
#
# Most probable word according to bigram probability: a
# Original word:  four
# .............................................
#
#
# Random Sentence from the chapter-:
# and eightysix thousand miles ______ error one second of
#
# Most probable word according to bigram probability: of
# Original word:  of
# .............................................
#
#
# Random Sentence from the chapter-:
# or faint these days nor did they ______ their attacker
#
# Most probable word according to bigram probability: were
# Original word:  rake
# .............................................
#
#
# Random Sentence from the chapter-:
# was on his way nothing ______ do for
#
# Most probable word according to bigram probability: in
# Original word:  to
# .............................................
#
#
# Random Sentence from the chapter-:
# on ______ job i havent much but there are
#
# Most probable word according to bigram probability: the
# Original word:  the
# .............................................
#
#
# Random Sentence from the chapter-:
# held came free and joined the ______ she
#
# Most probable word according to bigram probability: other
# Original word:  other
# .............................................
#
#
# Random Sentence from the chapter-:
# it was ______ years ago i intend to be
#
# Most probable word according to bigram probability: a
# Original word:  four
# .............................................
#
#
# Random Sentence from the chapter-:
# other hand nora phillips had behaved as though she ______
#
# Most probable word according to bigram probability: wasted
# Original word:  wanted
# .............................................
#
#
# Random Sentence from the chapter-:
# would ______ her away so paul took her hand as
#
# Most probable word according to bigram probability: be
# Original word:  give
# .............................................
#
#
# Random Sentence from the chapter-:
# of ______ at one lightvelocity equals a hundred
#
# Most probable word according to bigram probability: the
# Original word:  error
# .............................................
#
#
# Random Sentence from the chapter-:
# nicely men of that calibre ______ often chilled because
#
# Bigram starting with  {'calibre'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# said ______ was not a tone of command it
#
# Most probable word according to bigram probability: nora
# Original word:  it
# .............................................
#
#
# Random Sentence from the chapter-:
# feet in diameter was optically perfect ______ through
#
# Bigram starting with  {'perfect'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# bulge ______ the hull swelled out in the gentle
#
# Bigram starting with  {'bulge'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# joined the other she was warm and supple in ______
#
# Most probable word according to bigram probability: the
# Original word:  his
# .............................................
#
#
# Random Sentence from the chapter-:
# her ______ but how do i know youll be
#
# Most probable word according to bigram probability: outdistanced
# Original word:  mouth
# .............................................
#
#
# Random Sentence from the chapter-:
# gorgons couldnt ______ me he chuckled he reached for
#
# Bigram starting with  {'couldnt'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# to check up actually im ______ just that
#
# Most probable word according to bigram probability: not
# Original word:  doing
# .............................................
#
#
# Random Sentence from the chapter-:
# that he held came ______ and joined the other
#
# Most probable word according to bigram probability: the
# Original word:  free
# .............................................
#
#
# Random Sentence from the chapter-:
# you taste it your girl friend nora phillips was ______
#
# Most probable word according to bigram probability: a
# Original word:  born
# .............................................
#
#
# Random Sentence from the chapter-:
# from ______ it really is students of trigonometry
#
# Most probable word according to bigram probability: the
# Original word:  where
# .............................................
#
#
# Random Sentence from the chapter-:
# woman and neither complete dishabille nor ______ imperfection would
#
# Most probable word according to bigram probability: had
# Original word:  minor
# .............................................
#
#
# Random Sentence from the chapter-:
# makes it ______ aint all came staceys voice the
#
# Most probable word according to bigram probability: was
# Original word:  that
# .............................................
#
#
# Random Sentence from the chapter-:
# add once more to that ______ was the
#
# Most probable word according to bigram probability: the
# Original word:  error
# .............................................
#
#
# Random Sentence from the chapter-:
# the ______ room intending to hit the dining
#
# Most probable word according to bigram probability: other
# Original word:  computation
# .............................................
#
#
# Random Sentence from the chapter-:
# judo ______ upon him if she knew judo
#
# Bigram starting with  {'judo'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# been empirical knowledge for ______ couple of millions
#
# Most probable word according to bigram probability: the
# Original word:  a
# .............................................
#
#
# Random Sentence from the chapter-:
# by haedaecker ______ apparently the longrange calculations that had
#
# Most probable word according to bigram probability: while
# Original word:  but
# .............................................
#
#
# Random Sentence from the chapter-:
# at the end of the ______ flying time once
#
# Most probable word according to bigram probability: other
# Original word:  ships
# .............................................
#
#
# Random Sentence from the chapter-:
# earth which will give me some ______ velocity and
#
# Most probable word according to bigram probability: planet
# Original word:  angular
# .............................................
#
#
# Random Sentence from the chapter-:
# to face the spaceport door its ______ way
#
# Most probable word according to bigram probability: evidence
# Original word:  that
# .............................................
#
#
# Random Sentence from the chapter-:
# thwarting any further plans ______ criminal held for
#
# Bigram starting with  {'plans'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# of a spacecraft or the ruin of a ______
#
# Most probable word according to bigram probability: large
# Original word:  radio
# .............................................
#
#
# Random Sentence from the chapter-:
# women to kiss youve convinced me but ______ baffled
#
# Most probable word according to bigram probability: it
# Original word:  im
# .............................................
#
#
# Random Sentence from the chapter-:
# tap their ______ but we had a lipreader peering at
#
# Most probable word according to bigram probability: statements
# Original word:  telephone
# .............................................
#
#
# Random Sentence from the chapter-:
# will ______ quite some distance from where it really is
#
# Most probable word according to bigram probability: be
# Original word:  be
# .............................................
#
#
# Random Sentence from the chapter-:
# of sight ______ for it directly of course by
#
# Bigram starting with  {'sight'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# of that calibre are often chilled because they ______ a
#
# Most probable word according to bigram probability: were
# Original word:  fumble
# .............................................
#
#
# Random Sentence from the chapter-:
# react unfavorably to any ______ attempt at approach regardless
#
# Most probable word according to bigram probability: evidence
# Original word:  crude
# .............................................
#
#
# Random Sentence from the chapter-:
# but why so many chuckled nora variety ______
#
# Bigram starting with  {'variety'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# neoterra run for smuggling huh blurted paul ______ expilot tossed
#
# Most probable word according to bigram probability: could
# Original word:  an
# .............................................
#
#
# Random Sentence from the chapter-:
# not aim ______ it and run she asked surely
#
# Bigram starting with  {'aim'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# mob it seemed to paul that ______ woman had done
#
# Most probable word according to bigram probability: the
# Original word:  the
# .............................................
#
#
# Random Sentence from the chapter-:
# to point the nose of the ______ at the spot
#
# Most probable word according to bigram probability: other
# Original word:  ship
# .............................................
#
#
# Random Sentence from the chapter-:
# dinner ______ candlelight with music et al but ptomaine
#
# Bigram starting with  {'dinner'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# proxima centauri instead ______ alpha and that must
#
# Most probable word according to bigram probability: of
# Original word:  of
# .............................................
#
#
# Random Sentence from the chapter-:
# he looked me right in the eye ______ marks
#
# Most probable word according to bigram probability: on
# Original word:  no
# .............................................
#
#
# Random Sentence from the chapter-:
# like the greenhouse roof small ______ set between rigid
#
# Bigram starting with  {'small'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# and ______ to dream of nora phillips paul began
#
# Most probable word according to bigram probability: the
# Original word:  fortune
# .............................................
#
#
# Random Sentence from the chapter-:
# the space pilot the ship ______ take off on
#
# Most probable word according to bigram probability: took
# Original word:  could
# .............................................
#
#
# Random Sentence from the chapter-:
# these acts ______ consummated paul could be found
#
# Bigram starting with  {'acts'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# neoterra youre certain of that ______ the bureau
#
# Most probable word according to bigram probability: the
# Original word:  so
# .............................................
#
#
# Random Sentence from the chapter-:
# this ______ searchlight would arrive at terra to
#
# Most probable word according to bigram probability: is
# Original word:  immense
# .............................................
#
#
# Random Sentence from the chapter-:
# true to em ______ but why so many chuckled
#
# Bigram starting with  {'em'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# speed ______ was on his way nothing to do for
#
# Most probable word according to bigram probability: running
# Original word:  he
# .............................................
#
#
# Random Sentence from the chapter-:
# vegan gorgons couldnt stop me he chuckled he reached ______
#
# Most probable word according to bigram probability: the
# Original word:  for
# .............................................
#
#
# ...
#
# Bigram starting with  {'perform'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# error in ______ at the end of the run oh
#
# Most probable word according to bigram probability: the
# Original word:  position
# .............................................
#
#
# Random Sentence from the chapter-:
# the lam how do you ______ that it doesnt
#
# Most probable word according to bigram probability: can
# Original word:  make
# .............................................
#
#
# Random Sentence from the chapter-:
# stepped back a bit he turned around ______ started
#
# Most probable word according to bigram probability: then
# Original word:  and
# .............................................
#
#
# Random Sentence from the chapter-:
# along their driving axis so that ______ angle
#
# Most probable word according to bigram probability: the
# Original word:  the
# .............................................
#
#
# Random Sentence from the chapter-:
# that had not been empirical ______ for a couple of
#
# Bigram starting with  {'empirical'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# i suppose you know ______ the guy was cashiered from
#
# Most probable word according to bigram probability: about
# Original word:  that
# .............................................
#
#
# Random Sentence from the chapter-:
# to face the spaceport door its ______ way she said
#
# Most probable word according to bigram probability: evidence
# Original word:  that
# .............................................
#
#
# Random Sentence from the chapter-:
# punishing judo ______ upon him if she knew judo
#
# Bigram starting with  {'judo'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# terra ill let you pick your ______ but
#
# Most probable word according to bigram probability: own
# Original word:  choice
# .............................................
#
#
# Random Sentence from the chapter-:
# spotlight for a half ______ two hours later the light
#
# Bigram starting with  {'half'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# a moment or two the humming broke out ______
#
# Most probable word according to bigram probability: of
# Original word:  into
# .............................................
#
#
# Random Sentence from the chapter-:
# be a good idea for him to learn ______
#
# Bigram starting with  {'learn'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# me ______ the guy who used my identification last night
#
# Most probable word according to bigram probability: either
# Original word:  did
# .............................................
#
#
# Random Sentence from the chapter-:
# for it when i get back do ______ she
#
# Most probable word according to bigram probability: away
# Original word:  that
# .............................................
#
#
# Random Sentence from the chapter-:
# the type of ______ that would react unfavorably to
#
# Most probable word according to bigram probability: the
# Original word:  woman
# .............................................
#
#
# Random Sentence from the chapter-:
# said nora but her tone indicated ______ lack
#
# Bigram starting with  {'indicated'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# fame and fortune to dream of nora phillips ______
#
# Most probable word according to bigram probability: stacey
# Original word:  paul
# .............................................
#
#
# Random Sentence from the chapter-:
# swelled ______ in the gentle curve and about the place
#
# Bigram starting with  {'swelled'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# before ______ takeoff time the spotter would emit
#
# Most probable word according to bigram probability: he
# Original word:  the
# .............................................
#
#
# Random Sentence from the chapter-:
# see when we are exceeding ______ velocity of light
#
# Bigram starting with  {'exceeding'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# balanced ______ of fine tonus her waist was slender
#
# Bigram starting with  {'balanced'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# intent on ______ paul grayson she was working against them
#
# Most probable word according to bigram probability: the
# Original word:  stopping
# .............................................
#
#
# Random Sentence from the chapter-:
# big telescopes would direct ______ spotter spacecraft via the zwave
#
# Bigram starting with  {'direct'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# have been something ______ of a problem a
#
# Most probable word according to bigram probability: had
# Original word:  less
# .............................................
#
#
# Random Sentence from the chapter-:
# finest of health ______ mind and body if
#
# Bigram starting with  {'health'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# crude attempt ______ approach regardless of whether her interest
#
# Most probable word according to bigram probability: between
# Original word:  at
# .............................................
#
#
# Random Sentence from the chapter-:
# of aforementioned mainspring they made ______ error they should have
#
# Most probable word according to bigram probability: that
# Original word:  one
# .............................................
#
#
# Random Sentence from the chapter-:
# the ______ there are so many of them that they
#
# Most probable word according to bigram probability: other
# Original word:  others
# .............................................
#
#
# Random Sentence from the chapter-:
# destination we do objected paul you see ______ i took
#
# Most probable word according to bigram probability: stacey
# Original word:  if
# .............................................
#
#
# Random Sentence from the chapter-:
# maybe it might be a good idea ______
#
# Most probable word according to bigram probability: for
# Original word:  for
# .............................................
#
#
# Random Sentence from the chapter-:
# light we ______ run at so many lightvelocities for so
#
# Most probable word according to bigram probability: try
# Original word:  must
# .............................................
#
#
# Random Sentence from the chapter-:
# when the announcer called the ______ and number of pauls
#
# Most probable word according to bigram probability: other
# Original word:  time
# .............................................
#
#
# Random Sentence from the chapter-:
# it on the lam how do ______ make
#
# Most probable word according to bigram probability: away
# Original word:  you
# .............................................
#
#
# Random Sentence from the chapter-:
# mcbride and webster attorneysatlaw we couldnt tap ______
#
# Most probable word according to bigram probability: the
# Original word:  their
# .............................................
#
#
# Random Sentence from the chapter-:
# and about the ______ where the softboiledegg gourmet
#
# Most probable word according to bigram probability: other
# Original word:  place
# .............................................
#
#
# Random Sentence from the chapter-:
# of smoothing the headache out of his skull ______ fingers
#
# Bigram starting with  {'skull'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# rake their attacker with fingernails they employed judo ______ if
#
# Bigram starting with  {'judo'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# dame in every port he told her ______ true to
#
# Most probable word according to bigram probability: outdistanced
# Original word:  im
# .............................................
#
#
# Random Sentence from the chapter-:
# a couple of hours ago she received ______ telephone
#
# Bigram starting with  {'received'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# round and round go the deuterons smack ______ the target
#
# Bigram starting with  {'smack'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# make that it doesnt ______ good sense sure
#
# Most probable word according to bigram probability: make
# Original word:  make
# .............................................
#
#
# Random Sentence from the chapter-:
# satisfying emotional experience intellectually it proved ______ that had
#
# Most probable word according to bigram probability: good
# Original word:  nothing
# .............................................
#
#
# Random Sentence from the chapter-:
# information ______ the big machine it was not a complex
#
# Bigram starting with  {'information'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# shore the bow could be aimed at ______ pier
#
# Most probable word according to bigram probability: the
# Original word:  the
# .............................................
#
#
# Random Sentence from the chapter-:
# tone ______ command it was more a tone of
#
# Bigram starting with  {'tone'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# the ______ who clipped me turned up with scratches on
#
# Most probable word according to bigram probability: other
# Original word:  man
# .............................................
#
#
# Random Sentence from the chapter-:
# create a ______ gross error in position at
#
# Most probable word according to bigram probability: large
# Original word:  rather
# .............................................
#
#
# Random Sentence from the chapter-:
# properly located two hours before the takeoff time ______ spotter
#
# Most probable word according to bigram probability: to
# Original word:  the
# .............................................
#
#
# Random Sentence from the chapter-:
# ive ______ dame in every port he told
#
# Most probable word according to bigram probability: read
# Original word:  a
# .............................................
#
#
# Random Sentence from the chapter-:
# you what kind of job do you hold ______
#
# Most probable word according to bigram probability: the
# Original word:  why
# .............................................
#
#
# Random Sentence from the chapter-:
# nor did they rake their attacker ______ fingernails they
#
# Bigram starting with  {'attacker'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# by the spaceport guards ______ regulation police positives our
#
# Bigram starting with  {'guards'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# was hailed ______ the autocall he went to the
#
# Bigram starting with  {'hailed'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# little questions that bothered him time passed ______
#
# Most probable word according to bigram probability: the
# Original word:  swiftly
# .............................................
#
#
# Random Sentence from the chapter-:
# can you tell ______ whether the man who clipped me
#
# Bigram starting with  {'tell'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# surely you do not ______ this billion dollars worth
#
# Most probable word according to bigram probability: understand
# Original word:  need
# .............................................
#
#
# Random Sentence from the chapter-:
# them both when the announcer called ______ time and
#
# Bigram starting with  {'called'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# long way to walk nora understood that ______
#
# Most probable word according to bigram probability: the
# Original word:  and
# .............................................
#
#
# Random Sentence from the chapter-:
# the greenhouse roof small facets set ______ rigid girders in
#
# Most probable word according to bigram probability: out
# Original word:  between
# .............................................
#
#
# Random Sentence from the chapter-:
# her desires to ascertain her ______ before he
#
# Most probable word according to bigram probability: outdistanced
# Original word:  limit
# .............................................
#
#
# Random Sentence from the chapter-:
# other than one of the ______ furthermore he was facing
#
# Most probable word according to bigram probability: other
# Original word:  guards
# .............................................
#
#
# Random Sentence from the chapter-:
# for the future when ______ discoveries brought him
#
# Most probable word according to bigram probability: it
# Original word:  his
# .............................................
#
#
# Random Sentence from the chapter-:
# to choose the aiming telescope in the ______
#
# Most probable word according to bigram probability: other
# Original word:  dome
# .............................................
#
#
# Random Sentence from the chapter-:
# that surrounded every ship during the fasterthanlight ______
#
# Bigram starting with  {'fasterthanlight'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# his folder of data the rest he said ______
#
# Most probable word according to bigram probability: nora
# Original word:  is
# .............................................
#
#
# Random Sentence from the chapter-:
# paul could be found in ______ wreck of a
#
# Most probable word according to bigram probability: the
# Original word:  the
# .............................................
#
#
# Random Sentence from the chapter-:
# the smooth well balanced ______ of fine tonus her waist
#
# Bigram starting with  {'balanced'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# negative evidence i offer you two alternatives ______
#
# Bigram starting with  {'alternatives'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# absolute agreement it ______ him raging vegan gorgons couldnt
#
# Most probable word according to bigram probability: was
# Original word:  pleased
# .............................................
#
#
# Random Sentence from the chapter-:
# showed nora his folder ______ data the rest
#
# Bigram starting with  {'folder'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# paul could be found in ______ wreck of
#
# Most probable word according to bigram probability: the
# Original word:  the
# .............................................
#
#
# Random Sentence from the chapter-:
# information ______ might lead to the capture arrest conviction andor
#
# Bigram starting with  {'information'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# binary digits and handed ______ a strip of paper printed
#
# Bigram starting with  {'handed'}  wasn't found in the training text.
# .............................................
#
#
# Random Sentence from the chapter-:
# were doing your duty but ______ you tell me did
#
# Most probable word according to bigram probability: it
# Original word:  can
# .............................................
#
#
# Random Sentence from the chapter-:
# think and plan and dream to think ______ haedaecker
#
# Most probable word according to bigram probability: until
# Original word:  of
# .............................................

# %% [markdown]
# ## Writing a function and visualising the Shannon game guesses on a Pie Chart

# %%
def visualise_the_guesses(correct,incorrect):
    y=[correct,incorrect]
    total=correct+incorrect
    accuracy=(float(correct)/total)
    mylabels=[f"Correctly Identified {accuracy*100:.2f}%",f"Incorrectly Identified {(1-accuracy)*100:.2f}%"]
    myexplode=[0,0.2]
    mycolors = ["green", "red"]
    plt.pie(y,labels=mylabels,explode=myexplode,colors=mycolors)
    plt.show()

# %%
visualise_the_guesses(correct,incorrect)

# %% [markdown]
# The bigram probability constructed from the largest chapter of the book helped us to identify 5 to 9% of the words from a random sentence in a random chapter. If the training text were bigger better accuracy would have been expected.
